# %% [markdown]
# Analysis of FOOOF results from resting state

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# load csv files with aperiodic and periodic data
MS001_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS001_periodic_df.csv')
MS001_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS001_aperiodic_df.csv')

MS003_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS003_periodic_df.csv')
MS003_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS003_aperiodic_df.csv')

MS006_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS006_periodic_df.csv')
MS006_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS006_aperiodic_df.csv')

MS007_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS007_periodic_df.csv')
MS007_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS007_aperiodic_df.csv')

MS008_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS008_periodic_df.csv')
MS008_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS008_aperiodic_df.csv')

MS010_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS010_periodic_df.csv')
MS010_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS010_aperiodic_df.csv')

MS012_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS012_periodic_df.csv')
MS012_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS012_aperiodic_df.csv')

MS014_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS014_periodic_df.csv')
MS014_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS014_aperiodic_df.csv')

MS016_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS016_periodic_df.csv')
MS016_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS016_aperiodic_df.csv')

MS017_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS017_periodic_df.csv')
MS017_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS017_aperiodic_df.csv')

MS018_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS018_periodic_df.csv')
MS018_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS018_aperiodic_df.csv')

MS019_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS019_periodic_df.csv')
MS019_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS019_aperiodic_df.csv')

MS020_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS020_periodic_df.csv')
MS020_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS020_aperiodic_df.csv')

MS022_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS022_periodic_df.csv')
MS022_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS022_aperiodic_df.csv')

MS023_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS023_periodic_df.csv')
MS023_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS023_aperiodic_df.csv')

MS024_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS024_periodic_df.csv')
MS024_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS024_aperiodic_df.csv')

MS025_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS025_periodic_df.csv')
MS025_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS025_aperiodic_df.csv')

MS026_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS026_periodic_df.csv')
MS026_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS026_aperiodic_df.csv')

MS027_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS027_periodic_df.csv')
MS027_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS027_aperiodic_df.csv')

MS028_periodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS028_periodic_df.csv')
MS028_aperiodic = pd.read_csv('/Users/christinamaher/Desktop/fooof_results/MS028_aperiodic_df.csv')

# %%
# load anatomical data
MS001_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS001_labels.csv')
MS003_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS003_labels.csv')
MS006_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS006_labels.csv')
MS007_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS007_labels.csv')
MS008_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS008_labels.csv')
MS010_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS010_labels.csv')
MS012_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS012_labels.csv')
MS014_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS014_labels.csv')
MS016_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS016_labels.csv')
MS017_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS017_labels.csv')
MS018_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS018_labels.csv')
MS019_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS019_labels.csv')
MS020_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS020_labels.csv')
MS022_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS022_labels.csv')
MS023_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS023_labels.csv')
MS024_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS024_labels.csv')
MS025_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS025_labels.csv')
MS026_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS026_labels.csv')
MS027_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS027_labels.csv')
MS028_anat = pd.read_csv('/Users/christinamaher/Documents/GitHub/resting_state_ieeg/anat/MS028_labels.csv')

# %%
MS001_periodic
# Out:
#            ch_name subject      power  center_freq  bandwidth freq_band  \
# 0    lacas1-lacas2   MS001   6.239841     0.483022   2.279871       NaN
# 1    lacas1-lacas2   MS001   9.016785     0.396839   2.172196       NaN
# 2    lacas1-lacas2   MS001  12.878035     0.335320   5.182434       NaN
# 3    lacas1-lacas2   MS001  19.335842     0.192703   6.000000       NaN
# 4    lacas1-lacas2   MS001  26.307218     0.066048   4.289757       NaN
# ..             ...     ...        ...          ...        ...       ...
# 208  rmtpt7-rmtpt8   MS001  31.963131     0.233923   1.000000       NaN
# 209  rmtpt8-rmtpt9   MS001   7.046195     0.558615   2.780525       NaN
# 210  rmtpt8-rmtpt9   MS001  13.043819     0.327905   6.000000       NaN
# 211  rmtpt8-rmtpt9   MS001  19.952035     0.131775   6.000000       NaN
# 212  rmtpt8-rmtpt9   MS001  31.977416     0.090139   1.000000       NaN
#
#                 uniqueID
# 0    lacas1-lacas2_MS001
# 1    lacas1-lacas2_MS001
# 2    lacas1-lacas2_MS001
# 3    lacas1-lacas2_MS001
# 4    lacas1-lacas2_MS001
# ..                   ...
# 208  rmtpt7-rmtpt8_MS001
# 209  rmtpt8-rmtpt9_MS001
# 210  rmtpt8-rmtpt9_MS001
# 211  rmtpt8-rmtpt9_MS001
# 212  rmtpt8-rmtpt9_MS001
#
# [213 rows x 7 columns]

# %%
# make label column lowercase for all anatomical data
MS001_anat['label'] = MS001_anat['label'].str.lower()
MS003_anat['label'] = MS003_anat['label'].str.lower()
MS006_anat['label'] = MS006_anat['label'].str.lower()
MS007_anat['label'] = MS007_anat['label'].str.lower()
MS008_anat['label'] = MS008_anat['label'].str.lower()
MS010_anat['label'] = MS010_anat['label'].str.lower()
MS012_anat['label'] = MS012_anat['label'].str.lower()
MS014_anat['label'] = MS014_anat['label'].str.lower()
MS016_anat['label'] = MS016_anat['label'].str.lower()
MS017_anat['label'] = MS017_anat['label'].str.lower()
MS018_anat['label'] = MS018_anat['label'].str.lower()
MS019_anat['label'] = MS019_anat['label'].str.lower()
MS020_anat['label'] = MS020_anat['label'].str.lower()
MS022_anat['label'] = MS022_anat['label'].str.lower()
MS023_anat['label'] = MS023_anat['label'].str.lower()
MS024_anat['label'] = MS024_anat['label'].str.lower()
MS025_anat['label'] = MS025_anat['label'].str.lower()
MS026_anat['label'] = MS026_anat['label'].str.lower()
MS027_anat['label'] = MS027_anat['label'].str.lower()
MS028_anat['label'] = MS028_anat['label'].str.lower()


# merge anatomical and periodic data
MS001_periodic_anat = pd.merge(MS001_periodic, MS001_anat, left_on=MS001_periodic['ch_name'].str.split('-').str[0], right_on=MS001_anat['label'].str.split('-').str[0])
MS003_periodic_anat = pd.merge(MS003_periodic, MS003_anat, left_on=MS003_periodic['ch_name'].str.split('-').str[0], right_on=MS003_anat['label'].str.split('-').str[0])
MS006_periodic_anat = pd.merge(MS006_periodic, MS006_anat, left_on=MS006_periodic['ch_name'].str.split('-').str[0], right_on=MS006_anat['label'].str.split('-').str[0])
MS007_periodic_anat = pd.merge(MS007_periodic, MS007_anat, left_on=MS007_periodic['ch_name'].str.split('-').str[0], right_on=MS007_anat['label'].str.split('-').str[0])
MS008_periodic_anat = pd.merge(MS008_periodic, MS008_anat, left_on=MS008_periodic['ch_name'].str.split('-').str[0], right_on=MS008_anat['label'].str.split('-').str[0])
MS010_periodic_anat = pd.merge(MS010_periodic, MS010_anat, left_on=MS010_periodic['ch_name'].str.split('-').str[0], right_on=MS010_anat['label'].str.split('-').str[0])
MS012_periodic_anat = pd.merge(MS012_periodic, MS012_anat, left_on=MS012_periodic['ch_name'].str.split('-').str[0], right_on=MS012_anat['label'].str.split('-').str[0])
MS014_periodic_anat = pd.merge(MS014_periodic, MS014_anat, left_on=MS014_periodic['ch_name'].str.split('-').str[0], right_on=MS014_anat['label'].str.split('-').str[0])
MS016_periodic_anat = pd.merge(MS016_periodic, MS016_anat, left_on=MS016_periodic['ch_name'].str.split('-').str[0], right_on=MS016_anat['label'].str.split('-').str[0])
MS017_periodic_anat = pd.merge(MS017_periodic, MS017_anat, left_on=MS017_periodic['ch_name'].str.split('-').str[0], right_on=MS017_anat['label'].str.split('-').str[0])
MS018_periodic_anat = pd.merge(MS018_periodic, MS018_anat, left_on=MS018_periodic['ch_name'].str.split('-').str[0], right_on=MS018_anat['label'].str.split('-').str[0])
MS019_periodic_anat = pd.merge(MS019_periodic, MS019_anat, left_on=MS019_periodic['ch_name'].str.split('-').str[0], right_on=MS019_anat['label'].str.split('-').str[0])
MS020_periodic_anat = pd.merge(MS020_periodic, MS020_anat, left_on=MS020_periodic['ch_name'].str.split('-').str[0], right_on=MS020_anat['label'].str.split('-').str[0])
MS022_periodic_anat = pd.merge(MS022_periodic, MS022_anat, left_on=MS022_periodic['ch_name'].str.split('-').str[0], right_on=MS022_anat['label'].str.split('-').str[0])
MS023_periodic_anat = pd.merge(MS023_periodic, MS023_anat, left_on=MS023_periodic['ch_name'].str.split('-').str[0], right_on=MS023_anat['label'].str.split('-').str[0])
MS024_periodic_anat = pd.merge(MS024_periodic, MS024_anat, left_on=MS024_periodic['ch_name'].str.split('-').str[0], right_on=MS024_anat['label'].str.split('-').str[0])
MS025_periodic_anat = pd.merge(MS025_periodic, MS025_anat, left_on=MS025_periodic['ch_name'].str.split('-').str[0], right_on=MS025_anat['label'].str.split('-').str[0])
MS026_periodic_anat = pd.merge(MS026_periodic, MS026_anat, left_on=MS026_periodic['ch_name'].str.split('-').str[0], right_on=MS026_anat['label'].str.split('-').str[0])
MS027_periodic_anat = pd.merge(MS027_periodic, MS027_anat, left_on=MS027_periodic['ch_name'].str.split('-').str[0], right_on=MS027_anat['label'].str.split('-').str[0])
MS028_periodic_anat = pd.merge(MS028_periodic, MS028_anat, left_on=MS028_periodic['ch_name'].str.split('-').str[0], right_on=MS028_anat['label'].str.split('-').str[0])

# merge the anatomical and aperiodic data 
MS001_aperiodic_anat = pd.merge(MS001_aperiodic, MS001_anat, left_on=MS001_aperiodic['ch_name'].str.split('-').str[0], right_on=MS001_anat['label'].str.split('-').str[0])
MS003_aperiodic_anat = pd.merge(MS003_aperiodic, MS003_anat, left_on=MS003_aperiodic['ch_name'].str.split('-').str[0], right_on=MS003_anat['label'].str.split('-').str[0])
MS006_aperiodic_anat = pd.merge(MS006_aperiodic, MS006_anat, left_on=MS006_aperiodic['ch_name'].str.split('-').str[0], right_on=MS006_anat['label'].str.split('-').str[0])
MS007_aperiodic_anat = pd.merge(MS007_aperiodic, MS007_anat, left_on=MS007_aperiodic['ch_name'].str.split('-').str[0], right_on=MS007_anat['label'].str.split('-').str[0])
MS008_aperiodic_anat = pd.merge(MS008_aperiodic, MS008_anat, left_on=MS008_aperiodic['ch_name'].str.split('-').str[0], right_on=MS008_anat['label'].str.split('-').str[0])
MS010_aperiodic_anat = pd.merge(MS010_aperiodic, MS010_anat, left_on=MS010_aperiodic['ch_name'].str.split('-').str[0], right_on=MS010_anat['label'].str.split('-').str[0])
MS012_aperiodic_anat = pd.merge(MS012_aperiodic, MS012_anat, left_on=MS012_aperiodic['ch_name'].str.split('-').str[0], right_on=MS012_anat['label'].str.split('-').str[0])
MS014_aperiodic_anat = pd.merge(MS014_aperiodic, MS014_anat, left_on=MS014_aperiodic['ch_name'].str.split('-').str[0], right_on=MS014_anat['label'].str.split('-').str[0])
MS016_aperiodic_anat = pd.merge(MS016_aperiodic, MS016_anat, left_on=MS016_aperiodic['ch_name'].str.split('-').str[0], right_on=MS016_anat['label'].str.split('-').str[0])
MS017_aperiodic_anat = pd.merge(MS017_aperiodic, MS017_anat, left_on=MS017_aperiodic['ch_name'].str.split('-').str[0], right_on=MS017_anat['label'].str.split('-').str[0])
MS018_aperiodic_anat = pd.merge(MS018_aperiodic, MS018_anat, left_on=MS018_aperiodic['ch_name'].str.split('-').str[0], right_on=MS018_anat['label'].str.split('-').str[0])
MS019_aperiodic_anat = pd.merge(MS019_aperiodic, MS019_anat, left_on=MS019_aperiodic['ch_name'].str.split('-').str[0], right_on=MS019_anat['label'].str.split('-').str[0])
MS020_aperiodic_anat = pd.merge(MS020_aperiodic, MS020_anat, left_on=MS020_aperiodic['ch_name'].str.split('-').str[0], right_on=MS020_anat['label'].str.split('-').str[0])
MS022_aperiodic_anat = pd.merge(MS022_aperiodic, MS022_anat, left_on=MS022_aperiodic['ch_name'].str.split('-').str[0], right_on=MS022_anat['label'].str.split('-').str[0])
MS023_aperiodic_anat = pd.merge(MS023_aperiodic, MS023_anat, left_on=MS023_aperiodic['ch_name'].str.split('-').str[0], right_on=MS023_anat['label'].str.split('-').str[0])
MS024_aperiodic_anat = pd.merge(MS024_aperiodic, MS024_anat, left_on=MS024_aperiodic['ch_name'].str.split('-').str[0], right_on=MS024_anat['label'].str.split('-').str[0])
MS025_aperiodic_anat = pd.merge(MS025_aperiodic, MS025_anat, left_on=MS025_aperiodic['ch_name'].str.split('-').str[0], right_on=MS025_anat['label'].str.split('-').str[0])
MS026_aperiodic_anat = pd.merge(MS026_aperiodic, MS026_anat, left_on=MS026_aperiodic['ch_name'].str.split('-').str[0], right_on=MS026_anat['label'].str.split('-').str[0])
MS027_aperiodic_anat = pd.merge(MS027_aperiodic, MS027_anat, left_on=MS027_aperiodic['ch_name'].str.split('-').str[0], right_on=MS027_anat['label'].str.split('-').str[0])
MS028_aperiodic_anat = pd.merge(MS028_aperiodic, MS028_anat, left_on=MS028_aperiodic['ch_name'].str.split('-').str[0], right_on=MS028_anat['label'].str.split('-').str[0])

# %%
# drop white matter and OOB channels
MS001_periodic_anat = MS001_periodic_anat[~MS001_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS001_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS003_periodic_anat = MS003_periodic_anat[~MS003_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS003_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS006_periodic_anat = MS006_periodic_anat[~MS006_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS006_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS007_periodic_anat = MS007_periodic_anat[~MS007_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS007_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS008_periodic_anat = MS008_periodic_anat[~MS008_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS008_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS010_periodic_anat = MS010_periodic_anat[~MS010_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS010_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS012_periodic_anat = MS012_periodic_anat[~MS012_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS012_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS014_periodic_anat = MS014_periodic_anat[~MS014_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS014_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS016_periodic_anat = MS016_periodic_anat[~MS016_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS016_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS017_periodic_anat = MS017_periodic_anat[~MS017_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS017_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS018_periodic_anat = MS018_periodic_anat[~MS018_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS018_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS019_periodic_anat = MS019_periodic_anat[~MS019_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS019_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS020_periodic_anat = MS020_periodic_anat[~MS020_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS020_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS022_periodic_anat = MS022_periodic_anat[~MS022_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS022_periodic_anat['ManualExamination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS023_periodic_anat = MS023_periodic_anat[~MS023_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS023_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS024_periodic_anat = MS024_periodic_anat[~MS024_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS024_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS025_periodic_anat = MS025_periodic_anat[~MS025_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS025_periodic_anat['ManualExamination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS026_periodic_anat = MS026_periodic_anat[~MS026_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS026_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS027_periodic_anat = MS027_periodic_anat[~MS027_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS027_periodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS028_periodic_anat = MS028_periodic_anat[~MS028_periodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS028_periodic_anat['ManualExamination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]

# do the same for aperiodic data
MS001_aperiodic_anat = MS001_aperiodic_anat[~MS001_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS001_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS003_aperiodic_anat = MS003_aperiodic_anat[~MS003_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS003_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS006_aperiodic_anat = MS006_aperiodic_anat[~MS006_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS006_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS007_aperiodic_anat = MS007_aperiodic_anat[~MS007_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS007_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS008_aperiodic_anat = MS008_aperiodic_anat[~MS008_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS008_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS010_aperiodic_anat = MS010_aperiodic_anat[~MS010_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS010_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS012_aperiodic_anat = MS012_aperiodic_anat[~MS012_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS012_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS014_aperiodic_anat = MS014_aperiodic_anat[~MS014_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS014_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS016_aperiodic_anat = MS016_aperiodic_anat[~MS016_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS016_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS017_aperiodic_anat = MS017_aperiodic_anat[~MS017_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS017_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS018_aperiodic_anat = MS018_aperiodic_anat[~MS018_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS018_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS019_aperiodic_anat = MS019_aperiodic_anat[~MS019_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS019_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS020_aperiodic_anat = MS020_aperiodic_anat[~MS020_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS020_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS022_aperiodic_anat = MS022_aperiodic_anat[~MS022_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS022_aperiodic_anat['ManualExamination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS023_aperiodic_anat = MS023_aperiodic_anat[~MS023_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS023_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS024_aperiodic_anat = MS024_aperiodic_anat[~MS024_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS024_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS025_aperiodic_anat = MS025_aperiodic_anat[~MS025_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS025_aperiodic_anat['ManualExamination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS026_aperiodic_anat = MS026_aperiodic_anat[~MS026_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS026_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS027_aperiodic_anat = MS027_aperiodic_anat[~MS027_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS027_aperiodic_anat['Manual Examination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]
MS028_aperiodic_anat = MS028_aperiodic_anat[~MS028_aperiodic_anat['gm'].str.lower().isin(['wm', 'oob', 'white', 'unknown']) | ~MS028_aperiodic_anat['ManualExamination'].str.lower().isin(['wm', 'oob', 'white','unknown'])]

# %%
# assign the YBA labels to regions of interest 
anat_guide = pd.read_csv('/Users/christinamaher/Documents/GitHub/LFPAnalysis/LFPAnalysis/YBA_ROI_labelled.csv')
anat_guide['Custom'].unique() # custom labels for region of interest based on the YBA atlas

# periodic 
MS001_periodic_anat = pd.merge(MS001_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS003_periodic_anat = pd.merge(MS003_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS006_periodic_anat = pd.merge(MS006_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS007_periodic_anat = pd.merge(MS007_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS008_periodic_anat = pd.merge(MS008_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS010_periodic_anat = pd.merge(MS010_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS012_periodic_anat = pd.merge(MS012_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS014_periodic_anat = pd.merge(MS014_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS016_periodic_anat = pd.merge(MS016_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS017_periodic_anat = pd.merge(MS017_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS018_periodic_anat = pd.merge(MS018_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS019_periodic_anat = pd.merge(MS019_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS020_periodic_anat = pd.merge(MS020_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS022_periodic_anat = pd.merge(MS022_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS023_periodic_anat = pd.merge(MS023_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS024_periodic_anat = pd.merge(MS024_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS025_periodic_anat = pd.merge(MS025_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS026_periodic_anat = pd.merge(MS026_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS027_periodic_anat = pd.merge(MS027_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS028_periodic_anat = pd.merge(MS028_periodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')

# aperiodic
MS001_aperiodic_anat = pd.merge(MS001_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS003_aperiodic_anat = pd.merge(MS003_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS006_aperiodic_anat = pd.merge(MS006_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS007_aperiodic_anat = pd.merge(MS007_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS008_aperiodic_anat = pd.merge(MS008_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS010_aperiodic_anat = pd.merge(MS010_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS012_aperiodic_anat = pd.merge(MS012_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS014_aperiodic_anat = pd.merge(MS014_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS016_aperiodic_anat = pd.merge(MS016_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS017_aperiodic_anat = pd.merge(MS017_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS018_aperiodic_anat = pd.merge(MS018_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS019_aperiodic_anat = pd.merge(MS019_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS020_aperiodic_anat = pd.merge(MS020_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS022_aperiodic_anat = pd.merge(MS022_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS023_aperiodic_anat = pd.merge(MS023_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS024_aperiodic_anat = pd.merge(MS024_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS025_aperiodic_anat = pd.merge(MS025_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS026_aperiodic_anat = pd.merge(MS026_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS027_aperiodic_anat = pd.merge(MS027_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')
MS028_aperiodic_anat = pd.merge(MS028_aperiodic_anat, anat_guide, left_on='YBA_1', right_on='Long.name')

# %%
# assign peak frequencies to frequency bands
MS001_periodic_anat['freq_band'] = pd.cut(MS001_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS003_periodic_anat['freq_band'] = pd.cut(MS003_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS006_periodic_anat['freq_band'] = pd.cut(MS006_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS007_periodic_anat['freq_band'] = pd.cut(MS007_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS008_periodic_anat['freq_band'] = pd.cut(MS008_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS010_periodic_anat['freq_band'] = pd.cut(MS010_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS012_periodic_anat['freq_band'] = pd.cut(MS012_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS014_periodic_anat['freq_band'] = pd.cut(MS014_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS016_periodic_anat['freq_band'] = pd.cut(MS016_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS017_periodic_anat['freq_band'] = pd.cut(MS017_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS018_periodic_anat['freq_band'] = pd.cut(MS018_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS019_periodic_anat['freq_band'] = pd.cut(MS019_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS020_periodic_anat['freq_band'] = pd.cut(MS020_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS022_periodic_anat['freq_band'] = pd.cut(MS022_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS023_periodic_anat['freq_band'] = pd.cut(MS023_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS024_periodic_anat['freq_band'] = pd.cut(MS024_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS025_periodic_anat['freq_band'] = pd.cut(MS025_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS026_periodic_anat['freq_band'] = pd.cut(MS026_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS027_periodic_anat['freq_band'] = pd.cut(MS027_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])
MS028_periodic_anat['freq_band'] = pd.cut(MS028_periodic_anat['power'], [1, 4, 8, 13, 20, 30, 40], labels=['delta', 'theta', 'alpha', 'low_beta', 'high_beta', 'gamma'])

# %%
MS001_periodic_anat_max_power = MS001_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first'}).reset_index()
MS001_periodic_anat_max_power
# Out:
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/2157592984.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS001_periodic_anat_max_power = MS001_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first'}).reset_index()
#            ch_name  freq_band  center_freq Custom
# 0    lacas1-lacas2      delta          NaN    NaN
# 1    lacas1-lacas2      theta     0.483022    ACC
# 2    lacas1-lacas2      alpha     0.396839    ACC
# 3    lacas1-lacas2   low_beta     0.192703    ACC
# 4    lacas1-lacas2  high_beta     0.066048    ACC
# ..             ...        ...          ...    ...
# 235  rmtpt8-rmtpt9      theta     0.558615    STS
# 236  rmtpt8-rmtpt9      alpha          NaN    NaN
# 237  rmtpt8-rmtpt9   low_beta     0.327905    STS
# 238  rmtpt8-rmtpt9  high_beta          NaN    NaN
# 239  rmtpt8-rmtpt9      gamma     0.090139    STS
#
# [240 rows x 4 columns]

# %%
MS001_periodic_anat
# Out:
#        key_0          ch_name subject      power  center_freq  bandwidth  \
# 0     lacas1    lacas1-lacas2   MS001   6.239841     0.483022   2.279871
# 1     lacas1    lacas1-lacas2   MS001   9.016785     0.396839   2.172196
# 2     lacas1    lacas1-lacas2   MS001  12.878035     0.335320   5.182434
# 3     lacas1    lacas1-lacas2   MS001  19.335842     0.192703   6.000000
# 4     lacas1    lacas1-lacas2   MS001  26.307218     0.066048   4.289757
# ..       ...              ...     ...        ...          ...        ...
# 136  rmolf10  rmolf10-rmolf11   MS001  21.778350     0.207359   6.000000
# 137   rmtpt8    rmtpt8-rmtpt9   MS001   7.046195     0.558615   2.780525
# 138   rmtpt8    rmtpt8-rmtpt9   MS001  13.043819     0.327905   6.000000
# 139   rmtpt8    rmtpt8-rmtpt9   MS001  19.952035     0.131775   6.000000
# 140   rmtpt8    rmtpt8-rmtpt9   MS001  31.977416     0.090139   1.000000
#
#      freq_band               uniqueID    label BN246label  ...  Hemisphere  \
# 0        theta    lacas1-lacas2_MS001   lacas1    A32sg_L  ...        Left
# 1        alpha    lacas1-lacas2_MS001   lacas1    A32sg_L  ...        Left
# 2        alpha    lacas1-lacas2_MS001   lacas1    A32sg_L  ...        Left
# 3     low_beta    lacas1-lacas2_MS001   lacas1    A32sg_L  ...        Left
# 4    high_beta    lacas1-lacas2_MS001   lacas1    A32sg_L  ...        Left
# ..         ...                    ...      ...        ...  ...         ...
# 136  high_beta  rmolf10-rmolf11_MS001  rmolf10     A45r_R  ...       Right
# 137      theta    rmtpt8-rmtpt9_MS001   rmtpt8    A37dl_R  ...       Right
# 138   low_beta    rmtpt8-rmtpt9_MS001   rmtpt8    A37dl_R  ...       Right
# 139   low_beta    rmtpt8-rmtpt9_MS001   rmtpt8    A37dl_R  ...       Right
# 140      gamma    rmtpt8-rmtpt9_MS001   rmtpt8    A37dl_R  ...       Right
#
#           Lobe            Region                           Gyrus  Custom  \
# 0      Frontal         Cingulate                 Cingulate gyrus     ACC
# 1      Frontal         Cingulate                 Cingulate gyrus     ACC
# 2      Frontal         Cingulate                 Cingulate gyrus     ACC
# 3      Frontal         Cingulate                 Cingulate gyrus     ACC
# 4      Frontal         Cingulate                 Cingulate gyrus     ACC
# ..         ...               ...                             ...     ...
# 136   Frontal   Inferior frontal        Middle pars triangularis   vlPFC
# 137  Temporal      Temporal body  Superior middle temporal gyrus     STS
# 138  Temporal      Temporal body  Superior middle temporal gyrus     STS
# 139  Temporal      Temporal body  Superior middle temporal gyrus     STS
# 140  Temporal      Temporal body  Superior middle temporal gyrus     STS
#
#          Code        R        G        B  \
# 0       L_C_D  0.70980  0.27059  0.68235
# 1       L_C_D  0.70980  0.27059  0.68235
# 2       L_C_D  0.70980  0.27059  0.68235
# 3       L_C_D  0.70980  0.27059  0.68235
# 4       L_C_D  0.70980  0.27059  0.68235
# ..        ...      ...      ...      ...
# 136   R_TR2_B  1.00000  0.38039  0.55686
# 137  R_T2.1_F  0.52941  0.52941  1.00000
# 138  R_T2.1_F  0.52941  0.52941  1.00000
# 139  R_T2.1_F  0.52941  0.52941  1.00000
# 140  R_T2.1_F  0.52941  0.52941  1.00000
#
#                                   Long.name
# 0                    Left cingulate gyrus D
# 1                    Left cingulate gyrus D
# 2                    Left cingulate gyrus D
# 3                    Left cingulate gyrus D
# 4                    Left cingulate gyrus D
# ..                                      ...
# 136        Right middle pars triangularis B
# 137  Right superior middle temporal gyrus F
# 138  Right superior middle temporal gyrus F
# 139  Right superior middle temporal gyrus F
# 140  Right superior middle temporal gyrus F
#
# [141 rows x 35 columns]

# %%
# take the largest peak in each frequency band for each electrode 
MS001_periodic_anat_max_power = MS001_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS003_periodic_anat_max_power = MS003_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS006_periodic_anat_max_power = MS006_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS007_periodic_anat_max_power = MS007_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS008_periodic_anat_max_power = MS008_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS010_periodic_anat_max_power = MS010_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS012_periodic_anat_max_power = MS012_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS014_periodic_anat_max_power = MS014_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS016_periodic_anat_max_power = MS016_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS017_periodic_anat_max_power = MS017_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS018_periodic_anat_max_power = MS018_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS019_periodic_anat_max_power = MS019_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS020_periodic_anat_max_power = MS020_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS022_periodic_anat_max_power = MS022_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS023_periodic_anat_max_power = MS023_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS024_periodic_anat_max_power = MS024_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS025_periodic_anat_max_power = MS025_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS026_periodic_anat_max_power = MS026_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS027_periodic_anat_max_power = MS027_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
MS028_periodic_anat_max_power = MS028_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# Out:
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS001_periodic_anat_max_power = MS001_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS003_periodic_anat_max_power = MS003_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS006_periodic_anat_max_power = MS006_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS007_periodic_anat_max_power = MS007_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS008_periodic_anat_max_power = MS008_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS010_periodic_anat_max_power = MS010_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS012_periodic_anat_max_power = MS012_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS014_periodic_anat_max_power = MS014_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS016_periodic_anat_max_power = MS016_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS017_periodic_anat_max_power = MS017_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS018_periodic_anat_max_power = MS018_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS019_periodic_anat_max_power = MS019_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:14: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS020_periodic_anat_max_power = MS020_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS022_periodic_anat_max_power = MS022_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS023_periodic_anat_max_power = MS023_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:17: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS024_periodic_anat_max_power = MS024_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS025_periodic_anat_max_power = MS025_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:19: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS026_periodic_anat_max_power = MS026_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:20: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS027_periodic_anat_max_power = MS027_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/1209178462.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   MS028_periodic_anat_max_power = MS028_periodic_anat.groupby(['ch_name', 'freq_band']).agg({'center_freq': 'max', 'Custom': 'first', 'uniqueID': 'first'}).reset_index()

# %%
# merge all the periodic dataframes together
periodic_anat_max_power = pd.concat([MS001_periodic_anat_max_power, MS003_periodic_anat_max_power, MS006_periodic_anat_max_power, MS007_periodic_anat_max_power, MS008_periodic_anat_max_power, MS010_periodic_anat_max_power, MS012_periodic_anat_max_power, MS014_periodic_anat_max_power, MS016_periodic_anat_max_power, MS017_periodic_anat_max_power, MS018_periodic_anat_max_power, MS019_periodic_anat_max_power, MS020_periodic_anat_max_power, MS022_periodic_anat_max_power, MS023_periodic_anat_max_power, MS024_periodic_anat_max_power, MS025_periodic_anat_max_power, MS026_periodic_anat_max_power, MS027_periodic_anat_max_power, MS028_periodic_anat_max_power])

# merge all the aperiodic dataframes together
aperiodic_anat= pd.concat([MS001_aperiodic_anat, MS003_aperiodic_anat, MS006_aperiodic_anat, MS007_aperiodic_anat, MS008_aperiodic_anat, MS010_aperiodic_anat, MS012_aperiodic_anat, MS014_aperiodic_anat, MS016_aperiodic_anat, MS017_aperiodic_anat, MS018_aperiodic_anat, MS019_aperiodic_anat, MS020_aperiodic_anat, MS022_aperiodic_anat, MS023_aperiodic_anat, MS024_aperiodic_anat, MS025_aperiodic_anat, MS026_aperiodic_anat, MS027_aperiodic_anat, MS028_aperiodic_anat])

# %%
periodic_anat_max_power
# Out:
#            ch_name  freq_band  center_freq Custom             uniqueID
# 0    lacas1-lacas2      delta          NaN    NaN                  NaN
# 1    lacas1-lacas2      theta     0.483022    ACC  lacas1-lacas2_MS001
# 2    lacas1-lacas2      alpha     0.396839    ACC  lacas1-lacas2_MS001
# 3    lacas1-lacas2   low_beta     0.192703    ACC  lacas1-lacas2_MS001
# 4    lacas1-lacas2  high_beta     0.066048    ACC  lacas1-lacas2_MS001
# ..             ...        ...          ...    ...                  ...
# 331  rmolf8-rmolf9      theta     0.163933    OFC  rmolf8-rmolf9_MS028
# 332  rmolf8-rmolf9      alpha     0.268560    OFC  rmolf8-rmolf9_MS028
# 333  rmolf8-rmolf9   low_beta     0.442160    OFC  rmolf8-rmolf9_MS028
# 334  rmolf8-rmolf9  high_beta     0.310681    OFC  rmolf8-rmolf9_MS028
# 335  rmolf8-rmolf9      gamma          NaN    NaN                  NaN
#
# [5592 rows x 5 columns]

# %%
# NUMBER OF ELECS BY REGION 
# Get the counts of each value
value_counts = aperiodic_anat['Custom'].value_counts()

# Convert to DataFrame for better visualization
summary_table = pd.DataFrame({'Region': value_counts.index, 'Count': value_counts.values})

print(summary_table)
# Out:
#            Region  Count
# 0             ACC    150
# 1             OFC    118
# 2           dmPFC    105
# 3             HPC     89
# 4             AMY     69
# 5             STS     66
# 6            PINS     48
# 7            AINS     47
# 8           vmPFC     30
# 9           dlPFC     28
# 10          vlPFC     27
# 11       Temporal     19
# 12       Parietal     14
# 13  Temporal Pole     13
# 14            PHG     12
# 15            MCC     10
# 16          Motor      9
# 17            PCC      2

# %%
# Power by regions 

# power x delta x ROI
delta = periodic_anat_max_power[periodic_anat_max_power['freq_band'] == 'delta']
delta = delta.groupby(['Custom']).agg({'center_freq': 'mean'}).reset_index()
delta = delta.sort_values(by='center_freq')
plt.bar(delta['Custom'], delta['center_freq'])
plt.xticks(rotation=90)
plt.title('Delta')
plt.show()

# power x theta x ROI
theta = periodic_anat_max_power[periodic_anat_max_power['freq_band'] == 'theta']
theta = theta.groupby(['Custom']).agg({'center_freq': 'mean'}).reset_index()
theta = theta.sort_values(by='center_freq')
plt.bar(theta['Custom'], theta['center_freq'])
plt.xticks(rotation=90)
plt.title('Theta')
plt.show()

# power x alpha x ROI
alpha = periodic_anat_max_power[periodic_anat_max_power['freq_band'] == 'alpha']
alpha = alpha.groupby(['Custom']).agg({'center_freq': 'mean'}).reset_index()
alpha = alpha.sort_values(by='center_freq')
plt.bar(alpha['Custom'], alpha['center_freq'])
plt.xticks(rotation=90)
plt.title('Alpha')
plt.show()

# power x low_beta x ROI
low_beta = periodic_anat_max_power[periodic_anat_max_power['freq_band'] == 'low_beta']
low_beta = low_beta.groupby(['Custom']).agg({'center_freq': 'mean'}).reset_index()
low_beta = low_beta.sort_values(by='center_freq')
plt.bar(low_beta['Custom'], low_beta['center_freq'])
plt.xticks(rotation=90)
plt.title('Low Beta')
plt.show()

# power x high_beta x ROI
high_beta = periodic_anat_max_power[periodic_anat_max_power['freq_band'] == 'high_beta']
high_beta = high_beta.groupby(['Custom']).agg({'center_freq': 'mean'}).reset_index()
high_beta = high_beta.sort_values(by='center_freq')
plt.bar(high_beta['Custom'], high_beta['center_freq'])
plt.xticks(rotation=90)
plt.title('High Beta')
plt.show()

# power x gamma x ROI
gamma = periodic_anat_max_power[periodic_anat_max_power['freq_band'] == 'gamma']
gamma = gamma.groupby(['Custom']).agg({'center_freq': 'mean'}).reset_index()
gamma = gamma.sort_values(by='center_freq')
plt.bar(gamma['Custom'], gamma['center_freq'])
plt.xticks(rotation=90)
plt.title('Gamma')
plt.show()

# %%
aperiodic_anat
# Out:
#      key_0        ch_name subject  aperiodic_exponent  aperiodic_offset  \
# 0   lacas1  lacas1-lacas2   MS001            1.902561         -9.523506
# 1   lacas2  lacas2-lacas3   MS001            1.718432         -9.871483
# 2   lacas3  lacas3-lacas4   MS001            2.212105         -9.434933
# 3   lacas5  lacas5-lacas6   MS001            2.063630         -9.321145
# 4   lacas6  lacas6-lacas9   MS001            1.914939         -9.080106
# ..     ...            ...     ...                 ...               ...
# 52  rmolf2  rmolf2-rmolf3   MS028            1.568394         -9.844260
# 53  rmolf3  rmolf3-rmolf4   MS028            1.405343        -10.071610
# 54  rmolf4  rmolf4-rmolf5   MS028            1.385778         -9.943262
# 55  rmolf7  rmolf7-rmolf8   MS028            1.388918         -9.923873
# 56  rmolf8  rmolf8-rmolf9   MS028            1.209824        -10.135387
#
#        error       r^2             uniqueID   label BN246label  ...  \
# 0   0.025688  0.997362  lacas1-lacas2_MS001  lacas1    A32sg_L  ...
# 1   0.025966  0.996981  lacas2-lacas3_MS001  lacas2    A32sg_L  ...
# 2   0.035134  0.996862  lacas3-lacas4_MS001  lacas3    A32sg_L  ...
# 3   0.056359  0.990953  lacas5-lacas6_MS001  lacas5     A32p_L  ...
# 4   0.072627  0.985448  lacas6-lacas9_MS001  lacas6     A10m_L  ...
# ..       ...       ...                  ...     ...        ...  ...
# 52  0.026689  0.995358  rmolf2-rmolf3_MS028  rmolf2      A13_R  ...
# 53  0.025294  0.994886  rmolf3-rmolf4_MS028  rmolf3      A13_R  ...
# 54  0.029039  0.993540  rmolf4-rmolf5_MS028  rmolf4     A11l_R  ...
# 55  0.044146  0.982639  rmolf7-rmolf8_MS028  rmolf7  A12/47l_R  ...
# 56  0.041786  0.981451  rmolf8-rmolf9_MS028  rmolf8  A12/47l_R  ...
#
#                     Long.name  Note  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0      Left cingulate gyrus D   NaN          NaN          NaN          NaN
# 1      Left cingulate gyrus E   NaN          NaN          NaN          NaN
# 2      Left cingulate gyrus E   NaN          NaN          NaN          NaN
# 3       Left frontal pole 4 A   NaN          NaN          NaN          NaN
# 4       Left frontal pole 4 A   NaN          NaN          NaN          NaN
# ..                        ...   ...          ...          ...          ...
# 52  Right frontal orbital 5 A   NaN          NaN          NaN          NaN
# 53  Right frontal orbital 5 A   NaN          NaN          NaN          NaN
# 54  Right frontal orbital 5 C   NaN          NaN          NaN          NaN
# 55  Right frontal orbital 4 D   NaN          NaN          NaN          NaN
# 56  Right frontal orbital 4 D   NaN          NaN          NaN          NaN
#
#     Unnamed: 19 Unnamed: 20 Unnamed: 21 ManualExamination notes
# 0           NaN         NaN         NaN               NaN   NaN
# 1           NaN         NaN         NaN               NaN   NaN
# 2           NaN         NaN         NaN               NaN   NaN
# 3           NaN         NaN         NaN               NaN   NaN
# 4           NaN         NaN         NaN               NaN   NaN
# ..          ...         ...         ...               ...   ...
# 52          NaN         NaN         NaN               NaN   NaN
# 53          NaN         NaN         NaN               NaN   NaN
# 54          NaN         NaN         NaN               NaN   NaN
# 55          NaN         NaN         NaN               NaN   NaN
# 56          NaN         NaN         NaN               NaN   NaN
#
# [936 rows x 44 columns]

# %%
slope = aperiodic_anat.groupby(['Custom']).agg({'aperiodic_exponent': 'mean'}).reset_index()
slope = slope.sort_values(by='aperiodic_exponent')
plt.bar(slope['Custom'], slope['aperiodic_exponent'])
plt.xticks(rotation=90)
plt.title('slope')
plt.show()

# %%
offset = aperiodic_anat.groupby(['Custom']).agg({'aperiodic_offset': 'mean'}).reset_index()
offset = offset.sort_values(by='aperiodic_offset')
plt.bar(offset['Custom'], offset['aperiodic_offset'])
plt.xticks(rotation=90)
plt.title('offset')
plt.show()

# %%
           Region  Count
0             ACC    150
1             OFC    118
2           dmPFC    105
3             HPC     89
4             AMY     69
5             STS     66
6            PINS     48
7            AINS     47
8           vmPFC     30
9           dlPFC     28
10          vlPFC     27
11       Temporal     19
12       Parietal     14
13  Temporal Pole     13
14            PHG     12
15            MCC     10
16          Motor      9
17            PCC      2

# %%
# subset regions of interest for resting state and plot power by region
roi = ['ofc', 'amy','hpc','dlpfc','vlpfc','dmpfc','vmpfc','ins','acc']

# merge ains and pins labels
aperiodic_anat['Custom'] = aperiodic_anat['Custom'].replace({'AINS': 'INS', 'PINS': 'INS'})
periodic_anat_max_power['Custom'] = periodic_anat_max_power['Custom'].replace({'AINS': 'INS', 'PINS': 'INS'})

# %%
# for each region of interest, plot the power across frequency bands
for region in roi:
    region = region.upper()
    region_data = periodic_anat_max_power[periodic_anat_max_power['Custom'].str.upper() == region]
    region_data = region_data.groupby(['freq_band']).agg({'center_freq': 'mean'}).reset_index()
    plt.bar(region_data['freq_band'], region_data['center_freq'])
    plt.title(region)
    plt.show()
# Out:
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/3991213567.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   region_data = region_data.groupby(['freq_band']).agg({'center_freq': 'mean'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/3991213567.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   region_data = region_data.groupby(['freq_band']).agg({'center_freq': 'mean'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/3991213567.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   region_data = region_data.groupby(['freq_band']).agg({'center_freq': 'mean'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/3991213567.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   region_data = region_data.groupby(['freq_band']).agg({'center_freq': 'mean'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/3991213567.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   region_data = region_data.groupby(['freq_band']).agg({'center_freq': 'mean'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/3991213567.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   region_data = region_data.groupby(['freq_band']).agg({'center_freq': 'mean'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/3991213567.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   region_data = region_data.groupby(['freq_band']).agg({'center_freq': 'mean'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/3991213567.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   region_data = region_data.groupby(['freq_band']).agg({'center_freq': 'mean'}).reset_index()
# /var/folders/5p/bctklsps5kgb5fk5s1nygs3m0000gn/T/ipykernel_2305/3991213567.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   region_data = region_data.groupby(['freq_band']).agg({'center_freq': 'mean'}).reset_index()

# %%
roi_aperiodic = aperiodic_anat[aperiodic_anat['Custom'].str.lower().isin(roi)]
slope = roi_aperiodic.groupby(['Custom']).agg({'aperiodic_exponent': 'mean'}).reset_index()
slope = slope.sort_values(by='aperiodic_exponent')
plt.bar(slope['Custom'], slope['aperiodic_exponent'])
plt.xticks(rotation=90)
plt.title('slope')
plt.show()

# %%
roi_aperiodic = aperiodic_anat[aperiodic_anat['Custom'].str.lower().isin(roi)]
slope = roi_aperiodic.groupby(['Custom']).agg({'aperiodic_offset': 'mean'}).reset_index()
slope = slope.sort_values(by='aperiodic_offset')
plt.bar(slope['Custom'], slope['aperiodic_offset'])
plt.xticks(rotation=90)
plt.title('offset')
plt.show()
