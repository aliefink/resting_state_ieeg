# %% [markdown]
# # Preprocess Continuous Data - Resting State
# ## MS018
#
# 02/26/2024

# %%
import numpy as np
import mne
from glob import glob
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from scipy.stats import zscore, linregress, ttest_ind, ttest_rel, ttest_1samp
import pandas as pd
from mne.preprocessing.bads import _find_outliers
import os 
import joblib
import emd
import re

import warnings
warnings.filterwarnings('ignore')
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
import sys
sys.path.append('/Users/alexandrafink/Documents/GitHub/LFPAnalysis')

# %%
from LFPAnalysis import lfp_preprocess_utils, sync_utils, analysis_utils, nlx_utils

# %%
subj_id = 'MS018'

# Specify root directory for data and results 
base_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/resting_state_proj/resting_state_ieeg/'
anat_dir = f'{base_dir}anat'
neural_dir = f'{base_dir}preprocess/raw_data/{subj_id}'
save_dir = f'{base_dir}preprocess/clean_data/{subj_id}'
os.makedirs(save_dir,exist_ok = True)

# %% [markdown]
# #### Import Data

# %%
edf_files = glob(f'{neural_dir}/*.edf')

mne_data = mne.io.read_raw_edf(edf_files[0], preload=True)
mne_data
# Out:
# <RawEDF | MS018_Resting_iEEG.edf, 276 x 631040 (616.2 s), ~1.30 GB, data loaded>

# %%
mne_data.ch_names
# Out:
# ['LmOlF1',
#  'LmOlF2',
#  'LmOlF3',
#  'LmOlF4',
#  'LmOlF5',
#  'LmOlF6',
#  'LmOlF7',
#  'LmOlF8',
#  'LmOlF9',
#  'RmOlF1',
#  'RmOlF2',
#  'RmOlF3',
#  'RmOlF4',
#  'RmOlF5',
#  'RmOlF6',
#  'RmOlF7',
#  'RmOlF8',
#  'RmOlF9',
#  'LaCaS1',
#  'LaCaS2',
#  'LaCaS3',
#  'LaCaS4',
#  'LaCaS5',
#  'LaCaS6',
#  'LaCaS7',
#  'LaCaS8',
#  'LaCaS9',
#  'LaCaS10',
#  'RaCaS1',
#  'RaCaS2',
#  'RaCaS3',
#  'RaCaS4',
#  'RaCaS5',
#  'RaCaS6',
#  'RaCaS7',
#  'RaCaS8',
#  'RaCaS9',
#  'RaCaS10',
#  'RaCaS11',
#  'RaCaS12',
#  'LmCmS1',
#  'LmCmS2',
#  'LmCmS3',
#  'LmCmS4',
#  'LmCmS5',
#  'LmCmS6',
#  'LmCmS7',
#  'LmCmS8',
#  'LmCmS9',
#  'LmCmS10',
#  'RmCmS1',
#  'RmCmS2',
#  'RmCmS3',
#  'RmCmS4',
#  'RmCmS5',
#  'RmCmS6',
#  'RmCmS7',
#  'RmCmS8',
#  'C59',
#  'C60',
#  'C61',
#  'C62',
#  'C63',
#  'C64',
#  'LAglT1',
#  'LAglT2',
#  'LAglT3',
#  'LAglT4',
#  'LAglT5',
#  'LAglT6',
#  'LAglT7',
#  'LAglT8',
#  'LAglT9',
#  'RAglT1',
#  'RAglT2',
#  'RAglT3',
#  'RAglT4',
#  'RAglT5',
#  'RAglT6',
#  'RAglT7',
#  'RAglT8',
#  'RAglT9',
#  'LHplT1',
#  'LHplT2',
#  'LHplT3',
#  'LHplT4',
#  'LHplT5',
#  'LHplT6',
#  'LHplT7',
#  'LHplT8',
#  'LHplT9',
#  'LHplT10',
#  'RHplT1',
#  'RHplT2',
#  'RHplT3',
#  'RHplT4',
#  'RHplT5',
#  'RHplT6',
#  'RHplT7',
#  'RHplT8',
#  'RHplT9',
#  'RHplT10',
#  'LalsF1',
#  'LalsF2',
#  'LalsF3',
#  'LalsF4',
#  'LalsF5',
#  'LalsF6',
#  'LalsF7',
#  'LalsF8',
#  'LalsF9',
#  'LalsF10',
#  'LalsF11',
#  'LalsF12',
#  'LalsF13',
#  'LalsF14',
#  'LalsF15',
#  'LalsF16',
#  'C119',
#  'C120',
#  'C121',
#  'C122',
#  'C123',
#  'C124',
#  'C125',
#  'C126',
#  'C127',
#  'C128',
#  'RalsF1',
#  'RalsF2',
#  'RalsF3',
#  'RalsF4',
#  'RalsF5',
#  'RalsF6',
#  'RalsF7',
#  'RalsF8',
#  'RalsF9',
#  'RalsF10',
#  'RalsF11',
#  'RalsF12',
#  'RalsF13',
#  'RalsF14',
#  'RalsF15',
#  'RalsF16',
#  'RplS11',
#  'RplS12',
#  'RplS13',
#  'RplS14',
#  'RplS15',
#  'RplS16',
#  'RplS17',
#  'RplS18',
#  'RplS19',
#  'RplS110',
#  'RplS111',
#  'RplS112',
#  'LplS11',
#  'LplS12',
#  'LplS13',
#  'LplS14',
#  'LplS15',
#  'LplS16',
#  'LplS17',
#  'LplS18',
#  'LplS19',
#  'LplS110',
#  'LplS111',
#  'LplS112',
#  'LplS113',
#  'LplS114',
#  'LCMiP1',
#  'LCMiP2',
#  'LCMiP3',
#  'LCMiP4',
#  'LCMiP5',
#  'LCMiP6',
#  'LCMiP7',
#  'LCMiP8',
#  'LCMiP9',
#  'LCMiP10',
#  'LCMiP11',
#  'LCMiP12',
#  'LCMiP13',
#  'LCMiP14',
#  'C185',
#  'C186',
#  'C187',
#  'C188',
#  'C189',
#  'C190',
#  'C191',
#  'C192',
#  'RCMiP1',
#  'RCMiP2',
#  'RCMiP3',
#  'RCMiP4',
#  'RCMiP5',
#  'RCMiP6',
#  'RCMiP7',
#  'RCMiP8',
#  'RCMiP9',
#  'RCMiP10',
#  'RCMiP11',
#  'RCMiP12',
#  'RCMiP13',
#  'RCMiP14',
#  'Fp1',
#  'F7',
#  'T3',
#  'T5',
#  'O1',
#  'F3',
#  'C3',
#  'P3',
#  'Fp2',
#  'F8',
#  'T4',
#  'T6',
#  'O2',
#  'F4',
#  'C4',
#  'P4',
#  'Fz',
#  'Cz',
#  'Pz',
#  'EKG1',
#  'EKG2',
#  'C228',
#  'C229',
#  'C230',
#  'C231',
#  'C232',
#  'C233',
#  'C234',
#  'C235',
#  'C236',
#  'C237',
#  'C238',
#  'C239',
#  'C240',
#  'C241',
#  'C242',
#  'C243',
#  'C244',
#  'C245',
#  'C246',
#  'C247',
#  'C248',
#  'C249',
#  'C250',
#  'C251',
#  'C252',
#  'C253',
#  'C254',
#  'C255',
#  'C256',
#  'Research',
#  'DC2',
#  'DC3',
#  'DC4',
#  'DC5',
#  'DC6',
#  'DC7',
#  'DC8',
#  'DC9',
#  'DC10',
#  'DC11',
#  'DC12',
#  'DC13',
#  'DC14',
#  'DC15',
#  'DC16',
#  'TRIG',
#  'OSAT',
#  'PR',
#  'Pleth']

# %% [markdown]
# # Import Anat Recon Info - check all elecs are present in data + recon sheet

# %%
# Load the electrode localization data
anat_file = glob(f'{anat_dir}/{subj_id}_labels.csv')[0]
elec_locs = pd.read_csv(anat_file)
# Sometimes there's extra columns with no entries: 
elec_locs = elec_locs[elec_locs.columns.drop(list(elec_locs.filter(regex='Unnamed')))]
elec_locs = elec_locs.dropna(axis=0, how = 'all')
elec_locs
# Out:
#        label BN246label          x          y          z      mni_x  \
# 0     LaCaS1    A32sg_L  -5.191163  49.370031   6.599996  -6.001400
# 1     LaCaS2    A32sg_L  -5.989805  52.168332  10.599996  -6.763325
# 2     LaCaS3    A32sg_L  -6.389126  54.966633  14.599995  -7.045588
# 3     LaCaS4    A32sg_L  -7.187768  57.764934  18.599995  -7.908159
# 4     LaCaS5     A10m_L  -7.986409  60.563235  22.599995  -8.693478
# ..       ...        ...        ...        ...        ...        ...
# 181  RpIS112    Unknown  35.539562 -34.179237  72.199992  45.397519
# 182   uLAglT    rHipp_L -16.372147   8.594790 -13.000003 -18.226673
# 183   uLmOlF     A11m_L  -6.788447  48.170759 -13.400003  -7.358504
# 184   uRAglT    rHipp_R  13.976237   6.995761 -15.800003  17.141796
# 185   uRmOlF      A13_R   5.590499  36.178041  -5.800003   6.893072
#
#          mni_y      mni_z       gm  \
# 0    36.336286  -2.597083     Gray
# 1    39.497124   1.356690     Gray
# 2    42.755355   5.353050     Gray
# 3    45.967553   9.362542     Gray
# 4    49.173177  13.406068     Gray
# ..         ...        ...      ...
# 181 -35.816711  84.571360  Unknown
# 182  -6.104086 -19.641039     Gray
# 183  33.495630 -25.317349     Gray
# 184  -6.783901 -23.851153     Gray
# 185  22.751382 -14.385308     Gray
#
#                                                  NMM           Anat  \
# 0                 Left ACgG anterior cingulate gyrus        Unknown
# 1                 Left ACgG anterior cingulate gyrus        Unknown
# 2                 Left ACgG anterior cingulate gyrus        Unknown
# 3                 Left ACgG anterior cingulate gyrus        Unknown
# 4    Left MSFG superior frontal gyrus medial segment        Unknown
# ..                                               ...            ...
# 181                                          Unknown        Unknown
# 182                                    Left Amygdala  Amygdala (SF)
# 183                            Left GRe gyrus rectus       Area Fo1
# 184                                Right Hippocampus      Subiculum
# 185                  Right MFC medial frontal cortex       Area s24
#
#                     AnatMacro    BN246                     YBA_1  \
# 0                       L ACC     L CG    Left cingulate gyrus D
# 1                       L ACC     L CG    Left cingulate gyrus E
# 2                       L ACC     L CG    Left cingulate gyrus E
# 3                       L ACC     L CG    Left cingulate gyrus F
# 4     L Superior Medial Gyrus    L SFG     Left frontal pole 4 A
# ..                        ...      ...                       ...
# 181                   Unknown  Unknown                   Unknown
# 182             L Hippocampus   L Hipp    Left amygdala superior
# 183  L Superior Orbital Gyrus    L OrG  Left frontal orbital 4 A
# 184   R ParaHippocampal Gyrus   R Hipp     Right hippocampus pes
# 185            R Rectal Gyrus    R OrG    Right frontal pole 1 A
#
#     Manual Examination Notes
# 0                  NaN   NaN
# 1                  NaN   NaN
# 2                  NaN   NaN
# 3                   WM   NaN
# 4                  NaN   NaN
# ..                 ...   ...
# 181                OOB   NaN
# 182                NaN   NaN
# 183                NaN   NaN
# 184                NaN   NaN
# 185                NaN   NaN
#
# [186 rows x 16 columns]

# %% [markdown]
# ### Fix edf channel names

# %%
new_mne_names, unmatched_names, unmatched_seeg = lfp_preprocess_utils.match_elec_names(mne_data.ch_names, elec_locs.label)
# Out:
# Number of electrodes in the mne file is greater than the number of electrodes in the localization file

# %%
unmatched_names
# Out:
# ['uraglt', 'ulmolf', 'ulaglt', 'urmolf']

# %%
unmatched_seeg
# Out:
# []

# %%
new_name_dict = {x:y for (x,y) in zip(mne_data.ch_names, new_mne_names)}
new_name_dict
# Out:
# {'LmOlF1': 'lmolf1',
#  'LmOlF2': 'lmolf2',
#  'LmOlF3': 'lmolf3',
#  'LmOlF4': 'lmolf4',
#  'LmOlF5': 'lmolf5',
#  'LmOlF6': 'lmolf6',
#  'LmOlF7': 'lmolf7',
#  'LmOlF8': 'lmolf8',
#  'LmOlF9': 'lmolf9',
#  'RmOlF1': 'rmolf1',
#  'RmOlF2': 'rmolf2',
#  'RmOlF3': 'rmolf3',
#  'RmOlF4': 'rmolf4',
#  'RmOlF5': 'rmolf5',
#  'RmOlF6': 'rmolf6',
#  'RmOlF7': 'rmolf7',
#  'RmOlF8': 'rmolf8',
#  'RmOlF9': 'rmolf9',
#  'LaCaS1': 'lacas1',
#  'LaCaS2': 'lacas2',
#  'LaCaS3': 'lacas3',
#  'LaCaS4': 'lacas4',
#  'LaCaS5': 'lacas5',
#  'LaCaS6': 'lacas6',
#  'LaCaS7': 'lacas7',
#  'LaCaS8': 'lacas8',
#  'LaCaS9': 'lacas9',
#  'LaCaS10': 'lacas10',
#  'RaCaS1': 'racas1',
#  'RaCaS2': 'racas2',
#  'RaCaS3': 'racas3',
#  'RaCaS4': 'racas4',
#  'RaCaS5': 'racas5',
#  'RaCaS6': 'racas6',
#  'RaCaS7': 'racas7',
#  'RaCaS8': 'racas8',
#  'RaCaS9': 'racas9',
#  'RaCaS10': 'racas10',
#  'RaCaS11': 'racas11',
#  'RaCaS12': 'racas12',
#  'LmCmS1': 'lmcms1',
#  'LmCmS2': 'lmcms2',
#  'LmCmS3': 'lmcms3',
#  'LmCmS4': 'lmcms4',
#  'LmCmS5': 'lmcms5',
#  'LmCmS6': 'lmcms6',
#  'LmCmS7': 'lmcms7',
#  'LmCmS8': 'lmcms8',
#  'LmCmS9': 'lmcms9',
#  'LmCmS10': 'lmcms10',
#  'RmCmS1': 'rmcms1',
#  'RmCmS2': 'rmcms2',
#  'RmCmS3': 'rmcms3',
#  'RmCmS4': 'rmcms4',
#  'RmCmS5': 'rmcms5',
#  'RmCmS6': 'rmcms6',
#  'RmCmS7': 'rmcms7',
#  'RmCmS8': 'rmcms8',
#  'C59': 'c59',
#  'C60': 'c60',
#  'C61': 'c61',
#  'C62': 'c62',
#  'C63': 'c63',
#  'C64': 'c64',
#  'LAglT1': 'laglt1',
#  'LAglT2': 'laglt2',
#  'LAglT3': 'laglt3',
#  'LAglT4': 'laglt4',
#  'LAglT5': 'laglt5',
#  'LAglT6': 'laglt6',
#  'LAglT7': 'laglt7',
#  'LAglT8': 'laglt8',
#  'LAglT9': 'laglt9',
#  'RAglT1': 'raglt1',
#  'RAglT2': 'raglt2',
#  'RAglT3': 'raglt3',
#  'RAglT4': 'raglt4',
#  'RAglT5': 'raglt5',
#  'RAglT6': 'raglt6',
#  'RAglT7': 'raglt7',
#  'RAglT8': 'raglt8',
#  'RAglT9': 'raglt9',
#  'LHplT1': 'lhplt1',
#  'LHplT2': 'lhplt2',
#  'LHplT3': 'lhplt3',
#  'LHplT4': 'lhplt4',
#  'LHplT5': 'lhplt5',
#  'LHplT6': 'lhplt6',
#  'LHplT7': 'lhplt7',
#  'LHplT8': 'lhplt8',
#  'LHplT9': 'lhplt9',
#  'LHplT10': 'lhplt10',
#  'RHplT1': 'rhplt1',
#  'RHplT2': 'rhplt2',
#  'RHplT3': 'rhplt3',
#  'RHplT4': 'rhplt4',
#  'RHplT5': 'rhplt5',
#  'RHplT6': 'rhplt6',
#  'RHplT7': 'rhplt7',
#  'RHplT8': 'rhplt8',
#  'RHplT9': 'rhplt9',
#  'RHplT10': 'rhplt10',
#  'LalsF1': 'laisf1',
#  'LalsF2': 'laisf2',
#  'LalsF3': 'laisf3',
#  'LalsF4': 'laisf4',
#  'LalsF5': 'laisf5',
#  'LalsF6': 'laisf6',
#  'LalsF7': 'laisf7',
#  'LalsF8': 'laisf8',
#  'LalsF9': 'laisf9',
#  'LalsF10': 'laisf10',
#  'LalsF11': 'laisf11',
#  'LalsF12': 'laisf12',
#  'LalsF13': 'laisf13',
#  'LalsF14': 'laisf14',
#  'LalsF15': 'laisf15',
#  'LalsF16': 'laisf16',
#  'C119': 'c119',
#  'C120': 'c120',
#  'C121': 'c121',
#  'C122': 'c122',
#  'C123': 'c123',
#  'C124': 'c124',
#  'C125': 'c125',
#  'C126': 'c126',
#  'C127': 'c127',
#  'C128': 'c128',
#  'RalsF1': 'raisf1',
#  'RalsF2': 'raisf2',
#  'RalsF3': 'raisf3',
#  'RalsF4': 'raisf4',
#  'RalsF5': 'raisf5',
#  'RalsF6': 'raisf6',
#  'RalsF7': 'raisf7',
#  'RalsF8': 'raisf8',
#  'RalsF9': 'raisf9',
#  'RalsF10': 'raisf10',
#  'RalsF11': 'raisf11',
#  'RalsF12': 'raisf12',
#  'RalsF13': 'raisf13',
#  'RalsF14': 'raisf14',
#  'RalsF15': 'raisf15',
#  'RalsF16': 'raisf16',
#  'RplS11': 'rpis101',
#  'RplS12': 'rpis102',
#  'RplS13': 'rpis103',
#  'RplS14': 'rpis104',
#  'RplS15': 'rpis105',
#  'RplS16': 'rpis106',
#  'RplS17': 'rpis107',
#  'RplS18': 'rpis108',
#  'RplS19': 'rpis109',
#  'RplS110': 'rpis110',
#  'RplS111': 'rpis111',
#  'RplS112': 'rpis112',
#  'LplS11': 'lpis101',
#  'LplS12': 'lpis102',
#  'LplS13': 'lpis103',
#  'LplS14': 'lpis104',
#  'LplS15': 'lpis105',
#  'LplS16': 'lpis106',
#  'LplS17': 'lpis107',
#  'LplS18': 'lpis108',
#  'LplS19': 'lpis109',
#  'LplS110': 'lpis110',
#  'LplS111': 'lpis111',
#  'LplS112': 'lpis112',
#  'LplS113': 'lpis113',
#  'LplS114': 'lpis114',
#  'LCMiP1': 'lcmip1',
#  'LCMiP2': 'lcmip2',
#  'LCMiP3': 'lcmip3',
#  'LCMiP4': 'lcmip4',
#  'LCMiP5': 'lcmip5',
#  'LCMiP6': 'lcmip6',
#  'LCMiP7': 'lcmip7',
#  'LCMiP8': 'lcmip8',
#  'LCMiP9': 'lcmip9',
#  'LCMiP10': 'lcmip10',
#  'LCMiP11': 'lcmip11',
#  'LCMiP12': 'lcmip12',
#  'LCMiP13': 'lcmip13',
#  'LCMiP14': 'lcmip14',
#  'C185': 'c185',
#  'C186': 'c186',
#  'C187': 'c187',
#  'C188': 'c188',
#  'C189': 'c189',
#  'C190': 'c190',
#  'C191': 'c191',
#  'C192': 'c192',
#  'RCMiP1': 'rcmip1',
#  'RCMiP2': 'rcmip2',
#  'RCMiP3': 'rcmip3',
#  'RCMiP4': 'rcmip4',
#  'RCMiP5': 'rcmip5',
#  'RCMiP6': 'rcmip6',
#  'RCMiP7': 'rcmip7',
#  'RCMiP8': 'rcmip8',
#  'RCMiP9': 'rcmip9',
#  'RCMiP10': 'rcmip10',
#  'RCMiP11': 'rcmip11',
#  'RCMiP12': 'rcmip12',
#  'RCMiP13': 'rcmip13',
#  'RCMiP14': 'rcmip14',
#  'Fp1': 'fp1',
#  'F7': 'f7',
#  'T3': 't3',
#  'T5': 't5',
#  'O1': 'o1',
#  'F3': 'f3',
#  'C3': 'c3',
#  'P3': 'p3',
#  'Fp2': 'fp2',
#  'F8': 'f8',
#  'T4': 't4',
#  'T6': 't6',
#  'O2': 'o2',
#  'F4': 'f4',
#  'C4': 'c4',
#  'P4': 'p4',
#  'Fz': 'fz',
#  'Cz': 'cz',
#  'Pz': 'pz',
#  'EKG1': 'ekg1',
#  'EKG2': 'ekg2',
#  'C228': 'c228',
#  'C229': 'c229',
#  'C230': 'c230',
#  'C231': 'c231',
#  'C232': 'c232',
#  'C233': 'c233',
#  'C234': 'c234',
#  'C235': 'c235',
#  'C236': 'c236',
#  'C237': 'c237',
#  'C238': 'c238',
#  'C239': 'c239',
#  'C240': 'c240',
#  'C241': 'c241',
#  'C242': 'c242',
#  'C243': 'c243',
#  'C244': 'c244',
#  'C245': 'c245',
#  'C246': 'c246',
#  'C247': 'c247',
#  'C248': 'c248',
#  'C249': 'c249',
#  'C250': 'c250',
#  'C251': 'c251',
#  'C252': 'c252',
#  'C253': 'c253',
#  'C254': 'c254',
#  'C255': 'c255',
#  'C256': 'c256',
#  'Research': 'research',
#  'DC2': 'dc2',
#  'DC3': 'dc3',
#  'DC4': 'dc4',
#  'DC5': 'dc5',
#  'DC6': 'dc6',
#  'DC7': 'dc7',
#  'DC8': 'dc8',
#  'DC9': 'dc9',
#  'DC10': 'dc10',
#  'DC11': 'dc11',
#  'DC12': 'dc12',
#  'DC13': 'dc13',
#  'DC14': 'dc14',
#  'DC15': 'dc15',
#  'DC16': 'dc16',
#  'TRIG': 'trig',
#  'OSAT': 'osat',
#  'PR': 'pr',
#  'Pleth': 'pleth'}

# %%
# Rename the mne data according to the localization data
mne_data.rename_channels(new_name_dict)
# Out:
# <RawEDF | MS018_Resting_iEEG.edf, 276 x 631040 (616.2 s), ~1.30 GB, data loaded>

# %%
unmatched_seeg #make sure there are no unmatched names
# Out:
# []

# %%
anat_names = list(elec_locs.label.str.lower())
sum([ch not in mne_data.ch_names for ch in anat_names]) #if there are no missing channels, sum = 0. if sum >0, find the missing elecs
print([ch for ch in mne_data.ch_names if ch not in anat_names ]) 
#print extra channels in mne_data.ch_names and make sure none of them are neural channels
# Out:
# ['c59', 'c60', 'c61', 'c62', 'c63', 'c64', 'c119', 'c120', 'c121', 'c122', 'c123', 'c124', 'c125', 'c126', 'c127', 'c128', 'c185', 'c186', 'c187', 'c188', 'c189', 'c190', 'c191', 'c192', 'fp1', 'f7', 't3', 't5', 'o1', 'f3', 'c3', 'p3', 'fp2', 'f8', 't4', 't6', 'o2', 'f4', 'c4', 'p4', 'fz', 'cz', 'pz', 'ekg1', 'ekg2', 'c228', 'c229', 'c230', 'c231', 'c232', 'c233', 'c234', 'c235', 'c236', 'c237', 'c238', 'c239', 'c240', 'c241', 'c242', 'c243', 'c244', 'c245', 'c246', 'c247', 'c248', 'c249', 'c250', 'c251', 'c252', 'c253', 'c254', 'c255', 'c256', 'research', 'dc2', 'dc3', 'dc4', 'dc5', 'dc6', 'dc7', 'dc8', 'dc9', 'dc10', 'dc11', 'dc12', 'dc13', 'dc14', 'dc15', 'dc16', 'trig', 'osat', 'pr', 'pleth']

# %%
# Note, there is surface EEG data that we should separately indicate from the sEEG:
right_seeg_names = [i for i in mne_data.ch_names if i.startswith('r')]
left_seeg_names = [i for i in mne_data.ch_names if i.startswith('l')]
print(f'We have a total of', len(left_seeg_names), 'left &', len(right_seeg_names), 'right sEEG electrodes')
print(f'We have a total of {len(left_seeg_names) + len(right_seeg_names)} sEEG electrodes')
# Out:
# We have a total of 92 left & 91 right sEEG electrodes
# We have a total of 183 sEEG electrodes

# %%
drop_chans = list(set(mne_data.ch_names)^set(left_seeg_names+right_seeg_names)) # it is either called DC1 or research
mne_data.drop_channels(drop_chans) #number of chans should = number of seegs
# Out:
# <RawEDF | MS018_Resting_iEEG.edf, 183 x 631040 (616.2 s), ~881.2 MB, data loaded>

# %%
# Set channel types:
sEEG_mapping_dict = {f'{x}':'seeg' for x in left_seeg_names+right_seeg_names}
mne_data.set_channel_types(sEEG_mapping_dict)
# Out:
# <RawEDF | MS018_Resting_iEEG.edf, 183 x 631040 (616.2 s), ~881.2 MB, data loaded>

# %%
mne_data.drop_channels(['research'])
# Out:
# <RawEDF | MS018_Resting_iEEG.edf, 182 x 631040 (616.2 s), ~876.4 MB, data loaded>

# %%
# make montage (convert mm to m)

montage = mne.channels.make_dig_montage(ch_pos=dict(zip(elec_locs.label, 
                                                        elec_locs[['mni_x', 'mni_y', 'mni_z']].to_numpy(dtype=float)/1000)),
                                        coord_frame='mni_tal')

mne_data.set_montage(montage, match_case=False, on_missing='warn')
# Out:
# <RawEDF | MS018_Resting_iEEG.edf, 182 x 631040 (616.2 s), ~876.5 MB, data loaded>

# %% [markdown]
# ### Notch filter line noise

# %%
# Identify line noise
mne_data.info['line_freq'] = 60

# Notch out 60 Hz noise and harmonics 
mne_data.notch_filter(freqs=(60, 120, 180, 240))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 182 out of 182 | elapsed:    2.6s finished
# <RawEDF | MS018_Resting_iEEG.edf, 182 x 631040 (616.2 s), ~876.5 MB, data loaded>

# %% [markdown]
# ### Resampling data

# %%
resample_sr = 500
mne_data.resample(sfreq=resample_sr, npad='auto', n_jobs=-1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 182 out of 182 | elapsed:    3.8s finished
# <RawEDF | MS018_Resting_iEEG.edf, 182 x 308125 (616.2 s), ~428.1 MB, data loaded>

# %% [markdown]
# ### Bad Channel Removal (manual)

# %% [markdown]
# Let's pick out any bad channels missed by automatic screening (visual inspection as a reference), or restore channels that were erroneously deemed bad. You have to press the "power" button twice (once for the plot and once for the panel beneath it) when you're done so that you're manual changes are saved.

# %%
# mne_data = mne.io.read_raw_fif(f'{save_dir}/{subj_id}_raw_ieeg.fif', preload=True)

# %%
# %matplotlib notebook


fig = mne_data.plot(start=0, duration=120, n_channels=50, scalings=mne_data._data.max()/5)
fig.fake_keypress('a') #lots of bad times
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
mne_data.info['bads'] #sanity check that bads info saved
# Out:
# ['lacas8',
#  'rpis112',
#  'lpis102',
#  'lpis114',
#  'lacas10',
#  'racas7',
#  'racas8',
#  'racas11',
#  'racas12',
#  'raisf1',
#  'raisf13']

# %% [markdown]
# ## Save raw LFP data
# Notch filtered and resampled with bad elecs indicated

# %%
mne_data.save(f'{save_dir}/{subj_id}_raw_ieeg.fif',overwrite=True)

# %% [markdown]
# # Rereference data

# %% [markdown]
# To start annotating, press 'Add new label' in the bottom panel. Then left click and drag around window of interest.

# %%
# Re-reference neural data
anat_file = glob(f'{anat_dir}/{subj_id}_labels.csv')[0]

mne_data_bp_reref = lfp_preprocess_utils.ref_mne(mne_data=mne_data, 
                                              elec_path=anat_file, 
                                              method='bipolar', 
                                              site='MSSM')
# Out:
# Number of electrodes in the mne file is less than the number of electrodes in the localization file

# %%
# %matplotlib notebook

fig = mne_data_bp_reref.plot(start=2, duration=100, n_channels=50,scalings=mne_data._data.max()/5 ) # plot all channels at once
fig.fake_keypress("a")
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
mne_data_bp_reref.compute_psd().plot()
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
# <img src="data:image/png;base64,..." width="999.999985098839">

# %% [markdown]
# ### Save reref data

# %%
mne_data_bp_reref.save(f'{save_dir}/{subj_id}_bp_ref_ieeg.fif',overwrite=True)
