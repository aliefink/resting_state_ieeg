# %% [markdown]
# # Preprocess Continuous Data - Resting State
# ## MS014
#
# 10/03/2023

# %%
import numpy as np
import mne
from glob import glob
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from scipy.stats import zscore, linregress, ttest_ind, ttest_rel, ttest_1samp
import pandas as pd
from mne.preprocessing.bads import _find_outliers
import os 
import joblib
import emd
import re

import warnings
warnings.filterwarnings('ignore')
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
import sys
sys.path.append('/Users/alexandrafink/Documents/GitHub/LFPAnalysis')

# %%
from LFPAnalysis import lfp_preprocess_utils, sync_utils, analysis_utils, nlx_utils

# %%
subj_id = 'MS014'

# Specify root directory for data and results 
base_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/resting_state_proj/resting_state_ieeg/'
anat_dir = f'{base_dir}anat'
neural_dir = f'{base_dir}preprocess/raw_data/{subj_id}'
save_dir = f'{base_dir}preprocess/clean_data/{subj_id}'
os.makedirs(save_dir,exist_ok = True)

# %% [markdown]
# #### Import Data

# %%
edf_files = glob(f'{neural_dir}/*.edf')

mne_data = mne.io.read_raw_edf(edf_files[0], preload=True)
mne_data
# Out:
# <RawEDF | MS014_Resting_iEEG.edf, 148 x 616064 (601.6 s), ~695.8 MB, data loaded>

# %%
mne_data.ch_names
# Out:
# ['RmOlF1',
#  'RmOlF2',
#  'RmOlF3',
#  'RmOlF4',
#  'RmOlF5',
#  'RmOlF6',
#  'RmOlF7',
#  'RmOlF8',
#  'RmOlF9',
#  'RaCaS1',
#  'RaCaS2',
#  'RaCaS3',
#  'RaCaS4',
#  'RaCaS5',
#  'RaCaS6',
#  'RaCaS7',
#  'RaCaS8',
#  'RaCaS9',
#  'RaCaS10',
#  'RaCaS11',
#  'RaCaS12',
#  'RaCaS13',
#  'RaCaS14',
#  'RmCmS1',
#  'RmCmS2',
#  'RmCmS3',
#  'RmCmS4',
#  'RmCmS5',
#  'RmCmS6',
#  'RmCmS7',
#  'RmCmS8',
#  'RmCmS9',
#  'RmCmS10',
#  'RalpS1',
#  'RalpS2',
#  'RalpS3',
#  'RalpS4',
#  'RalpS5',
#  'RalpS6',
#  'RalpS7',
#  'RalpS8',
#  'RalpS9',
#  'RalpS10',
#  'RalpS11',
#  'RalpS12',
#  'RalpS13',
#  'RalpS14',
#  'RalpS15',
#  'RalpS16',
#  'Rsl1',
#  'Rsl2',
#  'Rsl3',
#  'Rsl4',
#  'Rsl5',
#  'Rsl6',
#  'Rsl7',
#  'Rsl8',
#  'C58',
#  'C59',
#  'C60',
#  'C61',
#  'C62',
#  'C63',
#  'C64',
#  'RAglT1',
#  'RAglT2',
#  'RAglT3',
#  'RAglT4',
#  'RAglT5',
#  'RAglT6',
#  'RAglT7',
#  'RAglT8',
#  'RAglT9',
#  'RHplT1',
#  'RHplT2',
#  'RHplT3',
#  'RHplT4',
#  'RHplT5',
#  'RHplT6',
#  'RHplT7',
#  'RHplT8',
#  'RHplT9',
#  'RHplT10',
#  'RLes1',
#  'RLes2',
#  'RLes3',
#  'RLes4',
#  'RLes5',
#  'RLes6',
#  'RLes7',
#  'RLes8',
#  'RLes9',
#  'RLes10',
#  'Fp1',
#  'F7',
#  'T3',
#  'T5',
#  'O1',
#  'F3',
#  'C3',
#  'P3',
#  'Fp2',
#  'F8',
#  'T4',
#  'T6',
#  'O2',
#  'F4',
#  'C4',
#  'P4',
#  'Fz',
#  'Cz',
#  'Pz',
#  'EKG1',
#  'EKG2',
#  'C115',
#  'C116',
#  'C117',
#  'C118',
#  'C119',
#  'C120',
#  'C121',
#  'C122',
#  'C123',
#  'C124',
#  'C125',
#  'C126',
#  'C127',
#  'C128',
#  'Research',
#  'DC2',
#  'DC3',
#  'DC4',
#  'DC5',
#  'DC6',
#  'DC7',
#  'DC8',
#  'DC9',
#  'DC10',
#  'DC11',
#  'DC12',
#  'DC13',
#  'DC14',
#  'DC15',
#  'DC16',
#  'TRIG',
#  'OSAT',
#  'PR',
#  'Pleth']

# %% [markdown]
# # Import Anat Recon Info - check all elecs are present in data + recon sheet

# %%
# Load the electrode localization data
anat_file = glob(f'{anat_dir}/{subj_id}_labels.csv')[0]
elec_locs = pd.read_csv(anat_file)
# Sometimes there's extra columns with no entries: 
elec_locs = elec_locs[elec_locs.columns.drop(list(elec_locs.filter(regex='Unnamed')))]
elec_locs = elec_locs.dropna(axis=0, how = 'all')
elec_locs
# Out:
#       label BN246label          x          y          z      mni_x      mni_y  \
# 0    RaCaS1     A14m_R   4.836167  42.912106   0.349001   5.437628  32.967164
# 1   RaCaS10      A9l_R  17.613934  41.713321  43.476521  19.710939  38.604577
# 2   RaCaS11     A8dl_R  19.211155  41.713321  48.268467  21.427907  39.357634
# 3   RaCaS12     A8dl_R  20.409071  41.713321  53.060414  22.745611  40.062229
# 4   RaCaS13    Unknown  22.006292  40.514536  58.251690  24.518511  39.555598
# ..      ...        ...        ...        ...        ...        ...        ...
# 83     RsI4     A44d_R  37.579195  12.143294  26.704708  41.972998   5.618481
# 84     RsI5    A6cvl_R  41.572248  10.145319  30.298667  46.245554   4.342895
# 85     RsI6    A6cvl_R  44.766689   9.745724  33.493299  49.645258   4.445183
# 86     RsI7    A6cvl_R  48.360436   8.946534  37.486587  53.518060   4.026982
# 87     RsI8     A4hf_R  51.554878   8.147344  41.080547  56.966862   3.652821
#
#         mni_z       gm                                  NMM      Anat  \
# 0  -10.841409     Gray  Right ACgG anterior cingulate gyrus  Area s32
# 1   37.666920    White     Right SFG superior frontal gyrus   Unknown
# 2   43.003857    White     Right SFG superior frontal gyrus   Unknown
# 3   48.282574     Gray     Right SFG superior frontal gyrus   Unknown
# 4   54.198018  Unknown                              Unknown   Unknown
# ..        ...      ...                                  ...       ...
# 83  22.722251    White           Right PrG precentral gyrus   Unknown
# 84  27.063820     Gray           Right PrG precentral gyrus   Unknown
# 85  30.637514     Gray           Right PrG precentral gyrus   Unknown
# 86  35.057535    White           Right PrG precentral gyrus   Unknown
# 87  39.042609     Gray           Right PrG precentral gyrus   Unknown
#
#                    AnatMacro    BN246                             YBA_1  \
# 0        R Mid Orbital Gyrus    R OrG           Right cingulate gyrus D
# 1   R Superior Frontal Gyrus    R SFG  Right superior frontal gyrus 3 D
# 2   R Superior Frontal Gyrus    R SFG  Right superior frontal gyrus 3 D
# 3   R Superior Frontal Gyrus    R SFG  Right superior frontal gyrus 3 D
# 4   R Superior Frontal Gyrus  Unknown  Right superior frontal gyrus 3 D
# ..                       ...      ...                               ...
# 83     R IFG (p Opercularis)    R IFG          Right pars opercularis A
# 84        R Precentral Gyrus    R PrG            Right anterior motor B
# 85        R Precentral Gyrus    R PrG            Right anterior motor A
# 86        R Precentral Gyrus    R PrG            Right anterior motor A
# 87        R Precentral Gyrus    R PrG            Right anterior motor A
#
#    Manual Examination      Notes
# 0                 NaN        NaN
# 1                  WM        NaN
# 2                  WM        NaN
# 3                 NaN        NaN
# 4                 OOB        NaN
# ..                ...        ...
# 83                 WM        NaN
# 84                NaN        NaN
# 85                OOB        NaN
# 86                 WM        NaN
# 87                NaN  maybe OOB
#
# [88 rows x 16 columns]

# %% [markdown]
# ### Fix edf channel names

# %%
new_mne_names, unmatched_names, unmatched_seeg = lfp_preprocess_utils.match_elec_names(mne_data.ch_names, elec_locs.label)
# Out:
# Number of electrodes in the mne file is greater than the number of electrodes in the localization file

# %%
unmatched_names
# Out:
# ['urmolf', 'uraglt']

# %%
unmatched_seeg
# Out:
# []

# %%
new_name_dict = {x:y for (x,y) in zip(mne_data.ch_names, new_mne_names)}
new_name_dict
# Out:
# {'rmolf1': 'rmolf1',
#  'rmolf2': 'rmolf2',
#  'rmolf3': 'rmolf3',
#  'rmolf4': 'rmolf4',
#  'rmolf5': 'rmolf5',
#  'rmolf6': 'rmolf6',
#  'rmolf7': 'rmolf7',
#  'rmolf8': 'rmolf8',
#  'rmolf9': 'rmolf9',
#  'racas1': 'racas1',
#  'racas2': 'racas2',
#  'racas3': 'racas3',
#  'racas4': 'racas4',
#  'racas5': 'racas5',
#  'racas6': 'racas6',
#  'racas7': 'racas7',
#  'racas8': 'racas8',
#  'racas9': 'racas9',
#  'racas10': 'racas10',
#  'racas11': 'racas11',
#  'racas12': 'racas12',
#  'racas13': 'racas13',
#  'racas14': 'racas14',
#  'rmcms1': 'rmcms1',
#  'rmcms2': 'rmcms2',
#  'rmcms3': 'rmcms3',
#  'rmcms4': 'rmcms4',
#  'rmcms5': 'rmcms5',
#  'rmcms6': 'rmcms6',
#  'rmcms7': 'rmcms7',
#  'rmcms8': 'rmcms8',
#  'rmcms9': 'rmcms9',
#  'rmcms10': 'rmcms10',
#  'raips1': 'raips1',
#  'raips2': 'raips2',
#  'raips3': 'raips3',
#  'raips4': 'raips4',
#  'raips5': 'raips5',
#  'raips6': 'raips6',
#  'raips7': 'raips7',
#  'raips8': 'raips8',
#  'raips9': 'raips9',
#  'raips10': 'raips10',
#  'raips11': 'raips11',
#  'raips12': 'raips12',
#  'raips13': 'raips13',
#  'raips14': 'raips14',
#  'raips15': 'raips15',
#  'raips16': 'raips16',
#  'rsi1': 'rsi1',
#  'rsi2': 'rsi2',
#  'rsi3': 'rsi3',
#  'rsi4': 'rsi4',
#  'rsi5': 'rsi5',
#  'rsi6': 'rsi6',
#  'rsi7': 'rsi7',
#  'rsi8': 'rsi8',
#  'c58': 'c58',
#  'c59': 'c59',
#  'c60': 'c60',
#  'c61': 'c61',
#  'c62': 'c62',
#  'c63': 'c63',
#  'c64': 'c64',
#  'raglt1': 'raglt1',
#  'raglt2': 'raglt2',
#  'raglt3': 'raglt3',
#  'raglt4': 'raglt4',
#  'raglt5': 'raglt5',
#  'raglt6': 'raglt6',
#  'raglt7': 'raglt7',
#  'raglt8': 'raglt8',
#  'raglt9': 'raglt9',
#  'rhplt1': 'rhplt1',
#  'rhplt2': 'rhplt2',
#  'rhplt3': 'rhplt3',
#  'rhplt4': 'rhplt4',
#  'rhplt5': 'rhplt5',
#  'rhplt6': 'rhplt6',
#  'rhplt7': 'rhplt7',
#  'rhplt8': 'rhplt8',
#  'rhplt9': 'rhplt9',
#  'rhplt10': 'rhplt10',
#  'rles1': 'rles1',
#  'rles2': 'rles2',
#  'rles3': 'rles3',
#  'rles4': 'rles4',
#  'rles5': 'rles5',
#  'rles6': 'rles6',
#  'rles7': 'rles7',
#  'rles8': 'rles8',
#  'rles9': 'rles9',
#  'rles10': 'rles10',
#  'fp1': 'fp1',
#  'f7': 'f7',
#  't3': 't3',
#  't5': 't5',
#  'o1': 'o1',
#  'f3': 'f3',
#  'c3': 'c3',
#  'p3': 'p3',
#  'fp2': 'fp2',
#  'f8': 'f8',
#  't4': 't4',
#  't6': 't6',
#  'o2': 'o2',
#  'f4': 'f4',
#  'c4': 'c4',
#  'p4': 'p4',
#  'fz': 'fz',
#  'cz': 'cz',
#  'pz': 'pz',
#  'ekg1': 'ekg1',
#  'ekg2': 'ekg2',
#  'c115': 'c115',
#  'c116': 'c116',
#  'c117': 'c117',
#  'c118': 'c118',
#  'c119': 'c119',
#  'c120': 'c120',
#  'c121': 'c121',
#  'c122': 'c122',
#  'c123': 'c123',
#  'c124': 'c124',
#  'c125': 'c125',
#  'c126': 'c126',
#  'c127': 'c127',
#  'c128': 'c128',
#  'research': 'research',
#  'dc2': 'dc2',
#  'dc3': 'dc3',
#  'dc4': 'dc4',
#  'dc5': 'dc5',
#  'dc6': 'dc6',
#  'dc7': 'dc7',
#  'dc8': 'dc8',
#  'dc9': 'dc9',
#  'dc10': 'dc10',
#  'dc11': 'dc11',
#  'dc12': 'dc12',
#  'dc13': 'dc13',
#  'dc14': 'dc14',
#  'dc15': 'dc15',
#  'dc16': 'dc16',
#  'trig': 'trig',
#  'osat': 'osat',
#  'pr': 'pr',
#  'pleth': 'pleth'}

# %%
# Rename the mne data according to the localization data
mne_data.rename_channels(new_name_dict)
# Out:
# <RawEDF | MS014_Resting_iEEG.edf, 148 x 616064 (601.6 s), ~695.8 MB, data loaded>

# %%
mne_data.ch_names
# Out:
# ['rmolf1',
#  'rmolf2',
#  'rmolf3',
#  'rmolf4',
#  'rmolf5',
#  'rmolf6',
#  'rmolf7',
#  'rmolf8',
#  'rmolf9',
#  'racas1',
#  'racas2',
#  'racas3',
#  'racas4',
#  'racas5',
#  'racas6',
#  'racas7',
#  'racas8',
#  'racas9',
#  'racas10',
#  'racas11',
#  'racas12',
#  'racas13',
#  'racas14',
#  'rmcms1',
#  'rmcms2',
#  'rmcms3',
#  'rmcms4',
#  'rmcms5',
#  'rmcms6',
#  'rmcms7',
#  'rmcms8',
#  'rmcms9',
#  'rmcms10',
#  'raips1',
#  'raips2',
#  'raips3',
#  'raips4',
#  'raips5',
#  'raips6',
#  'raips7',
#  'raips8',
#  'raips9',
#  'raips10',
#  'raips11',
#  'raips12',
#  'raips13',
#  'raips14',
#  'raips15',
#  'raips16',
#  'rsi1',
#  'rsi2',
#  'rsi3',
#  'rsi4',
#  'rsi5',
#  'rsi6',
#  'rsi7',
#  'rsi8',
#  'c58',
#  'c59',
#  'c60',
#  'c61',
#  'c62',
#  'c63',
#  'c64',
#  'raglt1',
#  'raglt2',
#  'raglt3',
#  'raglt4',
#  'raglt5',
#  'raglt6',
#  'raglt7',
#  'raglt8',
#  'raglt9',
#  'rhplt1',
#  'rhplt2',
#  'rhplt3',
#  'rhplt4',
#  'rhplt5',
#  'rhplt6',
#  'rhplt7',
#  'rhplt8',
#  'rhplt9',
#  'rhplt10',
#  'rles1',
#  'rles2',
#  'rles3',
#  'rles4',
#  'rles5',
#  'rles6',
#  'rles7',
#  'rles8',
#  'rles9',
#  'rles10',
#  'fp1',
#  'f7',
#  't3',
#  't5',
#  'o1',
#  'f3',
#  'c3',
#  'p3',
#  'fp2',
#  'f8',
#  't4',
#  't6',
#  'o2',
#  'f4',
#  'c4',
#  'p4',
#  'fz',
#  'cz',
#  'pz',
#  'ekg1',
#  'ekg2',
#  'c115',
#  'c116',
#  'c117',
#  'c118',
#  'c119',
#  'c120',
#  'c121',
#  'c122',
#  'c123',
#  'c124',
#  'c125',
#  'c126',
#  'c127',
#  'c128',
#  'research',
#  'dc2',
#  'dc3',
#  'dc4',
#  'dc5',
#  'dc6',
#  'dc7',
#  'dc8',
#  'dc9',
#  'dc10',
#  'dc11',
#  'dc12',
#  'dc13',
#  'dc14',
#  'dc15',
#  'dc16',
#  'trig',
#  'osat',
#  'pr',
#  'pleth']

# %%
anat_names = list(elec_locs.label.str.lower())
sum([ch not in mne_data.ch_names for ch in anat_names]) #if there are no missing channels, sum = 0. if sum >0, find the missing elecs
print([ch for ch in mne_data.ch_names if ch not in anat_names ]) 
#print extra channels in mne_data.ch_names and make sure none of them are neural channels
# Out:
# ['c58', 'c59', 'c60', 'c61', 'c62', 'c63', 'c64', 'fp1', 'f7', 't3', 't5', 'o1', 'f3', 'c3', 'p3', 'fp2', 'f8', 't4', 't6', 'o2', 'f4', 'c4', 'p4', 'fz', 'cz', 'pz', 'ekg1', 'ekg2', 'c115', 'c116', 'c117', 'c118', 'c119', 'c120', 'c121', 'c122', 'c123', 'c124', 'c125', 'c126', 'c127', 'c128', 'research', 'dc2', 'dc3', 'dc4', 'dc5', 'dc6', 'dc7', 'dc8', 'dc9', 'dc10', 'dc11', 'dc12', 'dc13', 'dc14', 'dc15', 'dc16', 'trig', 'osat', 'pr', 'pleth']

# %%
# Note, there is surface EEG data that we should separately indicate from the sEEG:
right_seeg_names = [i for i in mne_data.ch_names if i.startswith('r')]
left_seeg_names = [i for i in mne_data.ch_names if i.startswith('l')]
print(f'We have a total of', len(left_seeg_names), 'left &', len(right_seeg_names), 'right sEEG electrodes')
print(f'We have a total of {len(left_seeg_names) + len(right_seeg_names)} sEEG electrodes')
# Out:
# We have a total of 0 left & 87 right sEEG electrodes
# We have a total of 87 sEEG electrodes

# %%
mne_data
# Out:
# <RawEDF | MS014_Resting_iEEG.edf, 148 x 616064 (601.6 s), ~695.8 MB, data loaded>

# %%
drop_chans = list(set(mne_data.ch_names)^set(right_seeg_names)) # it is either called DC1 or research
mne_data.drop_channels(drop_chans) #number of chans should = number of seegs
# Out:
# <RawEDF | MS014_Resting_iEEG.edf, 87 x 616064 (601.6 s), ~409.0 MB, data loaded>

# %%
# Set channel types:
sEEG_mapping_dict = {f'{x}':'seeg' for x in left_seeg_names+right_seeg_names}
mne_data.set_channel_types(sEEG_mapping_dict)
# Out:
# <RawEDF | MS014_Resting_iEEG.edf, 87 x 616064 (601.6 s), ~409.0 MB, data loaded>

# %%
mne_data.drop_channels(['research'])
# Out:
# <RawEDF | MS014_Resting_iEEG.edf, 86 x 616064 (601.6 s), ~404.3 MB, data loaded>

# %%
# make montage (convert mm to m)

montage = mne.channels.make_dig_montage(ch_pos=dict(zip(elec_locs.label, 
                                                        elec_locs[['mni_x', 'mni_y', 'mni_z']].to_numpy(dtype=float)/1000)),
                                        coord_frame='mni_tal')

mne_data.set_montage(montage, match_case=False, on_missing='warn')
# Out:
# <RawEDF | MS014_Resting_iEEG.edf, 86 x 616064 (601.6 s), ~404.3 MB, data loaded>

# %% [markdown]
# ### Notch filter line noise

# %%
# Identify line noise
mne_data.info['line_freq'] = 60

# Notch out 60 Hz noise and harmonics 
mne_data.notch_filter(freqs=(60, 120, 180, 240))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  86 out of  86 | elapsed:    1.2s finished
# <RawEDF | MS014_Resting_iEEG.edf, 86 x 616064 (601.6 s), ~404.3 MB, data loaded>

# %% [markdown]
# ### Resampling data

# %%
resample_sr = 500
mne_data.resample(sfreq=resample_sr, npad='auto', n_jobs=-1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done  79 out of  86 | elapsed:    2.4s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  86 out of  86 | elapsed:    2.5s finished
# <RawEDF | MS014_Resting_iEEG.edf, 86 x 300812 (601.6 s), ~197.5 MB, data loaded>

# %% [markdown]
# ### Bad Channel Removal (manual)

# %% [markdown]
# Let's pick out any bad channels missed by automatic screening (visual inspection as a reference), or restore channels that were erroneously deemed bad. You have to press the "power" button twice (once for the plot and once for the panel beneath it) when you're done so that you're manual changes are saved.

# %%
# %matplotlib notebook
# %matplotlib notebook

fig = mne_data.plot(start=0, duration=120, n_channels=50)
fig.fake_keypress('a') #lots of bad times
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
mne_data.info['bads'] #sanity check that bads info saved
# Out:
# []

# %%
mne_data.ch_names
# Out:
# ['rmolf1',
#  'rmolf2',
#  'rmolf3',
#  'rmolf4',
#  'rmolf5',
#  'rmolf6',
#  'rmolf7',
#  'rmolf8',
#  'rmolf9',
#  'racas1',
#  'racas2',
#  'racas3',
#  'racas4',
#  'racas5',
#  'racas6',
#  'racas7',
#  'racas8',
#  'racas9',
#  'racas10',
#  'racas11',
#  'racas12',
#  'racas13',
#  'racas14',
#  'rmcms1',
#  'rmcms2',
#  'rmcms3',
#  'rmcms4',
#  'rmcms5',
#  'rmcms6',
#  'rmcms7',
#  'rmcms8',
#  'rmcms9',
#  'rmcms10',
#  'raips1',
#  'raips2',
#  'raips3',
#  'raips4',
#  'raips5',
#  'raips6',
#  'raips7',
#  'raips8',
#  'raips9',
#  'raips10',
#  'raips11',
#  'raips12',
#  'raips13',
#  'raips14',
#  'raips15',
#  'raips16',
#  'rsi1',
#  'rsi2',
#  'rsi3',
#  'rsi4',
#  'rsi5',
#  'rsi6',
#  'rsi7',
#  'rsi8',
#  'raglt1',
#  'raglt2',
#  'raglt3',
#  'raglt4',
#  'raglt5',
#  'raglt6',
#  'raglt7',
#  'raglt8',
#  'raglt9',
#  'rhplt1',
#  'rhplt2',
#  'rhplt3',
#  'rhplt4',
#  'rhplt5',
#  'rhplt6',
#  'rhplt7',
#  'rhplt8',
#  'rhplt9',
#  'rhplt10',
#  'rles1',
#  'rles2',
#  'rles3',
#  'rles4',
#  'rles5',
#  'rles6',
#  'rles7',
#  'rles8',
#  'rles9',
#  'rles10']

# %% [markdown]
# ## Save raw LFP data
# Notch filtered and resampled with bad elecs indicated

# %%
#define oob elecs as bad before saving out lfp file 
oob_elec = [elec_locs['label'].iloc[ind].lower() for ind, data in elec_locs['Manual Examination'].str.lower().items() if data=='oob']
oob_elec
# Out:
# ['racas13',
#  'racas14',
#  'rhplt10',
#  'rhplt7',
#  'rhplt8',
#  'rhplt9',
#  'rles10',
#  'rles9',
#  'rmcms10',
#  'rsi6']

# %%
bad_ch= mne_data.info['bads']
bad_ch = bad_ch + oob_elec
mne_data.info['bads'] = list(np.unique(bad_ch))
mne_data.info['bads'] # make sure an WM referenced pairs that include these channels is excluded.
# Out:
# ['racas13',
#  'racas14',
#  'rhplt10',
#  'rhplt7',
#  'rhplt8',
#  'rhplt9',
#  'rles10',
#  'rles9',
#  'rmcms10',
#  'rsi6']

# %%
mne_data.save(f'{save_dir}/{subj_id}_raw_ieeg.fif',overwrite=True)

# %% [markdown]
# # Rereference data

# %% [markdown]
# ### WM REF

# %%
anode_list, cathode_list, drop_wm_channels, oob_channels = lfp_preprocess_utils.wm_ref(mne_data=mne_data, 
                                                                                elec_path=anat_file, 
                                                                                unmatched_seeg = unmatched_seeg,
                                                                                bad_channels=mne_data.info['bads'],
                                                                                      site='MSSM')

# %%
# not super elegant way to do this, but it works
anode_list_clean = []
removed_anode_index = []
for i,ch in enumerate(anode_list):
    if ch not in bad_ch:
        anode_list_clean.append(ch)
    else:
        removed_anode_index.append(i)

cathode_list_update = [cathode_list[i] for i in range(len(cathode_list)) if i not in removed_anode_index]

cathode_list_clean = []
for ch in cathode_list_update:
    if ch not in bad_ch:
        cathode_list_clean.append(ch)

# %%
mne_data_wm_reref = mne.set_bipolar_reference(mne_data, 
                      anode=anode_list, 
                      cathode=cathode_list,
                      copy=True)

# %%
mne_data_wm_reref #none of the bad channels should be rereferenced - should we drop these?
# Out:
# <RawEDF | MS014_Resting_iEEG.edf, 73 x 300812 (601.6 s), ~167.6 MB, data loaded>

# %% [markdown]
# To start annotating, press 'Add new label' in the bottom panel. Then left click and drag around window of interest.

# %%
# %matplotlib notebook
# %matplotlib notebook
# use the epoch code to select only the WM referenced pairs
fig = mne_data_wm_reref.plot(start=2, duration=100, n_channels=50) # plot all channels at once
fig.fake_keypress("a")
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
mne_data_wm_reref.annotations.onset
# Out:
# array([261.82328408, 370.80127886, 392.62478534, 410.00784511])

# %%
def join_good_segs(mne_data):
    #creates indices of good epochs after labeling bad times manually, then crops good epochs and joins data 
    
    ### get good times: 
    good_start = list([mne_data_wm_reref.first_time]) #first timepoint in recording (should be 0)
    good_end = []
    
    for annot in mne_data.annotations:
        bad_start = mne_data.time_as_index(annot['onset']) #onset is start time of bad epoch 
        # ^ start time of bad epoch converted to index, then subtract 1 for end of good epoch
        bad_end = mne_data.time_as_index(annot['onset'] + annot['duration']) #onset + duration = end time of bad epoch
        # ^ end time of bad epoch converted to index 
        # must get bad start and end as indices so you can +-1 for good epochs - cannot +-1 using time only indexes

        good_end.append(mne_data.times[bad_start - 1]) #the start time of a bad epoch is the end of a good epoch - 1
        good_start.append(mne_data.times[bad_end+1]) #the end time of a bad epoch is the start of a good epoch +1 index
        #convert to integers before appending - indexing np arrays later is annoying
                          
    good_end.append(mne_data.times[mne_data.last_samp]) #index of last timepoint in recording (should = mne_data.n_times)
    
    ### get good data epochs and concatenate 
    good_segs = []
    for start,end in list(zip(good_start,good_end)):
        good_segs.append(mne_data.copy().crop(tmin=float(start), tmax=float(end),
                include_tmax=True))
    
    return mne.concatenate_raws(good_segs)
    
#derived from: 
    # source: https://mne.discourse.group/t/removing-time-segments-from-raw-object-without-epoching/4169/2
    # source: https://github.com/mne-tools/mne-python/blob/maint/1.5/mne/io/base.py#L681-L742

# %%
mne_data_wm_reref_clean = join_good_segs(mne_data_wm_reref)
mne_data_wm_reref_clean
# Out:
# <RawEDF | MS014_Resting_iEEG.edf, 73 x 296503 (593.0 s), ~165.2 MB, data loaded>

# %% [markdown]
# ### Save reref data

# %%
mne_data_wm_reref_clean.save(f'{save_dir}/{subj_id}_wm_ref_ieeg.fif',overwrite=True)
