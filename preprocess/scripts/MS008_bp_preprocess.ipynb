# %% [markdown]
# # Preprocess Continuous Data - Resting State
# ## MS008
# 10/01/2023
# Updated: 02/26/2024

# %%
import numpy as np
import mne
from glob import glob
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from scipy.stats import zscore, linregress, ttest_ind, ttest_rel, ttest_1samp
import pandas as pd
from mne.preprocessing.bads import _find_outliers
import os 
import joblib
import emd
import re

import warnings
warnings.filterwarnings('ignore')
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
import sys
sys.path.append('/Users/alexandrafink/Documents/GitHub/LFPAnalysis')

# %%
from LFPAnalysis import lfp_preprocess_utils, sync_utils, analysis_utils, nlx_utils

# %%
subj_id = 'MS008'

# Specify root directory for data and results 
base_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/resting_state_proj/resting_state_ieeg/'
anat_dir = f'{base_dir}anat'
neural_dir = f'{base_dir}preprocess/raw_data/{subj_id}'
save_dir = f'{base_dir}preprocess/clean_data/{subj_id}'
os.makedirs(save_dir,exist_ok = True)

# %% [markdown]
# #### Import Data

# %%
edf_files = glob(f'{neural_dir}/*.edf')

mne_data = mne.io.read_raw_edf(edf_files[0], preload=True)
mne_data
# Out:
# <RawEDF | MS008_Resting_iEEG.edf, 276 x 678016 (662.1 s), ~1.39 GB, data loaded>

# %%
mne_data.ch_names
# Out:
# ['LmOlF1',
#  'LmOlF2',
#  'LmOlF3',
#  'LmOlF4',
#  'LmOlF5',
#  'LmOlF6',
#  'LmOlF7',
#  'LmOlF8',
#  'LmOlF9',
#  'LmOlF10',
#  'RmOlF1',
#  'RmOlF2',
#  'RmOlF3',
#  'RmOlF4',
#  'RmOlF5',
#  'RmOlF6',
#  'RmOlF7',
#  'RmOlF8',
#  'RmOlF9',
#  'RmOlF10',
#  'LaCaS1',
#  'LaCaS2',
#  'LaCaS3',
#  'LaCaS4',
#  'LaCaS5',
#  'LaCaS6',
#  'LaCaS7',
#  'LaCaS8',
#  'LaCaS9',
#  'LaCaS10',
#  'LaCaS11',
#  'LaCaS12',
#  'RaCaS1',
#  'RaCaS2',
#  'RaCaS3',
#  'RaCaS4',
#  'RaCaS5',
#  'RaCaS6',
#  'RaCaS7',
#  'RaCaS8',
#  'RaCaS9',
#  'RaCaS10',
#  'RaCaS11',
#  'RaCaS12',
#  'RaCaS13',
#  'RaCaS14',
#  'LmCmS1',
#  'LmCmS2',
#  'LmCmS3',
#  'LmCmS4',
#  'LmCmS5',
#  'LmCmS6',
#  'LmCmS7',
#  'LmCmS8',
#  'RmCmS1',
#  'RmCmS2',
#  'RmCmS3',
#  'RmCmS4',
#  'RmCmS5',
#  'RmCmS6',
#  'RmCmS7',
#  'RmCmS8',
#  'C63',
#  'C64',
#  'LAglT1',
#  'LAglT2',
#  'LAglT3',
#  'LAglT4',
#  'LAglT5',
#  'LAglT6',
#  'LAglT7',
#  'LAglT8',
#  'RAglT1',
#  'RAglT2',
#  'RAglT3',
#  'RAglT4',
#  'RAglT5',
#  'RAglT6',
#  'RAglT7',
#  'RAglT8',
#  'RAglT9',
#  'RAglT10',
#  'RAglT11',
#  'RAglT12',
#  'RAglT13',
#  'RAglT14',
#  'RAglT15',
#  'RAglT16',
#  'LHplT1',
#  'LHplT2',
#  'LHplT3',
#  'LHplT4',
#  'LHplT5',
#  'LHplT6',
#  'LHplT7',
#  'LHplT8',
#  'LHplT9',
#  'LHplT10',
#  'RHpO1',
#  'RHpO2',
#  'RHpO3',
#  'RHpO4',
#  'RHpO5',
#  'RHpO6',
#  'RHpO7',
#  'RHpO8',
#  'RHpO9',
#  'RHpO10',
#  'RHpO11',
#  'RHpO12',
#  'RHpO13',
#  'RHpO14',
#  'RHpO15',
#  'RHpO16',
#  'LmTpT1',
#  'LmTpT2',
#  'LmTpT3',
#  'LmTpT4',
#  'LmTpT5',
#  'LmTpT6',
#  'LmTpT7',
#  'LmTpT8',
#  'LmTpT9',
#  'LmTpT10',
#  'C125',
#  'C126',
#  'C127',
#  'C128',
#  'RmTpT1',
#  'RmTpT2',
#  'RmTpT3',
#  'RmTpT4',
#  'RmTpT5',
#  'RmTpT6',
#  'RmTpT7',
#  'RmTpT8',
#  'RmTpT9',
#  'RmTpT10',
#  'RPEA1',
#  'RPEA2',
#  'RPEA3',
#  'RPEA4',
#  'RPEA5',
#  'RPEA6',
#  'RPEP1',
#  'RPEP2',
#  'RPEP3',
#  'RPEP4',
#  'RPEP5',
#  'RPEP6',
#  'Fp1',
#  'F7',
#  'T3',
#  'T5',
#  'O1',
#  'F3',
#  'C3',
#  'P3',
#  'Fp2',
#  'F8',
#  'T4',
#  'T6',
#  'O2',
#  'F4',
#  'C4',
#  'P4',
#  'Fz',
#  'Cz',
#  'Pz',
#  'EKG1',
#  'EKG2',
#  'RES',
#  'C173',
#  'C174',
#  'C175',
#  'C176',
#  'C177',
#  'C178',
#  'C179',
#  'C180',
#  'C181',
#  'C182',
#  'C183',
#  'C184',
#  'C185',
#  'C186',
#  'C187',
#  'C188',
#  'C189',
#  'C190',
#  'C191',
#  'C192',
#  'C193',
#  'C194',
#  'C195',
#  'C196',
#  'C197',
#  'C198',
#  'C199',
#  'C200',
#  'C201',
#  'C202',
#  'C203',
#  'C204',
#  'C205',
#  'C206',
#  'C207',
#  'C208',
#  'C209',
#  'C210',
#  'C211',
#  'C212',
#  'C213',
#  'C214',
#  'C215',
#  'C216',
#  'C217',
#  'C218',
#  'C219',
#  'C220',
#  'C221',
#  'C222',
#  'C223',
#  'C224',
#  'C225',
#  'C226',
#  'C227',
#  'C228',
#  'C229',
#  'C230',
#  'C231',
#  'C232',
#  'C233',
#  'C234',
#  'C235',
#  'C236',
#  'C237',
#  'C238',
#  'C239',
#  'C240',
#  'C241',
#  'C242',
#  'C243',
#  'C244',
#  'C245',
#  'C246',
#  'C247',
#  'C248',
#  'C249',
#  'C250',
#  'C251',
#  'C252',
#  'C253',
#  'C254',
#  'C255',
#  'C256',
#  'DC1',
#  'DC2',
#  'DC3',
#  'DC4',
#  'DC5',
#  'DC6',
#  'DC7',
#  'DC8',
#  'DC9',
#  'DC10',
#  'DC11',
#  'DC12',
#  'DC13',
#  'DC14',
#  'DC15',
#  'DC16',
#  'TRIG',
#  'OSAT',
#  'PR',
#  'Pleth']

# %% [markdown]
# # Import Anat Recon Info - check all elecs are present in data + recon sheet

# %%
# Load the electrode localization data
anat_file = glob(f'{anat_dir}/{subj_id}_labels.csv')[0]
elec_locs = pd.read_csv(anat_file)
# Sometimes there's extra columns with no entries: 
elec_locs = elec_locs[elec_locs.columns.drop(list(elec_locs.filter(regex='Unnamed')))]
elec_locs = elec_locs.dropna(axis=0, how = 'all')
elec_locs
# Out:
#        label BN246label          x          y          z      mni_x  \
# 0     LaCas1      A13_L  -9.181259  37.595151   0.399772  -7.760768
# 1    LaCas10   A9/46d_L -25.547852  38.395047  40.777025 -27.108802
# 2    LaCas11   A9/46d_L -27.144592  38.794996  45.574323 -28.906378
# 3    LaCas12    Unknown -28.741333  38.794996  50.371620 -30.694326
# 4     LaCas2      A13_L -11.177185  37.195202   4.797294 -10.275087
# ..       ...        ...        ...        ...        ...        ...
# 139    RPEP2    A39rd_R  31.934814 -48.393759  20.388511  36.891150
# 140    RPEP3    A39rd_R  34.329926 -51.993295  22.787160  39.464875
# 141    RPEP4    A39rd_R  37.124222 -55.192882  25.585583  42.519900
# 142    RPEP5    A39rd_R  39.519333 -59.192367  27.984232  45.235396
# 143    RPEP6    Unknown  42.313629 -62.391954  30.782656  48.488528
#
#          mni_y      mni_z       gm                                 NMM  \
# 0    29.351037 -16.334162    White      Left MFC medial frontal cortex
# 1    42.288239  30.742824     Gray       Left MFG middle frontal gyrus
# 2    44.081606  36.228537     Gray       Left MFG middle frontal gyrus
# 3    45.530011  41.862931  Unknown                             Unknown
# 4    30.396791 -11.027941    White  Left ACgG anterior cingulate gyrus
# ..         ...        ...      ...                                 ...
# 139 -56.539538  35.515119     Gray         Right Cerebral White Matter
# 140 -59.707416  39.502152     Gray             Right AnG angular gyrus
# 141 -62.351204  43.900651     Gray             Right AnG angular gyrus
# 142 -65.966077  48.102822     Gray             Right AnG angular gyrus
# 143 -68.664419  52.675070  Unknown                             Unknown
#
#                 Anat                 AnatMacro    BN246  \
# 0           Area s32            L Rectal Gyrus    L OrG
# 1            Unknown    L Middle Frontal Gyrus    L MFG
# 2            Unknown    L Middle Frontal Gyrus    L MFG
# 3            Unknown  L Superior Frontal Gyrus  Unknown
# 4           Area s32       L Mid Orbital Gyrus    L OrG
# ..               ...                       ...      ...
# 139  Area hIP1 (IPS)           R Angular Gyrus    R IPL
# 140          Unknown           R Angular Gyrus    R IPL
# 141   Area PGa (IPL)           R Angular Gyrus    R IPL
# 142   Area PGp (IPL)           R Angular Gyrus    R IPL
# 143          Unknown           R Angular Gyrus  Unknown
#
#                              YBA_1 Manual Examination Notes
# 0            Left frontal pole 1 B                 WM   NaN
# 1    Left middle frontal gyrus 3 A                NaN   NaN
# 2    Left middle frontal gyrus 3 B                NaN   NaN
# 3    Left middle frontal gyrus 3 B                OOB   NaN
# 4           Left cingulate gyrus C                 WM   NaN
# ..                             ...                ...   ...
# 139                        Unknown             lesion   NaN
# 140  Right supramarginal gyrus 5 B             lesion   NaN
# 141                        Unknown             lesion   NaN
# 142  Right supramarginal gyrus 5 B             lesion   NaN
# 143                        Unknown             lesion   NaN
#
# [144 rows x 16 columns]

# %% [markdown]
# ### Fix edf channel names

# %%
new_mne_names, unmatched_names, unmatched_seeg = lfp_preprocess_utils.match_elec_names(mne_data.ch_names, elec_locs.label)
# Out:
# Number of electrodes in the mne file is greater than the number of electrodes in the localization file

# %%
unmatched_names
# Out:
# []

# %%
unmatched_seeg
# Out:
# []

# %%
new_name_dict = {x:y for (x,y) in zip(mne_data.ch_names, new_mne_names)}
new_name_dict
# Out:
# {'LmOlF1': 'lmoif1',
#  'LmOlF2': 'lmoif2',
#  'LmOlF3': 'lmoif3',
#  'LmOlF4': 'lmoif4',
#  'LmOlF5': 'lmoif5',
#  'LmOlF6': 'lmoif6',
#  'LmOlF7': 'lmoif7',
#  'LmOlF8': 'lmoif8',
#  'LmOlF9': 'lmoif9',
#  'LmOlF10': 'lmoif10',
#  'RmOlF1': 'rmoif1',
#  'RmOlF2': 'rmoif2',
#  'RmOlF3': 'rmoif3',
#  'RmOlF4': 'rmoif4',
#  'RmOlF5': 'rmoif5',
#  'RmOlF6': 'rmoif6',
#  'RmOlF7': 'rmoif7',
#  'RmOlF8': 'rmoif8',
#  'RmOlF9': 'rmoif9',
#  'RmOlF10': 'rmoif10',
#  'LaCaS1': 'lacas1',
#  'LaCaS2': 'lacas2',
#  'LaCaS3': 'lacas3',
#  'LaCaS4': 'lacas4',
#  'LaCaS5': 'lacas5',
#  'LaCaS6': 'lacas6',
#  'LaCaS7': 'lacas7',
#  'LaCaS8': 'lacas8',
#  'LaCaS9': 'lacas9',
#  'LaCaS10': 'lacas10',
#  'LaCaS11': 'lacas11',
#  'LaCaS12': 'lacas12',
#  'RaCaS1': 'racas1',
#  'RaCaS2': 'racas2',
#  'RaCaS3': 'racas3',
#  'RaCaS4': 'racas4',
#  'RaCaS5': 'racas5',
#  'RaCaS6': 'racas6',
#  'RaCaS7': 'racas7',
#  'RaCaS8': 'racas8',
#  'RaCaS9': 'racas9',
#  'RaCaS10': 'racas10',
#  'RaCaS11': 'racas11',
#  'RaCaS12': 'racas12',
#  'RaCaS13': 'racas13',
#  'RaCaS14': 'racas14',
#  'LmCmS1': 'lmcms1',
#  'LmCmS2': 'lmcms2',
#  'LmCmS3': 'lmcms3',
#  'LmCmS4': 'lmcms4',
#  'LmCmS5': 'lmcms5',
#  'LmCmS6': 'lmcms6',
#  'LmCmS7': 'lmcms7',
#  'LmCmS8': 'lmcms8',
#  'RmCmS1': 'rmcms1',
#  'RmCmS2': 'rmcms2',
#  'RmCmS3': 'rmcms3',
#  'RmCmS4': 'rmcms4',
#  'RmCmS5': 'rmcms5',
#  'RmCmS6': 'rmcms6',
#  'RmCmS7': 'rmcms7',
#  'RmCmS8': 'rmcms8',
#  'C63': 'c63',
#  'C64': 'c64',
#  'LAglT1': 'lagit1',
#  'LAglT2': 'lagit2',
#  'LAglT3': 'lagit3',
#  'LAglT4': 'lagit4',
#  'LAglT5': 'lagit5',
#  'LAglT6': 'lagit6',
#  'LAglT7': 'lagit7',
#  'LAglT8': 'lagit8',
#  'RAglT1': 'ragit1',
#  'RAglT2': 'ragit2',
#  'RAglT3': 'ragit3',
#  'RAglT4': 'ragit4',
#  'RAglT5': 'ragit5',
#  'RAglT6': 'ragit6',
#  'RAglT7': 'ragit7',
#  'RAglT8': 'ragit8',
#  'RAglT9': 'ragit9',
#  'RAglT10': 'ragit10',
#  'RAglT11': 'ragit11',
#  'RAglT12': 'ragit12',
#  'RAglT13': 'ragit13',
#  'RAglT14': 'ragit14',
#  'RAglT15': 'ragit15',
#  'RAglT16': 'ragit16',
#  'LHplT1': 'lhpit1',
#  'LHplT2': 'lhpit2',
#  'LHplT3': 'lhpit3',
#  'LHplT4': 'lhpit4',
#  'LHplT5': 'lhpit5',
#  'LHplT6': 'lhpit6',
#  'LHplT7': 'lhpit7',
#  'LHplT8': 'lhpit8',
#  'LHplT9': 'lhpit9',
#  'LHplT10': 'lhpit10',
#  'RHpO1': 'rhpo1',
#  'RHpO2': 'rhpo2',
#  'RHpO3': 'rhpo3',
#  'RHpO4': 'rhpo4',
#  'RHpO5': 'rhpo5',
#  'RHpO6': 'rhpo6',
#  'RHpO7': 'rhpo7',
#  'RHpO8': 'rhpo8',
#  'RHpO9': 'rhpo9',
#  'RHpO10': 'rhpo10',
#  'RHpO11': 'rhpo11',
#  'RHpO12': 'rhpo12',
#  'RHpO13': 'rhpo13',
#  'RHpO14': 'rhpo14',
#  'RHpO15': 'rhpo15',
#  'RHpO16': 'rhpo16',
#  'LmTpT1': 'lmtpt1',
#  'LmTpT2': 'lmtpt2',
#  'LmTpT3': 'lmtpt3',
#  'LmTpT4': 'lmtpt4',
#  'LmTpT5': 'lmtpt5',
#  'LmTpT6': 'lmtpt6',
#  'LmTpT7': 'lmtpt7',
#  'LmTpT8': 'lmtpt8',
#  'LmTpT9': 'lmtpt9',
#  'LmTpT10': 'lmtpt10',
#  'C125': 'c125',
#  'C126': 'c126',
#  'C127': 'c127',
#  'C128': 'c128',
#  'RmTpT1': 'rmtpt1',
#  'RmTpT2': 'rmtpt2',
#  'RmTpT3': 'rmtpt3',
#  'RmTpT4': 'rmtpt4',
#  'RmTpT5': 'rmtpt5',
#  'RmTpT6': 'rmtpt6',
#  'RmTpT7': 'rmtpt7',
#  'RmTpT8': 'rmtpt8',
#  'RmTpT9': 'rmtpt9',
#  'RmTpT10': 'rmtpt10',
#  'RPEA1': 'rpea1',
#  'RPEA2': 'rpea2',
#  'RPEA3': 'rpea3',
#  'RPEA4': 'rpea4',
#  'RPEA5': 'rpea5',
#  'RPEA6': 'rpea6',
#  'RPEP1': 'rpep1',
#  'RPEP2': 'rpep2',
#  'RPEP3': 'rpep3',
#  'RPEP4': 'rpep4',
#  'RPEP5': 'rpep5',
#  'RPEP6': 'rpep6',
#  'Fp1': 'fp1',
#  'F7': 'f7',
#  'T3': 't3',
#  'T5': 't5',
#  'O1': 'o1',
#  'F3': 'f3',
#  'C3': 'c3',
#  'P3': 'p3',
#  'Fp2': 'fp2',
#  'F8': 'f8',
#  'T4': 't4',
#  'T6': 't6',
#  'O2': 'o2',
#  'F4': 'f4',
#  'C4': 'c4',
#  'P4': 'p4',
#  'Fz': 'fz',
#  'Cz': 'cz',
#  'Pz': 'pz',
#  'EKG1': 'ekg1',
#  'EKG2': 'ekg2',
#  'RES': 'res',
#  'C173': 'c173',
#  'C174': 'c174',
#  'C175': 'c175',
#  'C176': 'c176',
#  'C177': 'c177',
#  'C178': 'c178',
#  'C179': 'c179',
#  'C180': 'c180',
#  'C181': 'c181',
#  'C182': 'c182',
#  'C183': 'c183',
#  'C184': 'c184',
#  'C185': 'c185',
#  'C186': 'c186',
#  'C187': 'c187',
#  'C188': 'c188',
#  'C189': 'c189',
#  'C190': 'c190',
#  'C191': 'c191',
#  'C192': 'c192',
#  'C193': 'c193',
#  'C194': 'c194',
#  'C195': 'c195',
#  'C196': 'c196',
#  'C197': 'c197',
#  'C198': 'c198',
#  'C199': 'c199',
#  'C200': 'c200',
#  'C201': 'c201',
#  'C202': 'c202',
#  'C203': 'c203',
#  'C204': 'c204',
#  'C205': 'c205',
#  'C206': 'c206',
#  'C207': 'c207',
#  'C208': 'c208',
#  'C209': 'c209',
#  'C210': 'c210',
#  'C211': 'c211',
#  'C212': 'c212',
#  'C213': 'c213',
#  'C214': 'c214',
#  'C215': 'c215',
#  'C216': 'c216',
#  'C217': 'c217',
#  'C218': 'c218',
#  'C219': 'c219',
#  'C220': 'c220',
#  'C221': 'c221',
#  'C222': 'c222',
#  'C223': 'c223',
#  'C224': 'c224',
#  'C225': 'c225',
#  'C226': 'c226',
#  'C227': 'c227',
#  'C228': 'c228',
#  'C229': 'c229',
#  'C230': 'c230',
#  'C231': 'c231',
#  'C232': 'c232',
#  'C233': 'c233',
#  'C234': 'c234',
#  'C235': 'c235',
#  'C236': 'c236',
#  'C237': 'c237',
#  'C238': 'c238',
#  'C239': 'c239',
#  'C240': 'c240',
#  'C241': 'c241',
#  'C242': 'c242',
#  'C243': 'c243',
#  'C244': 'c244',
#  'C245': 'c245',
#  'C246': 'c246',
#  'C247': 'c247',
#  'C248': 'c248',
#  'C249': 'c249',
#  'C250': 'c250',
#  'C251': 'c251',
#  'C252': 'c252',
#  'C253': 'c253',
#  'C254': 'c254',
#  'C255': 'c255',
#  'C256': 'c256',
#  'DC1': 'dc1',
#  'DC2': 'dc2',
#  'DC3': 'dc3',
#  'DC4': 'dc4',
#  'DC5': 'dc5',
#  'DC6': 'dc6',
#  'DC7': 'dc7',
#  'DC8': 'dc8',
#  'DC9': 'dc9',
#  'DC10': 'dc10',
#  'DC11': 'dc11',
#  'DC12': 'dc12',
#  'DC13': 'dc13',
#  'DC14': 'dc14',
#  'DC15': 'dc15',
#  'DC16': 'dc16',
#  'TRIG': 'trig',
#  'OSAT': 'osat',
#  'PR': 'pr',
#  'Pleth': 'pleth'}

# %%
# Rename the mne data according to the localization data
mne_data.rename_channels(new_name_dict)
# Out:
# <RawEDF | MS008_Resting_iEEG.edf, 276 x 678016 (662.1 s), ~1.39 GB, data loaded>

# %%
unmatched_seeg #make sure there are no unmatched names
# Out:
# []

# %%
anat_names = list(elec_locs.label.str.lower())
sum([ch not in mne_data.ch_names for ch in anat_names]) #if there are no missing channels, sum = 0. if sum >0, find the missing elecs
print([ch for ch in mne_data.ch_names if ch not in anat_names ]) 
#print extra channels in mne_data.ch_names and make sure none of them are neural channels
# Out:
# ['c63', 'c64', 'c125', 'c126', 'c127', 'c128', 'fp1', 'f7', 't3', 't5', 'o1', 'f3', 'c3', 'p3', 'fp2', 'f8', 't4', 't6', 'o2', 'f4', 'c4', 'p4', 'fz', 'cz', 'pz', 'ekg1', 'ekg2', 'res', 'c173', 'c174', 'c175', 'c176', 'c177', 'c178', 'c179', 'c180', 'c181', 'c182', 'c183', 'c184', 'c185', 'c186', 'c187', 'c188', 'c189', 'c190', 'c191', 'c192', 'c193', 'c194', 'c195', 'c196', 'c197', 'c198', 'c199', 'c200', 'c201', 'c202', 'c203', 'c204', 'c205', 'c206', 'c207', 'c208', 'c209', 'c210', 'c211', 'c212', 'c213', 'c214', 'c215', 'c216', 'c217', 'c218', 'c219', 'c220', 'c221', 'c222', 'c223', 'c224', 'c225', 'c226', 'c227', 'c228', 'c229', 'c230', 'c231', 'c232', 'c233', 'c234', 'c235', 'c236', 'c237', 'c238', 'c239', 'c240', 'c241', 'c242', 'c243', 'c244', 'c245', 'c246', 'c247', 'c248', 'c249', 'c250', 'c251', 'c252', 'c253', 'c254', 'c255', 'c256', 'dc1', 'dc2', 'dc3', 'dc4', 'dc5', 'dc6', 'dc7', 'dc8', 'dc9', 'dc10', 'dc11', 'dc12', 'dc13', 'dc14', 'dc15', 'dc16', 'trig', 'osat', 'pr', 'pleth']

# %%
# Note, there is surface EEG data that we should separately indicate from the sEEG:
right_seeg_names = [i for i in mne_data.ch_names if i.startswith('r')]
left_seeg_names = [i for i in mne_data.ch_names if i.startswith('l')]
print(f'We have a total of', len(left_seeg_names), 'left &', len(right_seeg_names), 'right sEEG electrodes')
print(f'We have a total of {len(left_seeg_names) + len(right_seeg_names)} sEEG electrodes')
# Out:
# We have a total of 58 left & 87 right sEEG electrodes
# We have a total of 145 sEEG electrodes

# %%
drop_chans = list(set(mne_data.ch_names)^set(left_seeg_names+right_seeg_names)) # it is either called DC1 or research
mne_data.drop_channels(drop_chans) #number of chans should = number of seegs
# Out:
# <RawEDF | MS008_Resting_iEEG.edf, 145 x 678016 (662.1 s), ~750.2 MB, data loaded>

# %%
# Set channel types:
sEEG_mapping_dict = {f'{x}':'seeg' for x in left_seeg_names+right_seeg_names}
mne_data.set_channel_types(sEEG_mapping_dict)
# Out:
# <RawEDF | MS008_Resting_iEEG.edf, 145 x 678016 (662.1 s), ~750.2 MB, data loaded>

# %%
# make montage (convert mm to m)

montage = mne.channels.make_dig_montage(ch_pos=dict(zip(elec_locs.label, 
                                                        elec_locs[['mni_x', 'mni_y', 'mni_z']].to_numpy(dtype=float)/1000)),
                                        coord_frame='mni_tal')

mne_data.set_montage(montage, match_case=False, on_missing='warn')
# Out:
# <RawEDF | MS008_Resting_iEEG.edf, 145 x 678016 (662.1 s), ~750.3 MB, data loaded>

# %% [markdown]
# ### Notch filter line noise

# %%
# Identify line noise
mne_data.info['line_freq'] = 60

# Notch out 60 Hz noise and harmonics 
mne_data.notch_filter(freqs=(60, 120, 180, 240))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 145 out of 145 | elapsed:    2.3s finished
# <RawEDF | MS008_Resting_iEEG.edf, 145 x 678016 (662.1 s), ~750.3 MB, data loaded>

# %% [markdown]
# ### Resampling data

# %%
resample_sr = 500
mne_data.resample(sfreq=resample_sr, npad='auto', n_jobs=-1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 145 out of 145 | elapsed:    1.9s finished
# <RawEDF | MS008_Resting_iEEG.edf, 145 x 331062 (662.1 s), ~366.4 MB, data loaded>

# %% [markdown]
# ### Bad Channel Removal (manual)

# %% [markdown]
# Let's pick out any bad channels missed by automatic screening (visual inspection as a reference), or restore channels that were erroneously deemed bad. You have to press the "power" button twice (once for the plot and once for the panel beneath it) when you're done so that you're manual changes are saved.

# %%
mne_data = mne.io.read_raw_fif(f'{save_dir}/{subj_id}_raw_ieeg.fif', preload=True)

# %%
# %matplotlib notebook

fig = mne_data.plot(start=0, duration=120, n_channels=50, scalings=mne_data._data.max()/20)
fig.fake_keypress('a') #lots of bad times
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
mne_data.info['bads'] #sanity check that bads info saved
# Out:
# ['lmcms8', 'racas4', 'rmcms8', 'rhpo16', 'rhpo15', 'rhpo14', 'res']

# %% [markdown]
# ## Save raw LFP data
# Notch filtered and resampled with bad elecs indicated

# %%
mne_data.save(f'{save_dir}/{subj_id}_raw_ieeg.fif',overwrite=True)

# %% [markdown]
# # Rereference data

# %% [markdown]
# To start annotating, press 'Add new label' in the bottom panel. Then left click and drag around window of interest.

# %%
# Re-reference neural data
anat_file = glob(f'{anat_dir}/{subj_id}_labels.csv')[0]

mne_data_bp_reref = lfp_preprocess_utils.ref_mne(mne_data=mne_data, 
                                              elec_path=anat_file, 
                                              method='bipolar', 
                                              site='MSSM')
# Out:
# Number of electrodes in the mne file is greater than the number of electrodes in the localization file

# %%
# %matplotlib notebook
# use the epoch code to select only the WM referenced pairs
fig = mne_data_bp_reref.plot(start=2, duration=100, n_channels=50,scalings=mne_data._data.max()/20 ) # plot all channels at once
fig.fake_keypress("a")
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
mne_data_bp_reref.compute_psd().plot()
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
# <img src="data:image/png;base64,..." width="999.999985098839">

# %% [markdown]
# ### Save reref data

# %%
mne_data_bp_reref.save(f'{save_dir}/{subj_id}_bp_ref_ieeg.fif',overwrite=True)
