# %% [markdown]
# # Preprocess Continuous Data - Resting State
# ## MS012
#
# 10/03/2023
# Updated: 02/26/2024

# %%
import numpy as np
import mne
from glob import glob
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from scipy.stats import zscore, linregress, ttest_ind, ttest_rel, ttest_1samp
import pandas as pd
from mne.preprocessing.bads import _find_outliers
import os 
import joblib
import emd
import re

import warnings
warnings.filterwarnings('ignore')
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
import sys
sys.path.append('/Users/alexandrafink/Documents/GitHub/LFPAnalysis')

# %%
from LFPAnalysis import lfp_preprocess_utils, sync_utils, analysis_utils, nlx_utils

# %%
subj_id = 'MS012'

# Specify root directory for data and results 
base_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/resting_state_proj/resting_state_ieeg/'
anat_dir = f'{base_dir}anat'
neural_dir = f'{base_dir}preprocess/raw_data/{subj_id}'
save_dir = f'{base_dir}preprocess/clean_data/{subj_id}'
os.makedirs(save_dir,exist_ok = True)

# %% [markdown]
# #### Import Data

# %%
edf_files = glob(f'{neural_dir}/*.edf')

mne_data = mne.io.read_raw_edf(edf_files[0], preload=True)
mne_data
# Out:
# <RawEDF | MS012_Resting_iEEG.edf, 276 x 634048 (619.2 s), ~1.30 GB, data loaded>

# %%
mne_data.ch_names
# Out:
# ['RmOlF1',
#  'RmOlF2',
#  'RmOlF3',
#  'RmOlF4',
#  'RmOlF5',
#  'RmOlF6',
#  'RmOlF7',
#  'RmOlF8',
#  'RmOlF9',
#  'RmOlF10',
#  'RmOlF11',
#  'RmOlF12',
#  'RaCaS1',
#  'RaCaS2',
#  'RaCaS3',
#  'RaCaS4',
#  'RaCaS5',
#  'RaCaS6',
#  'RaCaS7',
#  'RaCaS8',
#  'RaCaS9',
#  'RaCaS10',
#  'RmCmS1',
#  'RmCmS2',
#  'RmCmS3',
#  'RmCmS4',
#  'RmCmS5',
#  'RmCmS6',
#  'RmCmS7',
#  'RmCmS8',
#  'RmCmS9',
#  'RmCmS10',
#  'RalS1',
#  'RalS2',
#  'RalS3',
#  'RalS4',
#  'RalS5',
#  'RalS6',
#  'RalS7',
#  'RalS8',
#  'RalS9',
#  'RalS10',
#  'RalS11',
#  'RalS12',
#  'RalS13',
#  'RalS14',
#  'RmlS1',
#  'RmlS2',
#  'RmlS3',
#  'RmlS4',
#  'RmlS5',
#  'RmlS6',
#  'RmlS7',
#  'RmlS8',
#  'RmlS9',
#  'RmlS10',
#  'RmlS11',
#  'RmlS12',
#  'RplS11',
#  'RplS12',
#  'RplS13',
#  'RplS14',
#  'RplS15',
#  'RplS16',
#  'RplS17',
#  'RplS18',
#  'RplS19',
#  'RplS110',
#  'RplS111',
#  'RplS112',
#  'RplS113',
#  'RplS114',
#  'RplS115',
#  'RplS116',
#  'RAglT1',
#  'RAglT2',
#  'RAglT3',
#  'RAglT4',
#  'RAglT5',
#  'RAglT6',
#  'RAglT7',
#  'RAglT8',
#  'RAglT9',
#  'RAglT10',
#  'RHplT1',
#  'RHplT2',
#  'RHplT3',
#  'RHplT4',
#  'RHplT5',
#  'RHplT6',
#  'RHplT7',
#  'RHplT8',
#  'RHplT9',
#  'RHplT10',
#  'RmTpT1',
#  'RmTpT2',
#  'RmTpT3',
#  'RmTpT4',
#  'RmTpT5',
#  'RmTpT6',
#  'RmTpT7',
#  'RmTpT8',
#  'RmTpT9',
#  'RmTpT10',
#  'FP1',
#  'F7',
#  'T3',
#  'T5',
#  'O1',
#  'F3',
#  'C3',
#  'P3',
#  'FP2',
#  'F8',
#  'T4',
#  'T6',
#  'O2',
#  'F4',
#  'C4',
#  'P4',
#  'FZ',
#  'CZ',
#  'PZ',
#  'EKG1',
#  'EKG2',
#  'chest1',
#  'chest2',
#  'ABD1',
#  'ABD2',
#  'C130',
#  'C131',
#  'C132',
#  'C133',
#  'C134',
#  'C135',
#  'C136',
#  'C137',
#  'C138',
#  'C139',
#  'C140',
#  'C141',
#  'C142',
#  'C143',
#  'C144',
#  'C145',
#  'C146',
#  'C147',
#  'C148',
#  'C149',
#  'C150',
#  'C151',
#  'C152',
#  'C153',
#  'C154',
#  'C155',
#  'C156',
#  'C157',
#  'C158',
#  'C159',
#  'C160',
#  'C161',
#  'C162',
#  'C163',
#  'C164',
#  'C165',
#  'C166',
#  'C167',
#  'C168',
#  'C169',
#  'C170',
#  'C171',
#  'C172',
#  'C173',
#  'C174',
#  'C175',
#  'C176',
#  'C177',
#  'C178',
#  'C179',
#  'C180',
#  'C181',
#  'C182',
#  'C183',
#  'C184',
#  'C185',
#  'C186',
#  'C187',
#  'C188',
#  'C189',
#  'C190',
#  'C191',
#  'C192',
#  'C193',
#  'C194',
#  'C195',
#  'C196',
#  'C197',
#  'C198',
#  'C199',
#  'C200',
#  'C201',
#  'C202',
#  'C203',
#  'C204',
#  'C205',
#  'C206',
#  'C207',
#  'C208',
#  'C209',
#  'C210',
#  'C211',
#  'C212',
#  'C213',
#  'C214',
#  'C215',
#  'C216',
#  'C217',
#  'C218',
#  'C219',
#  'C220',
#  'C221',
#  'C222',
#  'C223',
#  'C224',
#  'C225',
#  'C226',
#  'C227',
#  'C228',
#  'C229',
#  'C230',
#  'C231',
#  'C232',
#  'C233',
#  'C234',
#  'C235',
#  'C236',
#  'C237',
#  'C238',
#  'C239',
#  'C240',
#  'C241',
#  'C242',
#  'C243',
#  'C244',
#  'C245',
#  'C246',
#  'C247',
#  'C248',
#  'C249',
#  'C250',
#  'C251',
#  'C252',
#  'C253',
#  'C254',
#  'C255',
#  'C256',
#  'Research',
#  'DC2',
#  'DC3',
#  'DC4',
#  'DC5',
#  'DC6',
#  'DC7',
#  'DC8',
#  'DC9',
#  'DC10',
#  'DC11',
#  'DC12',
#  'DC13',
#  'DC14',
#  'DC15',
#  'DC16',
#  'TRIG',
#  'OSAT',
#  'PR',
#  'Pleth']

# %% [markdown]
# # Import Anat Recon Info - check all elecs are present in data + recon sheet

# %%
# Load the electrode localization data
anat_file = glob(f'{anat_dir}/{subj_id}_labels.csv')[0]
elec_locs = pd.read_csv(anat_file)
# Sometimes there's extra columns with no entries: 
elec_locs = elec_locs[elec_locs.columns.drop(list(elec_locs.filter(regex='Unnamed')))]
elec_locs = elec_locs.dropna(axis=0, how = 'all')
elec_locs
# Out:
#        label BN246label          x          y          z      mni_x  \
# 0     RaCaS1    A24rv_R   2.213847  40.555422  -7.592365   4.000299
# 1    RaCaS10      A9l_R  12.608599  57.336974  29.969887  15.494926
# 2     RaCaS2    A24rv_R   3.413242  42.153665  -3.596380   5.193647
# 3     RaCaS3    A24rv_R   4.612636  43.352347   1.198800   6.248130
# 4     RaCaS4    A24rv_R   5.812031  44.950590   5.594383   7.611961
# ..       ...        ...        ...        ...        ...        ...
# 99    RplS15        G_R  30.999314  -6.992307   3.596391  35.220487
# 100   RplS16        G_R  30.599516 -10.987915   7.192777  34.940151
# 101   RplS17    Unknown  30.199718 -14.983522  10.789163  34.688592
# 102   RplS18    Unknown  29.799920 -18.979129  14.385548  34.226653
# 103   RplS19    Unknown  29.000324 -22.974737  18.381532  33.301022
#
#          mni_y      mni_z     gm                                  NMM  \
# 0    31.589838  -7.086648   Gray  Right ACgG anterior cingulate gyrus
# 1    46.622420  42.064551   Gray     Right SFG superior frontal gyrus
# 2    33.135858  -1.753866   Gray  Right ACgG anterior cingulate gyrus
# 3    34.246815   4.546188   Gray  Right ACgG anterior cingulate gyrus
# 4    35.782938  10.284493   Gray  Right ACgG anterior cingulate gyrus
# ..         ...        ...    ...                                  ...
# 99  -20.101441   1.856086   Gray          Right PIns posterior insula
# 100 -24.533599   5.788729   Gray               Right PP planum polare
# 101 -29.067621   9.718461  White          Right Cerebral White Matter
# 102 -33.595343  13.608131  White          Right Cerebral White Matter
# 103 -38.064898  17.971963  White          Right Cerebral White Matter
#
#            Anat                  AnatMacro    BN246  \
# 0      Area s24                      R ACC     R CG
# 1       Unknown   R Superior Frontal Gyrus    R SFG
# 2       Area 33                      R ACC     R CG
# 3       Area 33                      R ACC     R CG
# 4       Area 33                      R ACC     R CG
# ..          ...                        ...      ...
# 99     Area Ig1              R Insula Lobe    R INS
# 100    Area Ig1                    Unknown    R INS
# 101  Area TE 11  R Superior Temporal Gyrus  Unknown
# 102  Area TE 11                    Unknown  Unknown
# 103     Unknown                    Unknown  Unknown
#
#                                     YBA_1 Manual Examination Notes
# 0                 Right cingulate gyrus D                NaN   NaN
# 1        Right superior frontal gyrus 2 C                NaN   NaN
# 2                 Right cingulate gyrus D                NaN   NaN
# 3                 Right cingulate gyrus E                NaN   NaN
# 4                 Right cingulate gyrus F                 WM   NaN
# ..                                    ...                ...   ...
# 99   Right posterior long insular gyrus B                NaN   NaN
# 100  Right posterior long insular gyrus A                NaN   NaN
# 101       Right superior temporal gyrus E                 WM   NaN
# 102       Right superior temporal gyrus F                 WM   NaN
# 103                               Unknown                 WM   NaN
#
# [104 rows x 16 columns]

# %% [markdown]
# ### Fix edf channel names

# %%
new_mne_names, unmatched_names, unmatched_seeg = lfp_preprocess_utils.match_elec_names(mne_data.ch_names, elec_locs.label)
# Out:
# Number of electrodes in the mne file is greater than the number of electrodes in the localization file

# %%
unmatched_names
# Out:
# []

# %%
unmatched_seeg
# Out:
# []

# %%
new_name_dict = {x:y for (x,y) in zip(mne_data.ch_names, new_mne_names)}
new_name_dict
# Out:
# {'RmOlF1': 'rmolf1',
#  'RmOlF2': 'rmolf2',
#  'RmOlF3': 'rmolf3',
#  'RmOlF4': 'rmolf4',
#  'RmOlF5': 'rmolf5',
#  'RmOlF6': 'rmolf6',
#  'RmOlF7': 'rmolf7',
#  'RmOlF8': 'rmolf8',
#  'RmOlF9': 'rmolf9',
#  'RmOlF10': 'rmolf10',
#  'RmOlF11': 'rmolf11',
#  'RmOlF12': 'rmolf12',
#  'RaCaS1': 'racas1',
#  'RaCaS2': 'racas2',
#  'RaCaS3': 'racas3',
#  'RaCaS4': 'racas4',
#  'RaCaS5': 'racas5',
#  'RaCaS6': 'racas6',
#  'RaCaS7': 'racas7',
#  'RaCaS8': 'racas8',
#  'RaCaS9': 'racas9',
#  'RaCaS10': 'racas10',
#  'RmCmS1': 'rmcms1',
#  'RmCmS2': 'rmcms2',
#  'RmCmS3': 'rmcms3',
#  'RmCmS4': 'rmcms4',
#  'RmCmS5': 'rmcms5',
#  'RmCmS6': 'rmcms6',
#  'RmCmS7': 'rmcms7',
#  'RmCmS8': 'rmcms8',
#  'RmCmS9': 'rmcms9',
#  'RmCmS10': 'rmcms10',
#  'RalS1': 'rals1',
#  'RalS2': 'rals2',
#  'RalS3': 'rals3',
#  'RalS4': 'rals4',
#  'RalS5': 'rals5',
#  'RalS6': 'rals6',
#  'RalS7': 'rals7',
#  'RalS8': 'rals8',
#  'RalS9': 'rals9',
#  'RalS10': 'rals10',
#  'RalS11': 'rals11',
#  'RalS12': 'rals12',
#  'RalS13': 'rals13',
#  'RalS14': 'rals14',
#  'RmlS1': 'rmls1',
#  'RmlS2': 'rmls2',
#  'RmlS3': 'rmls3',
#  'RmlS4': 'rmls4',
#  'RmlS5': 'rmls5',
#  'RmlS6': 'rmls6',
#  'RmlS7': 'rmls7',
#  'RmlS8': 'rmls8',
#  'RmlS9': 'rmls9',
#  'RmlS10': 'rmls10',
#  'RmlS11': 'rmls11',
#  'RmlS12': 'rmls12',
#  'RplS11': 'rpls11',
#  'RplS12': 'rpls12',
#  'RplS13': 'rpls13',
#  'RplS14': 'rpls14',
#  'RplS15': 'rpls15',
#  'RplS16': 'rpls16',
#  'RplS17': 'rpls17',
#  'RplS18': 'rpls18',
#  'RplS19': 'rpls19',
#  'RplS110': 'rpls110',
#  'RplS111': 'rpls111',
#  'RplS112': 'rpls112',
#  'RplS113': 'rpls113',
#  'RplS114': 'rpls114',
#  'RplS115': 'rpls115',
#  'RplS116': 'rpls116',
#  'RAglT1': 'raglt1',
#  'RAglT2': 'raglt2',
#  'RAglT3': 'raglt3',
#  'RAglT4': 'raglt4',
#  'RAglT5': 'raglt5',
#  'RAglT6': 'raglt6',
#  'RAglT7': 'raglt7',
#  'RAglT8': 'raglt8',
#  'RAglT9': 'raglt9',
#  'RAglT10': 'raglt10',
#  'RHplT1': 'rhplt1',
#  'RHplT2': 'rhplt2',
#  'RHplT3': 'rhplt3',
#  'RHplT4': 'rhplt4',
#  'RHplT5': 'rhplt5',
#  'RHplT6': 'rhplt6',
#  'RHplT7': 'rhplt7',
#  'RHplT8': 'rhplt8',
#  'RHplT9': 'rhplt9',
#  'RHplT10': 'rhplt10',
#  'RmTpT1': 'rmtpt1',
#  'RmTpT2': 'rmtpt2',
#  'RmTpT3': 'rmtpt3',
#  'RmTpT4': 'rmtpt4',
#  'RmTpT5': 'rmtpt5',
#  'RmTpT6': 'rmtpt6',
#  'RmTpT7': 'rmtpt7',
#  'RmTpT8': 'rmtpt8',
#  'RmTpT9': 'rmtpt9',
#  'RmTpT10': 'rmtpt10',
#  'FP1': 'fp1',
#  'F7': 'f7',
#  'T3': 't3',
#  'T5': 't5',
#  'O1': 'o1',
#  'F3': 'f3',
#  'C3': 'c3',
#  'P3': 'p3',
#  'FP2': 'fp2',
#  'F8': 'f8',
#  'T4': 't4',
#  'T6': 't6',
#  'O2': 'o2',
#  'F4': 'f4',
#  'C4': 'c4',
#  'P4': 'p4',
#  'FZ': 'fz',
#  'CZ': 'cz',
#  'PZ': 'pz',
#  'EKG1': 'ekg1',
#  'EKG2': 'ekg2',
#  'chest1': 'chest1',
#  'chest2': 'chest2',
#  'ABD1': 'abd1',
#  'ABD2': 'abd2',
#  'C130': 'c130',
#  'C131': 'c131',
#  'C132': 'c132',
#  'C133': 'c133',
#  'C134': 'c134',
#  'C135': 'c135',
#  'C136': 'c136',
#  'C137': 'c137',
#  'C138': 'c138',
#  'C139': 'c139',
#  'C140': 'c140',
#  'C141': 'c141',
#  'C142': 'c142',
#  'C143': 'c143',
#  'C144': 'c144',
#  'C145': 'c145',
#  'C146': 'c146',
#  'C147': 'c147',
#  'C148': 'c148',
#  'C149': 'c149',
#  'C150': 'c150',
#  'C151': 'c151',
#  'C152': 'c152',
#  'C153': 'c153',
#  'C154': 'c154',
#  'C155': 'c155',
#  'C156': 'c156',
#  'C157': 'c157',
#  'C158': 'c158',
#  'C159': 'c159',
#  'C160': 'c160',
#  'C161': 'c161',
#  'C162': 'c162',
#  'C163': 'c163',
#  'C164': 'c164',
#  'C165': 'c165',
#  'C166': 'c166',
#  'C167': 'c167',
#  'C168': 'c168',
#  'C169': 'c169',
#  'C170': 'c170',
#  'C171': 'c171',
#  'C172': 'c172',
#  'C173': 'c173',
#  'C174': 'c174',
#  'C175': 'c175',
#  'C176': 'c176',
#  'C177': 'c177',
#  'C178': 'c178',
#  'C179': 'c179',
#  'C180': 'c180',
#  'C181': 'c181',
#  'C182': 'c182',
#  'C183': 'c183',
#  'C184': 'c184',
#  'C185': 'c185',
#  'C186': 'c186',
#  'C187': 'c187',
#  'C188': 'c188',
#  'C189': 'c189',
#  'C190': 'c190',
#  'C191': 'c191',
#  'C192': 'c192',
#  'C193': 'c193',
#  'C194': 'c194',
#  'C195': 'c195',
#  'C196': 'c196',
#  'C197': 'c197',
#  'C198': 'c198',
#  'C199': 'c199',
#  'C200': 'c200',
#  'C201': 'c201',
#  'C202': 'c202',
#  'C203': 'c203',
#  'C204': 'c204',
#  'C205': 'c205',
#  'C206': 'c206',
#  'C207': 'c207',
#  'C208': 'c208',
#  'C209': 'c209',
#  'C210': 'c210',
#  'C211': 'c211',
#  'C212': 'c212',
#  'C213': 'c213',
#  'C214': 'c214',
#  'C215': 'c215',
#  'C216': 'c216',
#  'C217': 'c217',
#  'C218': 'c218',
#  'C219': 'c219',
#  'C220': 'c220',
#  'C221': 'c221',
#  'C222': 'c222',
#  'C223': 'c223',
#  'C224': 'c224',
#  'C225': 'c225',
#  'C226': 'c226',
#  'C227': 'c227',
#  'C228': 'c228',
#  'C229': 'c229',
#  'C230': 'c230',
#  'C231': 'c231',
#  'C232': 'c232',
#  'C233': 'c233',
#  'C234': 'c234',
#  'C235': 'c235',
#  'C236': 'c236',
#  'C237': 'c237',
#  'C238': 'c238',
#  'C239': 'c239',
#  'C240': 'c240',
#  'C241': 'c241',
#  'C242': 'c242',
#  'C243': 'c243',
#  'C244': 'c244',
#  'C245': 'c245',
#  'C246': 'c246',
#  'C247': 'c247',
#  'C248': 'c248',
#  'C249': 'c249',
#  'C250': 'c250',
#  'C251': 'c251',
#  'C252': 'c252',
#  'C253': 'c253',
#  'C254': 'c254',
#  'C255': 'c255',
#  'C256': 'c256',
#  'Research': 'research',
#  'DC2': 'dc2',
#  'DC3': 'dc3',
#  'DC4': 'dc4',
#  'DC5': 'dc5',
#  'DC6': 'dc6',
#  'DC7': 'dc7',
#  'DC8': 'dc8',
#  'DC9': 'dc9',
#  'DC10': 'dc10',
#  'DC11': 'dc11',
#  'DC12': 'dc12',
#  'DC13': 'dc13',
#  'DC14': 'dc14',
#  'DC15': 'dc15',
#  'DC16': 'dc16',
#  'TRIG': 'trig',
#  'OSAT': 'osat',
#  'PR': 'pr',
#  'Pleth': 'pleth'}

# %%
# Rename the mne data according to the localization data
mne_data.rename_channels(new_name_dict)
# Out:
# <RawEDF | MS012_Resting_iEEG.edf, 276 x 634048 (619.2 s), ~1.30 GB, data loaded>

# %%
mne_data.ch_names
# Out:
# ['rmolf1',
#  'rmolf2',
#  'rmolf3',
#  'rmolf4',
#  'rmolf5',
#  'rmolf6',
#  'rmolf7',
#  'rmolf8',
#  'rmolf9',
#  'rmolf10',
#  'rmolf11',
#  'rmolf12',
#  'racas1',
#  'racas2',
#  'racas3',
#  'racas4',
#  'racas5',
#  'racas6',
#  'racas7',
#  'racas8',
#  'racas9',
#  'racas10',
#  'rmcms1',
#  'rmcms2',
#  'rmcms3',
#  'rmcms4',
#  'rmcms5',
#  'rmcms6',
#  'rmcms7',
#  'rmcms8',
#  'rmcms9',
#  'rmcms10',
#  'rals1',
#  'rals2',
#  'rals3',
#  'rals4',
#  'rals5',
#  'rals6',
#  'rals7',
#  'rals8',
#  'rals9',
#  'rals10',
#  'rals11',
#  'rals12',
#  'rals13',
#  'rals14',
#  'rmls1',
#  'rmls2',
#  'rmls3',
#  'rmls4',
#  'rmls5',
#  'rmls6',
#  'rmls7',
#  'rmls8',
#  'rmls9',
#  'rmls10',
#  'rmls11',
#  'rmls12',
#  'rpls11',
#  'rpls12',
#  'rpls13',
#  'rpls14',
#  'rpls15',
#  'rpls16',
#  'rpls17',
#  'rpls18',
#  'rpls19',
#  'rpls110',
#  'rpls111',
#  'rpls112',
#  'rpls113',
#  'rpls114',
#  'rpls115',
#  'rpls116',
#  'raglt1',
#  'raglt2',
#  'raglt3',
#  'raglt4',
#  'raglt5',
#  'raglt6',
#  'raglt7',
#  'raglt8',
#  'raglt9',
#  'raglt10',
#  'rhplt1',
#  'rhplt2',
#  'rhplt3',
#  'rhplt4',
#  'rhplt5',
#  'rhplt6',
#  'rhplt7',
#  'rhplt8',
#  'rhplt9',
#  'rhplt10',
#  'rmtpt1',
#  'rmtpt2',
#  'rmtpt3',
#  'rmtpt4',
#  'rmtpt5',
#  'rmtpt6',
#  'rmtpt7',
#  'rmtpt8',
#  'rmtpt9',
#  'rmtpt10',
#  'fp1',
#  'f7',
#  't3',
#  't5',
#  'o1',
#  'f3',
#  'c3',
#  'p3',
#  'fp2',
#  'f8',
#  't4',
#  't6',
#  'o2',
#  'f4',
#  'c4',
#  'p4',
#  'fz',
#  'cz',
#  'pz',
#  'ekg1',
#  'ekg2',
#  'chest1',
#  'chest2',
#  'abd1',
#  'abd2',
#  'c130',
#  'c131',
#  'c132',
#  'c133',
#  'c134',
#  'c135',
#  'c136',
#  'c137',
#  'c138',
#  'c139',
#  'c140',
#  'c141',
#  'c142',
#  'c143',
#  'c144',
#  'c145',
#  'c146',
#  'c147',
#  'c148',
#  'c149',
#  'c150',
#  'c151',
#  'c152',
#  'c153',
#  'c154',
#  'c155',
#  'c156',
#  'c157',
#  'c158',
#  'c159',
#  'c160',
#  'c161',
#  'c162',
#  'c163',
#  'c164',
#  'c165',
#  'c166',
#  'c167',
#  'c168',
#  'c169',
#  'c170',
#  'c171',
#  'c172',
#  'c173',
#  'c174',
#  'c175',
#  'c176',
#  'c177',
#  'c178',
#  'c179',
#  'c180',
#  'c181',
#  'c182',
#  'c183',
#  'c184',
#  'c185',
#  'c186',
#  'c187',
#  'c188',
#  'c189',
#  'c190',
#  'c191',
#  'c192',
#  'c193',
#  'c194',
#  'c195',
#  'c196',
#  'c197',
#  'c198',
#  'c199',
#  'c200',
#  'c201',
#  'c202',
#  'c203',
#  'c204',
#  'c205',
#  'c206',
#  'c207',
#  'c208',
#  'c209',
#  'c210',
#  'c211',
#  'c212',
#  'c213',
#  'c214',
#  'c215',
#  'c216',
#  'c217',
#  'c218',
#  'c219',
#  'c220',
#  'c221',
#  'c222',
#  'c223',
#  'c224',
#  'c225',
#  'c226',
#  'c227',
#  'c228',
#  'c229',
#  'c230',
#  'c231',
#  'c232',
#  'c233',
#  'c234',
#  'c235',
#  'c236',
#  'c237',
#  'c238',
#  'c239',
#  'c240',
#  'c241',
#  'c242',
#  'c243',
#  'c244',
#  'c245',
#  'c246',
#  'c247',
#  'c248',
#  'c249',
#  'c250',
#  'c251',
#  'c252',
#  'c253',
#  'c254',
#  'c255',
#  'c256',
#  'research',
#  'dc2',
#  'dc3',
#  'dc4',
#  'dc5',
#  'dc6',
#  'dc7',
#  'dc8',
#  'dc9',
#  'dc10',
#  'dc11',
#  'dc12',
#  'dc13',
#  'dc14',
#  'dc15',
#  'dc16',
#  'trig',
#  'osat',
#  'pr',
#  'pleth']

# %%
anat_names = list(elec_locs.label.str.lower())
sum([ch not in mne_data.ch_names for ch in anat_names]) #if there are no missing channels, sum = 0. if sum >0, find the missing elecs
print([ch for ch in mne_data.ch_names if ch not in anat_names ]) 
#print extra channels in mne_data.ch_names and make sure none of them are neural channels
# Out:
# ['fp1', 'f7', 't3', 't5', 'o1', 'f3', 'c3', 'p3', 'fp2', 'f8', 't4', 't6', 'o2', 'f4', 'c4', 'p4', 'fz', 'cz', 'pz', 'ekg1', 'ekg2', 'chest1', 'chest2', 'abd1', 'abd2', 'c130', 'c131', 'c132', 'c133', 'c134', 'c135', 'c136', 'c137', 'c138', 'c139', 'c140', 'c141', 'c142', 'c143', 'c144', 'c145', 'c146', 'c147', 'c148', 'c149', 'c150', 'c151', 'c152', 'c153', 'c154', 'c155', 'c156', 'c157', 'c158', 'c159', 'c160', 'c161', 'c162', 'c163', 'c164', 'c165', 'c166', 'c167', 'c168', 'c169', 'c170', 'c171', 'c172', 'c173', 'c174', 'c175', 'c176', 'c177', 'c178', 'c179', 'c180', 'c181', 'c182', 'c183', 'c184', 'c185', 'c186', 'c187', 'c188', 'c189', 'c190', 'c191', 'c192', 'c193', 'c194', 'c195', 'c196', 'c197', 'c198', 'c199', 'c200', 'c201', 'c202', 'c203', 'c204', 'c205', 'c206', 'c207', 'c208', 'c209', 'c210', 'c211', 'c212', 'c213', 'c214', 'c215', 'c216', 'c217', 'c218', 'c219', 'c220', 'c221', 'c222', 'c223', 'c224', 'c225', 'c226', 'c227', 'c228', 'c229', 'c230', 'c231', 'c232', 'c233', 'c234', 'c235', 'c236', 'c237', 'c238', 'c239', 'c240', 'c241', 'c242', 'c243', 'c244', 'c245', 'c246', 'c247', 'c248', 'c249', 'c250', 'c251', 'c252', 'c253', 'c254', 'c255', 'c256', 'research', 'dc2', 'dc3', 'dc4', 'dc5', 'dc6', 'dc7', 'dc8', 'dc9', 'dc10', 'dc11', 'dc12', 'dc13', 'dc14', 'dc15', 'dc16', 'trig', 'osat', 'pr', 'pleth']

# %%
# Note, there is surface EEG data that we should separately indicate from the sEEG:
right_seeg_names = [i for i in mne_data.ch_names if i.startswith('r')]
left_seeg_names = [i for i in mne_data.ch_names if i.startswith('l')]
print(f'We have a total of', len(left_seeg_names), 'left &', len(right_seeg_names), 'right sEEG electrodes')
print(f'We have a total of {len(left_seeg_names) + len(right_seeg_names)} sEEG electrodes')
# Out:
# We have a total of 0 left & 105 right sEEG electrodes
# We have a total of 105 sEEG electrodes

# %%
drop_chans = list(set(mne_data.ch_names)^set(left_seeg_names+right_seeg_names)) # it is either called DC1 or research
mne_data.drop_channels(drop_chans) #number of chans should = number of seegs
# Out:
# <RawEDF | MS012_Resting_iEEG.edf, 105 x 634048 (619.2 s), ~508.0 MB, data loaded>

# %%
# Set channel types:
sEEG_mapping_dict = {f'{x}':'seeg' for x in left_seeg_names+right_seeg_names}
mne_data.set_channel_types(sEEG_mapping_dict)
# Out:
# <RawEDF | MS012_Resting_iEEG.edf, 105 x 634048 (619.2 s), ~508.0 MB, data loaded>

# %%
mne_data.drop_channels(['research'])
# Out:
# <RawEDF | MS012_Resting_iEEG.edf, 104 x 634048 (619.2 s), ~503.2 MB, data loaded>

# %%
# make montage (convert mm to m)

montage = mne.channels.make_dig_montage(ch_pos=dict(zip(elec_locs.label, 
                                                        elec_locs[['mni_x', 'mni_y', 'mni_z']].to_numpy(dtype=float)/1000)),
                                        coord_frame='mni_tal')

mne_data.set_montage(montage, match_case=False, on_missing='warn')
# Out:
# <RawEDF | MS012_Resting_iEEG.edf, 104 x 634048 (619.2 s), ~503.2 MB, data loaded>

# %% [markdown]
# ### Notch filter line noise

# %%
# Identify line noise
mne_data.info['line_freq'] = 60

# Notch out 60 Hz noise and harmonics 
mne_data.notch_filter(freqs=(60, 120, 180, 240))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 104 out of 104 | elapsed:    1.4s finished
# <RawEDF | MS012_Resting_iEEG.edf, 104 x 634048 (619.2 s), ~503.2 MB, data loaded>

# %% [markdown]
# ### Resampling data

# %%
resample_sr = 500
mne_data.resample(sfreq=resample_sr, npad='auto', n_jobs=-1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 104 out of 104 | elapsed:    3.1s finished
# <RawEDF | MS012_Resting_iEEG.edf, 104 x 309594 (619.2 s), ~245.8 MB, data loaded>

# %% [markdown]
# ### Bad Channel Removal (manual)

# %% [markdown]
# Let's pick out any bad channels missed by automatic screening (visual inspection as a reference), or restore channels that were erroneously deemed bad. You have to press the "power" button twice (once for the plot and once for the panel beneath it) when you're done so that you're manual changes are saved.

# %%
mne_data = mne.io.read_raw_fif(f'{save_dir}/{subj_id}_raw_ieeg.fif', preload=True)

# %%
# %matplotlib notebook

fig = mne_data.plot(start=0, duration=120, n_channels=50, scalings=mne_data._data.max()/20)
fig.fake_keypress('a') #lots of bad times
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
mne_data.info['bads'] #sanity check that bads info saved
# Out:
# ['raglt7', 'rmcms1', 'rmolf10', 'rmolf3', 'rmtpt10', 'rmtpt9', 'rhplt9']

# %% [markdown]
# ## Save raw LFP data
# Notch filtered and resampled with bad elecs indicated

# %%
mne_data.save(f'{save_dir}/{subj_id}_raw_ieeg.fif',overwrite=True)

# %% [markdown]
# # Rereference data

# %% [markdown]
# To start annotating, press 'Add new label' in the bottom panel. Then left click and drag around window of interest.

# %%
# Re-reference neural data
anat_file = glob(f'{anat_dir}/{subj_id}_labels.csv')[0]

mne_data_bp_reref = lfp_preprocess_utils.ref_mne(mne_data=mne_data, 
                                              elec_path=anat_file, 
                                              method='bipolar', 
                                              site='MSSM')

# %%
# %matplotlib notebook

fig = mne_data_bp_reref.plot(start=2, duration=100, n_channels=50,scalings=mne_data._data.max()/20 ) # plot all channels at once
fig.fake_keypress("a")
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
mne_data_bp_reref.compute_psd().plot()
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
# <img src="data:image/png;base64,..." width="999.999985098839">

# %% [markdown]
# ### Save reref data

# %%
mne_data_bp_reref.save(f'{save_dir}/{subj_id}_bp_ref_ieeg.fif',overwrite=True)
