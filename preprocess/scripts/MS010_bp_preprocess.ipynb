# %% [markdown]
# # Preprocess Continuous Data - Resting State
# ## MS010
#
# 10/01/2023
# Updated: 02/26/2024

# %%
import numpy as np
import mne
from glob import glob
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from scipy.stats import zscore, linregress, ttest_ind, ttest_rel, ttest_1samp
import pandas as pd
from mne.preprocessing.bads import _find_outliers
import os 
import joblib
import emd
import re

import warnings
warnings.filterwarnings('ignore')
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
import sys
sys.path.append('/Users/alexandrafink/Documents/GitHub/LFPAnalysis')

# %%
from LFPAnalysis import lfp_preprocess_utils, sync_utils, analysis_utils, nlx_utils

# %%
subj_id = 'MS010'

# Specify root directory for data and results 
base_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/resting_state_proj/resting_state_ieeg/'
anat_dir = f'{base_dir}anat'
neural_dir = f'{base_dir}preprocess/raw_data/{subj_id}'
save_dir = f'{base_dir}preprocess/clean_data/{subj_id}'
os.makedirs(save_dir,exist_ok = True)

# %% [markdown]
# #### Import Data

# %%
edf_files = glob(f'{neural_dir}/*.edf')

mne_data = mne.io.read_raw_edf(edf_files[0], preload=True)
mne_data
# Out:
# <RawEDF | MS010_Resting_iEEG.edf, 276 x 665024 (649.4 s), ~1.37 GB, data loaded>

# %%
mne_data.ch_names
# Out:
# ['RmOlF21',
#  'RmOlF22',
#  'RmOlF23',
#  'RmOlF24',
#  'RmOlF25',
#  'RmOlF26',
#  'RmOlF27',
#  'RmOlF28',
#  'RmOlF29',
#  'LmOlF1',
#  'LmOlF2',
#  'LmOlF3',
#  'LmOlF4',
#  'LmOlF5',
#  'LmOlF6',
#  'LmOlF7',
#  'LmOlF8',
#  'LmOlF9',
#  'RmOlF1',
#  'RmOlF2',
#  'RmOlF3',
#  'RmOlF4',
#  'RmOlF5',
#  'RmOlF6',
#  'RmOlF7',
#  'RmOlF8',
#  'RmOlF9',
#  'RmOlF10',
#  'RmOlF11',
#  'RmOlF12',
#  'RaCaS1',
#  'RaCaS2',
#  'RaCaS3',
#  'RaCaS4',
#  'RaCaS5',
#  'RaCaS6',
#  'RaCaS7',
#  'RaCaS8',
#  'RaCaS9',
#  'RaCaS10',
#  'RaCaS11',
#  'RaCaS12',
#  'RaCaS13',
#  'RaCaS14',
#  'LaCaS1',
#  'LaCaS2',
#  'LaCaS3',
#  'LaCaS4',
#  'LaCaS5',
#  'LaCaS6',
#  'LaCaS7',
#  'LaCaS8',
#  'LaCaS9',
#  'LaCaS10',
#  'LaCaS11',
#  'LaCaS12',
#  'C57',
#  'C58',
#  'C59',
#  'C60',
#  'C61',
#  'C62',
#  'C63',
#  'C64',
#  'RmCmS1',
#  'RmCmS2',
#  'RmCmS3',
#  'RmCmS4',
#  'RmCmS5',
#  'RmCmS6',
#  'RmCmS7',
#  'RmCmS8',
#  'RmCmS9',
#  'RmCmS10',
#  'RaImF1',
#  'RaImF2',
#  'RaImF3',
#  'RaImF4',
#  'RaImF5',
#  'RaImF6',
#  'RaImF7',
#  'RaImF8',
#  'RaImF9',
#  'RaImF10',
#  'RaImF11',
#  'RaImF12',
#  'RmLsL1',
#  'RmLsL2',
#  'RmLsL3',
#  'RmLsL4',
#  'RmLsL5',
#  'RmLsL6',
#  'RmLsL7',
#  'RmLsL8',
#  'RmLsL9',
#  'RmLsL10',
#  'LpOsF1',
#  'LpOsF2',
#  'LpOsF3',
#  'LpOsF4',
#  'LpOsF5',
#  'LpOsF6',
#  'LpOsF7',
#  'LpOsF8',
#  'LpOsF9',
#  'LpOsF10',
#  'LpOsF11',
#  'LpOsF12',
#  'LAgIT1',
#  'LAgIT2',
#  'LAgIT3',
#  'LAgIT4',
#  'LAgIT5',
#  'LAgIT6',
#  'LAgIT7',
#  'LAgIT8',
#  'LAgIT9',
#  'LAgIT10',
#  'RAgIT1',
#  'RAgIT2',
#  'RAgIT3',
#  'RAgIT4',
#  'RAgIT5',
#  'RAgIT6',
#  'RAgIT7',
#  'RAgIT8',
#  'RAgIT9',
#  'RAgIT10',
#  'LHpIT1',
#  'LHpIT2',
#  'LHpIT3',
#  'LHpIT4',
#  'LHpIT5',
#  'LHpIT6',
#  'LHpIT7',
#  'LHpIT8',
#  'LHpIT9',
#  'LHpIT10',
#  'RHpIT1',
#  'RHpIT2',
#  'RHpIT3',
#  'RHpIT4',
#  'RHpIT5',
#  'RHpIT6',
#  'RHpIT7',
#  'RHpIT8',
#  'RHpIT9',
#  'RHpIT10',
#  'Fp1',
#  'F7',
#  'T3',
#  'T5',
#  'O1',
#  'F3',
#  'C3',
#  'P3',
#  'Fp2',
#  'F8',
#  'T4',
#  'T6',
#  'O2',
#  'F4',
#  'C4',
#  'P4',
#  'Fz',
#  'Cz',
#  'Pz',
#  'EKG1',
#  'EKG2',
#  'C170',
#  'C171',
#  'C172',
#  'C173',
#  'C174',
#  'C175',
#  'C176',
#  'C177',
#  'C178',
#  'C179',
#  'C180',
#  'C181',
#  'C182',
#  'C183',
#  'C184',
#  'C185',
#  'C186',
#  'C187',
#  'C188',
#  'C189',
#  'C190',
#  'C191',
#  'C192',
#  'C193',
#  'C194',
#  'C195',
#  'C196',
#  'C197',
#  'C198',
#  'C199',
#  'C200',
#  'C201',
#  'C202',
#  'C203',
#  'C204',
#  'C205',
#  'C206',
#  'C207',
#  'C208',
#  'C209',
#  'C210',
#  'C211',
#  'C212',
#  'C213',
#  'C214',
#  'C215',
#  'C216',
#  'C217',
#  'C218',
#  'C219',
#  'C220',
#  'C221',
#  'C222',
#  'C223',
#  'C224',
#  'C225',
#  'C226',
#  'C227',
#  'C228',
#  'C229',
#  'C230',
#  'C231',
#  'C232',
#  'C233',
#  'C234',
#  'C235',
#  'C236',
#  'C237',
#  'C238',
#  'C239',
#  'C240',
#  'C241',
#  'C242',
#  'C243',
#  'C244',
#  'C245',
#  'C246',
#  'C247',
#  'C248',
#  'C249',
#  'C250',
#  'C251',
#  'C252',
#  'C253',
#  'C254',
#  'C255',
#  'C256',
#  'DC1',
#  'DC2',
#  'DC3',
#  'DC4',
#  'DC5',
#  'DC6',
#  'DC7',
#  'DC8',
#  'DC9',
#  'DC10',
#  'DC11',
#  'DC12',
#  'DC13',
#  'DC14',
#  'DC15',
#  'DC16',
#  'TRIG',
#  'OSAT',
#  'PR',
#  'Pleth']

# %% [markdown]
# # Import Anat Recon Info - check all elecs are present in data + recon sheet

# %%
# Load the electrode localization data
anat_file = glob(f'{anat_dir}/{subj_id}_labels.csv')[0]
elec_locs = pd.read_csv(anat_file)
# Sometimes there's extra columns with no entries: 
elec_locs = elec_locs[elec_locs.columns.drop(list(elec_locs.filter(regex='Unnamed')))]
elec_locs = elec_locs.dropna(axis=0, how = 'all')
elec_locs
# Out:
#        label BN246label          x          y          z      mni_x  \
# 0     LaCaS1    A32sg_L  -3.592187  40.175614  -8.634711  -5.156680
# 1     LaCaS2    A24rv_L  -4.789584  39.775857  -3.843449  -6.082721
# 2     LaCaS3    A24rv_L  -5.986980  39.376100   0.149269  -7.263138
# 3     LaCaS4     A32p_L  -7.184376  38.976342   5.339803  -8.611181
# 4     LaCaS5     A32p_L  -8.381773  38.176828  10.131065  -9.947727
# ..       ...        ...        ...        ...        ...        ...
# 135  RmOlF25    Unknown  24.347062  32.180469 -14.623789  25.775105
# 136  RmOlF26  A12/47l_R  28.737516  32.979983 -12.627430  30.559476
# 137  RmOlF27  A12/47l_R  33.127969  34.179255 -10.631070  35.381554
# 138  RmOlF28    A44op_R  38.316687  35.378527  -8.235439  41.007059
# 139  RmOlF29    A44op_R  41.509744  35.778284  -7.037624  44.445934
#
#          mni_y      mni_z     gm  \
# 0    34.582614  -0.905955   Gray
# 1    34.849200   4.249422   Gray
# 2    35.024753   8.559389  White
# 3    35.391450  14.251972   Gray
# 4    35.286669  19.715878   Gray
# ..         ...        ...    ...
# 135  26.939826  -8.000681  White
# 136  28.328100  -6.336726   Gray
# 137  29.925947  -4.486460   Gray
# 138  31.701540  -2.180106   Gray
# 139  32.316042  -1.066724  White
#
#                                                    NMM     Anat  \
# 0                   Left ACgG anterior cingulate gyrus  Unknown
# 1                   Left ACgG anterior cingulate gyrus  Unknown
# 2                           Left Cerebral White Matter  Unknown
# 3                   Left ACgG anterior cingulate gyrus  Unknown
# 4                   Left ACgG anterior cingulate gyrus  Unknown
# ..                                                 ...      ...
# 135                        Right Cerebral White Matter  Unknown
# 136                   Right LOrG lateral orbital gyrus  Unknown
# 137  Right OrIFG orbital part of the inferior front...  Unknown
# 138  Right OrIFG orbital part of the inferior front...  Unknown
# 139  Right TrIFG triangular part of the inferior fr...  Unknown
#
#                   AnatMacro    BN246                               YBA_1  \
# 0                     L ACC     L CG              Left cingulate gyrus D
# 1                     L ACC     L CG              Left cingulate gyrus E
# 2                     L ACC     L CG              Left cingulate gyrus F
# 3                     L ACC     L CG                             Unknown
# 4                     L ACC     L CG              Left cingulate gyrus G
# ..                      ...      ...                                 ...
# 135                 Unknown  Unknown                             Unknown
# 136     R IFG (p Orbitalis)    R OrG           Right frontal orbital 4 D
# 137     R IFG (p Orbitalis)    R OrG           Right frontal orbital 4 D
# 138     R IFG (p Orbitalis)    R IFG  Right anterior pars triangularis B
# 139  R IFG (p Triangularis)    R IFG  Right anterior pars triangularis B
#
#     Manual Examination Note
# 0                  NaN  NaN
# 1                  NaN  NaN
# 2                   WM  NaN
# 3                   WM  NaN
# 4                  NaN  NaN
# ..                 ...  ...
# 135                 WM  NaN
# 136                NaN  NaN
# 137                OOB  NaN
# 138                NaN  NaN
# 139                 WM  NaN
#
# [140 rows x 16 columns]

# %% [markdown]
# ### Fix edf channel names

# %%
new_mne_names, unmatched_names, unmatched_seeg = lfp_preprocess_utils.match_elec_names(mne_data.ch_names, elec_locs.label)
# Out:
# Number of electrodes in the mne file is greater than the number of electrodes in the localization file

# %%
unmatched_names
# Out:
# []

# %%
unmatched_seeg
# Out:
# []

# %%
new_name_dict = {x:y for (x,y) in zip(mne_data.ch_names, new_mne_names)}
new_name_dict
# Out:
# {'RmOlF21': 'rmolf21',
#  'RmOlF22': 'rmolf22',
#  'RmOlF23': 'rmolf23',
#  'RmOlF24': 'rmolf24',
#  'RmOlF25': 'rmolf25',
#  'RmOlF26': 'rmolf26',
#  'RmOlF27': 'rmolf27',
#  'RmOlF28': 'rmolf28',
#  'RmOlF29': 'rmolf29',
#  'LmOlF1': 'lmolf1',
#  'LmOlF2': 'lmolf2',
#  'LmOlF3': 'lmolf3',
#  'LmOlF4': 'lmolf4',
#  'LmOlF5': 'lmolf5',
#  'LmOlF6': 'lmolf6',
#  'LmOlF7': 'lmolf7',
#  'LmOlF8': 'lmolf8',
#  'LmOlF9': 'lmolf9',
#  'RmOlF1': 'rmolf1',
#  'RmOlF2': 'rmolf2',
#  'RmOlF3': 'rmolf3',
#  'RmOlF4': 'rmolf4',
#  'RmOlF5': 'rmolf5',
#  'RmOlF6': 'rmolf6',
#  'RmOlF7': 'rmolf7',
#  'RmOlF8': 'rmolf8',
#  'RmOlF9': 'rmolf9',
#  'RmOlF10': 'rmolf10',
#  'RmOlF11': 'rmolf11',
#  'RmOlF12': 'rmolf12',
#  'RaCaS1': 'racas1',
#  'RaCaS2': 'racas2',
#  'RaCaS3': 'racas3',
#  'RaCaS4': 'racas4',
#  'RaCaS5': 'racas5',
#  'RaCaS6': 'racas6',
#  'RaCaS7': 'racas7',
#  'RaCaS8': 'racas8',
#  'RaCaS9': 'racas9',
#  'RaCaS10': 'racas10',
#  'RaCaS11': 'racas11',
#  'RaCaS12': 'racas12',
#  'RaCaS13': 'racas13',
#  'RaCaS14': 'racas14',
#  'LaCaS1': 'lacas1',
#  'LaCaS2': 'lacas2',
#  'LaCaS3': 'lacas3',
#  'LaCaS4': 'lacas4',
#  'LaCaS5': 'lacas5',
#  'LaCaS6': 'lacas6',
#  'LaCaS7': 'lacas7',
#  'LaCaS8': 'lacas8',
#  'LaCaS9': 'lacas9',
#  'LaCaS10': 'lacas10',
#  'LaCaS11': 'lacas11',
#  'LaCaS12': 'lacas12',
#  'C57': 'c57',
#  'C58': 'c58',
#  'C59': 'c59',
#  'C60': 'c60',
#  'C61': 'c61',
#  'C62': 'c62',
#  'C63': 'c63',
#  'C64': 'c64',
#  'RmCmS1': 'rmcms1',
#  'RmCmS2': 'rmcms2',
#  'RmCmS3': 'rmcms3',
#  'RmCmS4': 'rmcms4',
#  'RmCmS5': 'rmcms5',
#  'RmCmS6': 'rmcms6',
#  'RmCmS7': 'rmcms7',
#  'RmCmS8': 'rmcms8',
#  'RmCmS9': 'rmcms9',
#  'RmCmS10': 'rmcms10',
#  'RaImF1': 'raimf1',
#  'RaImF2': 'raimf2',
#  'RaImF3': 'raimf3',
#  'RaImF4': 'raimf4',
#  'RaImF5': 'raimf5',
#  'RaImF6': 'raimf6',
#  'RaImF7': 'raimf7',
#  'RaImF8': 'raimf8',
#  'RaImF9': 'raimf9',
#  'RaImF10': 'raimf10',
#  'RaImF11': 'raimf11',
#  'RaImF12': 'raimf12',
#  'RmLsL1': 'rmlsl1',
#  'RmLsL2': 'rmlsl2',
#  'RmLsL3': 'rmlsl3',
#  'RmLsL4': 'rmlsl4',
#  'RmLsL5': 'rmlsl5',
#  'RmLsL6': 'rmlsl6',
#  'RmLsL7': 'rmlsl7',
#  'RmLsL8': 'rmlsl8',
#  'RmLsL9': 'rmlsl9',
#  'RmLsL10': 'rmlsl10',
#  'LpOsF1': 'lposf1',
#  'LpOsF2': 'lposf2',
#  'LpOsF3': 'lposf3',
#  'LpOsF4': 'lposf4',
#  'LpOsF5': 'lposf5',
#  'LpOsF6': 'lposf6',
#  'LpOsF7': 'lposf7',
#  'LpOsF8': 'lposf8',
#  'LpOsF9': 'lposf9',
#  'LpOsF10': 'lposf10',
#  'LpOsF11': 'lposf11',
#  'LpOsF12': 'lposf12',
#  'LAgIT1': 'laglt1',
#  'LAgIT2': 'laglt2',
#  'LAgIT3': 'laglt3',
#  'LAgIT4': 'laglt4',
#  'LAgIT5': 'laglt5',
#  'LAgIT6': 'laglt6',
#  'LAgIT7': 'laglt7',
#  'LAgIT8': 'laglt8',
#  'LAgIT9': 'laglt9',
#  'LAgIT10': 'laglt10',
#  'RAgIT1': 'ragit1',
#  'RAgIT2': 'ragit2',
#  'RAgIT3': 'ragit3',
#  'RAgIT4': 'ragit4',
#  'RAgIT5': 'ragit5',
#  'RAgIT6': 'ragit6',
#  'RAgIT7': 'ragit7',
#  'RAgIT8': 'ragit8',
#  'RAgIT9': 'ragit9',
#  'RAgIT10': 'ragit10',
#  'LHpIT1': 'lhplt1',
#  'LHpIT2': 'lhplt2',
#  'LHpIT3': 'lhplt3',
#  'LHpIT4': 'lhplt4',
#  'LHpIT5': 'lhplt5',
#  'LHpIT6': 'lhplt6',
#  'LHpIT7': 'lhplt7',
#  'LHpIT8': 'lhplt8',
#  'LHpIT9': 'lhplt9',
#  'LHpIT10': 'lhplt10',
#  'RHpIT1': 'rhpit1',
#  'RHpIT2': 'rhpit2',
#  'RHpIT3': 'rhpit3',
#  'RHpIT4': 'rhpit4',
#  'RHpIT5': 'rhpit5',
#  'RHpIT6': 'rhpit6',
#  'RHpIT7': 'rhpit7',
#  'RHpIT8': 'rhpit8',
#  'RHpIT9': 'rhpit9',
#  'RHpIT10': 'rhpit10',
#  'Fp1': 'fp1',
#  'F7': 'f7',
#  'T3': 't3',
#  'T5': 't5',
#  'O1': 'o1',
#  'F3': 'f3',
#  'C3': 'c3',
#  'P3': 'p3',
#  'Fp2': 'fp2',
#  'F8': 'f8',
#  'T4': 't4',
#  'T6': 't6',
#  'O2': 'o2',
#  'F4': 'f4',
#  'C4': 'c4',
#  'P4': 'p4',
#  'Fz': 'fz',
#  'Cz': 'cz',
#  'Pz': 'pz',
#  'EKG1': 'ekg1',
#  'EKG2': 'ekg2',
#  'C170': 'c170',
#  'C171': 'c171',
#  'C172': 'c172',
#  'C173': 'c173',
#  'C174': 'c174',
#  'C175': 'c175',
#  'C176': 'c176',
#  'C177': 'c177',
#  'C178': 'c178',
#  'C179': 'c179',
#  'C180': 'c180',
#  'C181': 'c181',
#  'C182': 'c182',
#  'C183': 'c183',
#  'C184': 'c184',
#  'C185': 'c185',
#  'C186': 'c186',
#  'C187': 'c187',
#  'C188': 'c188',
#  'C189': 'c189',
#  'C190': 'c190',
#  'C191': 'c191',
#  'C192': 'c192',
#  'C193': 'c193',
#  'C194': 'c194',
#  'C195': 'c195',
#  'C196': 'c196',
#  'C197': 'c197',
#  'C198': 'c198',
#  'C199': 'c199',
#  'C200': 'c200',
#  'C201': 'c201',
#  'C202': 'c202',
#  'C203': 'c203',
#  'C204': 'c204',
#  'C205': 'c205',
#  'C206': 'c206',
#  'C207': 'c207',
#  'C208': 'c208',
#  'C209': 'c209',
#  'C210': 'c210',
#  'C211': 'c211',
#  'C212': 'c212',
#  'C213': 'c213',
#  'C214': 'c214',
#  'C215': 'c215',
#  'C216': 'c216',
#  'C217': 'c217',
#  'C218': 'c218',
#  'C219': 'c219',
#  'C220': 'c220',
#  'C221': 'c221',
#  'C222': 'c222',
#  'C223': 'c223',
#  'C224': 'c224',
#  'C225': 'c225',
#  'C226': 'c226',
#  'C227': 'c227',
#  'C228': 'c228',
#  'C229': 'c229',
#  'C230': 'c230',
#  'C231': 'c231',
#  'C232': 'c232',
#  'C233': 'c233',
#  'C234': 'c234',
#  'C235': 'c235',
#  'C236': 'c236',
#  'C237': 'c237',
#  'C238': 'c238',
#  'C239': 'c239',
#  'C240': 'c240',
#  'C241': 'c241',
#  'C242': 'c242',
#  'C243': 'c243',
#  'C244': 'c244',
#  'C245': 'c245',
#  'C246': 'c246',
#  'C247': 'c247',
#  'C248': 'c248',
#  'C249': 'c249',
#  'C250': 'c250',
#  'C251': 'c251',
#  'C252': 'c252',
#  'C253': 'c253',
#  'C254': 'c254',
#  'C255': 'c255',
#  'C256': 'c256',
#  'DC1': 'dc1',
#  'DC2': 'dc2',
#  'DC3': 'dc3',
#  'DC4': 'dc4',
#  'DC5': 'dc5',
#  'DC6': 'dc6',
#  'DC7': 'dc7',
#  'DC8': 'dc8',
#  'DC9': 'dc9',
#  'DC10': 'dc10',
#  'DC11': 'dc11',
#  'DC12': 'dc12',
#  'DC13': 'dc13',
#  'DC14': 'dc14',
#  'DC15': 'dc15',
#  'DC16': 'dc16',
#  'TRIG': 'trig',
#  'OSAT': 'osat',
#  'PR': 'pr',
#  'Pleth': 'pleth'}

# %%
# Rename the mne data according to the localization data
mne_data.rename_channels(new_name_dict)
# Out:
# <RawEDF | MS010_Resting_iEEG.edf, 276 x 665024 (649.4 s), ~1.37 GB, data loaded>

# %%
unmatched_seeg #make sure there are no unmatched names
# Out:
# []

# %%
anat_names = list(elec_locs.label.str.lower())
sum([ch not in mne_data.ch_names for ch in anat_names]) #if there are no missing channels, sum = 0. if sum >0, find the missing elecs
print([ch for ch in mne_data.ch_names if ch not in anat_names ]) 
#print extra channels in mne_data.ch_names and make sure none of them are neural channels
# Out:
# ['c57', 'c58', 'c59', 'c60', 'c61', 'c62', 'c63', 'c64', 'fp1', 'f7', 't3', 't5', 'o1', 'f3', 'c3', 'p3', 'fp2', 'f8', 't4', 't6', 'o2', 'f4', 'c4', 'p4', 'fz', 'cz', 'pz', 'ekg1', 'ekg2', 'c170', 'c171', 'c172', 'c173', 'c174', 'c175', 'c176', 'c177', 'c178', 'c179', 'c180', 'c181', 'c182', 'c183', 'c184', 'c185', 'c186', 'c187', 'c188', 'c189', 'c190', 'c191', 'c192', 'c193', 'c194', 'c195', 'c196', 'c197', 'c198', 'c199', 'c200', 'c201', 'c202', 'c203', 'c204', 'c205', 'c206', 'c207', 'c208', 'c209', 'c210', 'c211', 'c212', 'c213', 'c214', 'c215', 'c216', 'c217', 'c218', 'c219', 'c220', 'c221', 'c222', 'c223', 'c224', 'c225', 'c226', 'c227', 'c228', 'c229', 'c230', 'c231', 'c232', 'c233', 'c234', 'c235', 'c236', 'c237', 'c238', 'c239', 'c240', 'c241', 'c242', 'c243', 'c244', 'c245', 'c246', 'c247', 'c248', 'c249', 'c250', 'c251', 'c252', 'c253', 'c254', 'c255', 'c256', 'dc1', 'dc2', 'dc3', 'dc4', 'dc5', 'dc6', 'dc7', 'dc8', 'dc9', 'dc10', 'dc11', 'dc12', 'dc13', 'dc14', 'dc15', 'dc16', 'trig', 'osat', 'pr', 'pleth']

# %%
# Note, there is surface EEG data that we should separately indicate from the sEEG:
right_seeg_names = [i for i in mne_data.ch_names if i.startswith('r')]
left_seeg_names = [i for i in mne_data.ch_names if i.startswith('l')]
print(f'We have a total of', len(left_seeg_names), 'left &', len(right_seeg_names), 'right sEEG electrodes')
print(f'We have a total of {len(left_seeg_names) + len(right_seeg_names)} sEEG electrodes')
# Out:
# We have a total of 53 left & 87 right sEEG electrodes
# We have a total of 140 sEEG electrodes

# %%
drop_chans = list(set(mne_data.ch_names)^set(left_seeg_names+right_seeg_names)) # it is either called DC1 or research
mne_data.drop_channels(drop_chans) #number of chans should = number of seegs
# Out:
# <RawEDF | MS010_Resting_iEEG.edf, 140 x 665024 (649.4 s), ~710.5 MB, data loaded>

# %%
# Set channel types:
sEEG_mapping_dict = {f'{x}':'seeg' for x in left_seeg_names+right_seeg_names}
mne_data.set_channel_types(sEEG_mapping_dict)
# Out:
# <RawEDF | MS010_Resting_iEEG.edf, 140 x 665024 (649.4 s), ~710.5 MB, data loaded>

# %%
# make montage (convert mm to m)

montage = mne.channels.make_dig_montage(ch_pos=dict(zip(elec_locs.label, 
                                                        elec_locs[['mni_x', 'mni_y', 'mni_z']].to_numpy(dtype=float)/1000)),
                                        coord_frame='mni_tal')

mne_data.set_montage(montage, match_case=False, on_missing='warn')
# Out:
# <RawEDF | MS010_Resting_iEEG.edf, 140 x 665024 (649.4 s), ~710.5 MB, data loaded>

# %% [markdown]
# ### Notch filter line noise

# %%
# Identify line noise
mne_data.info['line_freq'] = 60

# Notch out 60 Hz noise and harmonics 
mne_data.notch_filter(freqs=(60, 120, 180, 240))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 140 out of 140 | elapsed:    2.2s finished
# <RawEDF | MS010_Resting_iEEG.edf, 140 x 665024 (649.4 s), ~710.5 MB, data loaded>

# %% [markdown]
# ### Resampling data

# %%
resample_sr = 500
mne_data.resample(sfreq=resample_sr, npad='auto', n_jobs=-1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 140 out of 140 | elapsed:    3.2s finished
# <RawEDF | MS010_Resting_iEEG.edf, 140 x 324719 (649.4 s), ~347.0 MB, data loaded>

# %% [markdown]
# ### Bad Channel Removal (manual)

# %% [markdown]
# Let's pick out any bad channels missed by automatic screening (visual inspection as a reference), or restore channels that were erroneously deemed bad. You have to press the "power" button twice (once for the plot and once for the panel beneath it) when you're done so that you're manual changes are saved.

# %%
mne_data = mne.io.read_raw_fif(f'{save_dir}/{subj_id}_raw_ieeg.fif', preload=True)

# %%
# %matplotlib notebook

fig = mne_data.plot(start=0, duration=120, n_channels=50, scalings=mne_data._data.max()/20)
fig.fake_keypress('a') #lots of bad times
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
mne_data.info['bads'] #sanity check that bads info saved
# Out:
# ['lacas11', 'rhpit10', 'rmolf12', 'rmolf11', 'rhpit8', 'lhplt4']

# %% [markdown]
# ## Save raw LFP data
# Notch filtered and resampled with bad elecs indicated

# %%
mne_data.save(f'{save_dir}/{subj_id}_raw_ieeg.fif',overwrite=True)

# %% [markdown]
# # Rereference data

# %% [markdown]
# To start annotating, press 'Add new label' in the bottom panel. Then left click and drag around window of interest.

# %%
# Re-reference neural data
anat_file = glob(f'{anat_dir}/{subj_id}_labels.csv')[0]

mne_data_bp_reref = lfp_preprocess_utils.ref_mne(mne_data=mne_data, 
                                              elec_path=anat_file, 
                                              method='bipolar', 
                                              site='MSSM')

# %%
# %matplotlib notebook

fig = mne_data_bp_reref.plot(start=2, duration=100, n_channels=50,scalings=mne_data._data.max()/20 ) # plot all channels at once
fig.fake_keypress("a")
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
mne_data_bp_reref.compute_psd().plot()
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
# <img src="data:image/png;base64,..." width="999.999985098839">

# %% [markdown]
# ### Save reref data

# %%
mne_data_bp_reref.save(f'{save_dir}/{subj_id}_bp_ref_ieeg.fif',overwrite=True)
