# %% [markdown]
# # Preprocess Continuous Data - Resting State
# ## MS016
#
# 10/03/2023
# Updated: 02/26/2024

# %%
import numpy as np
import mne
from glob import glob
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from scipy.stats import zscore, linregress, ttest_ind, ttest_rel, ttest_1samp
import pandas as pd
from mne.preprocessing.bads import _find_outliers
import os 
import joblib
import emd
import re

import warnings
warnings.filterwarnings('ignore')
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
import sys
sys.path.append('/Users/alexandrafink/Documents/GitHub/LFPAnalysis')

# %%
from LFPAnalysis import lfp_preprocess_utils, sync_utils, analysis_utils, nlx_utils

# %%
subj_id = 'MS016'

# Specify root directory for data and results 
base_dir = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/resting_state_proj/resting_state_ieeg/'
anat_dir = f'{base_dir}anat'
neural_dir = f'{base_dir}preprocess/raw_data/{subj_id}'
save_dir = f'{base_dir}preprocess/clean_data/{subj_id}'
os.makedirs(save_dir,exist_ok = True)

# %% [markdown]
# #### Import Data

# %%
edf_files = glob(f'{neural_dir}/*.edf')

mne_data = mne.io.read_raw_edf(edf_files[0], preload=True)
mne_data
# Out:
# <RawEDF | MS016_Resting_iEEG.edf, 276 x 692032 (675.8 s), ~1.42 GB, data loaded>

# %%
mne_data.ch_names
# Out:
# ['LmOIF1',
#  'LmOIF2',
#  'LmOIF3',
#  'LmOIF4',
#  'LmOIF5',
#  'LmOIF6',
#  'LmOIF7',
#  'LmOIF8',
#  'LmOIF9',
#  'LaCaS1',
#  'LaCaS2',
#  'LaCaS3',
#  'LaCaS4',
#  'LaCaS5',
#  'LaCaS6',
#  'LaCaS7',
#  'LaCaS8',
#  'LaCaS9',
#  'LaCaS10',
#  'LaCaS11',
#  'LaCaS12',
#  'LAgIT1',
#  'LAgIT2',
#  'LAgIT3',
#  'LAgIT4',
#  'LAgIT5',
#  'LAgIT6',
#  'LAgIT7',
#  'LAgIT8',
#  'LAgIT9',
#  'LAgIT10',
#  'LAgIT11',
#  'LAgIT12',
#  'LHpIT1',
#  'LHpIT2',
#  'LHpIT3',
#  'LHpIT4',
#  'LHpIT5',
#  'LHpIT6',
#  'LHpIT7',
#  'LHpIT8',
#  'LHpIT9',
#  'LHpIT10',
#  'LILS21',
#  'LILS22',
#  'LILS23',
#  'LILS24',
#  'LILS25',
#  'LILS26',
#  'LmLS31',
#  'LmLS32',
#  'LmLS33',
#  'LmLS34',
#  'LmLS35',
#  'LmLS36',
#  'LmLS37',
#  'LmLS38',
#  'C58',
#  'C59',
#  'C60',
#  'C61',
#  'C62',
#  'C63',
#  'C64',
#  'LILS11',
#  'LILS12',
#  'LILS13',
#  'LILS14',
#  'LILS15',
#  'LILS16',
#  'LILS17',
#  'LILS18',
#  'RAgIT1',
#  'RAgIT2',
#  'RAgIT3',
#  'RAgIT4',
#  'RAgIT5',
#  'RAgIT6',
#  'RAgIT7',
#  'RAgIT8',
#  'RAgIT9',
#  'RHpIT1',
#  'RHpIT2',
#  'RHpIT3',
#  'RHpIT4',
#  'RHpIT5',
#  'RHpIT6',
#  'RHpIT7',
#  'RHpIT8',
#  'RHpIT9',
#  'RHpIT10',
#  'RaCaS1',
#  'RaCaS2',
#  'RaCaS3',
#  'RaCaS4',
#  'RaCaS5',
#  'RaCaS6',
#  'RaCaS7',
#  'RaCaS8',
#  'RaCaS9',
#  'RaCaS10',
#  'RaCaS11',
#  'RaCaS12',
#  'LaImS1',
#  'LaImS2',
#  'LaImS3',
#  'LaImS4',
#  'LaImS5',
#  'LaImS6',
#  'LaImS7',
#  'LaImS8',
#  'LaImS9',
#  'LaImS10',
#  'LaImS11',
#  'LaImS12',
#  'LaImS13',
#  'LaImS14',
#  'LaImS15',
#  'LaImS16',
#  'C120',
#  'C121',
#  'C122',
#  'C123',
#  'C124',
#  'C125',
#  'C126',
#  'C127',
#  'C128',
#  'LmCmS1',
#  'LmCmS2',
#  'LmCmS3',
#  'LmCmS4',
#  'LmCmS5',
#  'LmCmS6',
#  'LmCmS7',
#  'LmCmS8',
#  'LmCmS9',
#  'LmCmS10',
#  'Fp1',
#  'F7',
#  'T3',
#  'T5',
#  'O1',
#  'F3',
#  'C3',
#  'P3',
#  'Fp2',
#  'F8',
#  'T4',
#  'T6',
#  'O2',
#  'F4',
#  'C4',
#  'P4',
#  'Fz',
#  'Cz',
#  'Pz',
#  'EKG1',
#  'EKG2',
#  'C160',
#  'Abs1',
#  'Abs2',
#  'Chest1',
#  'Chest2',
#  'C165',
#  'C166',
#  'C167',
#  'C168',
#  'C169',
#  'C170',
#  'C171',
#  'C172',
#  'C173',
#  'C174',
#  'C175',
#  'C176',
#  'C177',
#  'C178',
#  'C179',
#  'C180',
#  'C181',
#  'C182',
#  'C183',
#  'C184',
#  'C185',
#  'C186',
#  'C187',
#  'C188',
#  'C189',
#  'C190',
#  'C191',
#  'C192',
#  'C193',
#  'C194',
#  'C195',
#  'C196',
#  'C197',
#  'C198',
#  'C199',
#  'C200',
#  'C201',
#  'C202',
#  'C203',
#  'C204',
#  'C205',
#  'C206',
#  'C207',
#  'C208',
#  'C209',
#  'C210',
#  'C211',
#  'C212',
#  'C213',
#  'C214',
#  'C215',
#  'C216',
#  'C217',
#  'C218',
#  'C219',
#  'C220',
#  'C221',
#  'C222',
#  'C223',
#  'C224',
#  'C225',
#  'C226',
#  'C227',
#  'C228',
#  'C229',
#  'C230',
#  'C231',
#  'C232',
#  'C233',
#  'C234',
#  'C235',
#  'C236',
#  'C237',
#  'C238',
#  'C239',
#  'C240',
#  'C241',
#  'C242',
#  'C243',
#  'C244',
#  'C245',
#  'C246',
#  'C247',
#  'C248',
#  'C249',
#  'C250',
#  'C251',
#  'C252',
#  'C253',
#  'C254',
#  'C255',
#  'C256',
#  'DC1',
#  'DC2',
#  'DC3',
#  'DC4',
#  'DC5',
#  'DC6',
#  'DC7',
#  'DC8',
#  'DC9',
#  'DC10',
#  'DC11',
#  'DC12',
#  'DC13',
#  'DC14',
#  'DC15',
#  'DC16',
#  'TRIG',
#  'OSAT',
#  'PR',
#  'Pleth']

# %% [markdown]
# # Import Anat Recon Info - check all elecs are present in data + recon sheet

# %%
# Load the electrode localization data
anat_file = glob(f'{anat_dir}/{subj_id}_labels.csv')[0]
elec_locs = pd.read_csv(anat_file)
# Sometimes there's extra columns with no entries: 
elec_locs = elec_locs[elec_locs.columns.drop(list(elec_locs.filter(regex='Unnamed')))]
elec_locs = elec_locs.dropna(axis=0, how = 'all')
elec_locs
# Out:
#        label BN246label          x          y          z      mni_x  \
# 0     LaCas1    A32sg_L  -4.195963  38.755833   1.548926  -4.923962
# 1     LaCas2    A24rv_L  -6.593655  39.555832   5.546539  -7.498945
# 2     LaCas3    Unknown  -8.991346  40.755832   9.544152 -10.170427
# 3     LaCas4    Unknown -11.389038  41.955831  13.941527 -12.808619
# 4     LaCas5    Unknown -13.786730  43.155830  17.939140 -15.421547
# ..       ...        ...        ...        ...        ...        ...
# 119   RHpIT8     aSTS_R  56.545561   1.955851  -9.644391  58.019499
# 120   RHpIT9     aSTS_R  61.340944   1.555851  -9.244630  62.811500
# 121  RHpIT10     aSTS_R  66.535943   1.555851  -8.445107  67.976394
# 122   uLmOlF     A11m_L  -8.192116  60.355822  -8.045346  -9.830705
# 123   uRAgIT    mAmyg_R  17.782878  11.955846 -15.241049  18.562377
#
#          mni_y      mni_z     gm                                 NMM  \
# 0    30.522125  -7.317985   Gray  Left ACgG anterior cingulate gyrus
# 1    32.166524  -2.505895  White  Left ACgG anterior cingulate gyrus
# 2    34.069446   2.265049  White          Left Cerebral White Matter
# 3    36.020665   7.462891  White          Left Cerebral White Matter
# 4    37.883783  12.121384  White          Left Cerebral White Matter
# ..         ...        ...    ...                                 ...
# 119 -12.896641 -17.481019   Gray     Right MTG middle temporal gyrus
# 120 -13.164481 -16.651358   Gray     Right MTG middle temporal gyrus
# 121 -12.872683 -15.407620   Gray     Right MTG middle temporal gyrus
# 122  51.408831 -21.944260   Gray      Left MOrG medial orbital gyrus
# 123  -2.126867 -24.986204   Gray                      Right Amygdala
#
#               Anat                 AnatMacro    BN246  \
# 0         Area s24                     L ACC     L CG
# 1          Unknown                     L ACC     L CG
# 2          Unknown                   Unknown  Unknown
# 3          Unknown                   Unknown  Unknown
# 4          Unknown                   Unknown  Unknown
# ..             ...                       ...      ...
# 119        Unknown   R Middle Temporal Gyrus    R MTG
# 120        Unknown   R Middle Temporal Gyrus    R MTG
# 121        Unknown   R Middle Temporal Gyrus    R MTG
# 122       Area Fo1  L Superior Orbital Gyrus    L OrG
# 123  Amygdala (LB)   R ParaHippocampal Gyrus   R Amyg
#
#                                       YBA_1  \
# 0                    Left cingulate gyrus D
# 1                    Left cingulate gyrus D
# 2                                   Unknown
# 3                                   Unknown
# 4                                   Unknown
# ..                                      ...
# 119                                 Unknown
# 120  Right superior middle temporal gyrus B
# 121  Right superior middle temporal gyrus B
# 122                Left frontal orbital 2 B
# 123                 Right amygdala inferior
#
#                          Manual Examination Notes
# 0                                       NaN   NaN
# 1                                        WM   NaN
# 2                                        WM   NaN
# 3                                        WM   NaN
# 4                                        WM   NaN
# ..                                      ...   ...
# 119  Right superior middle temporal gyrus B   NaN
# 120                                     NaN   NaN
# 121                                     OOB   NaN
# 122                                     NaN   NaN
# 123                                     NaN   NaN
#
# [124 rows x 16 columns]

# %% [markdown]
# ### Fix edf channel names

# %%
new_mne_names, unmatched_names, unmatched_seeg = lfp_preprocess_utils.match_elec_names(mne_data.ch_names, elec_locs.label)
# Out:
# Number of electrodes in the mne file is greater than the number of electrodes in the localization file

# %%
unmatched_names
# Out:
# ['ulmolf', 'uragit']

# %%
unmatched_seeg
# Out:
# []

# %%
new_name_dict = {x:y for (x,y) in zip(mne_data.ch_names, new_mne_names)}
new_name_dict
# Out:
# {'LmOIF1': 'lmolf1',
#  'LmOIF2': 'lmolf2',
#  'LmOIF3': 'lmolf3',
#  'LmOIF4': 'lmolf4',
#  'LmOIF5': 'lmolf5',
#  'LmOIF6': 'lmolf6',
#  'LmOIF7': 'lmolf7',
#  'LmOIF8': 'lmolf8',
#  'LmOIF9': 'lmolf9',
#  'LaCaS1': 'lacas1',
#  'LaCaS2': 'lacas2',
#  'LaCaS3': 'lacas3',
#  'LaCaS4': 'lacas4',
#  'LaCaS5': 'lacas5',
#  'LaCaS6': 'lacas6',
#  'LaCaS7': 'lacas7',
#  'LaCaS8': 'lacas8',
#  'LaCaS9': 'lacas9',
#  'LaCaS10': 'lacas10',
#  'LaCaS11': 'lacas11',
#  'LaCaS12': 'lacas12',
#  'LAgIT1': 'lagit1',
#  'LAgIT2': 'lagit2',
#  'LAgIT3': 'lagit3',
#  'LAgIT4': 'lagit4',
#  'LAgIT5': 'lagit5',
#  'LAgIT6': 'lagit6',
#  'LAgIT7': 'lagit7',
#  'LAgIT8': 'lagit8',
#  'LAgIT9': 'lagit9',
#  'LAgIT10': 'lagit10',
#  'LAgIT11': 'lagit11',
#  'LAgIT12': 'lagit12',
#  'LHpIT1': 'lhpit1',
#  'LHpIT2': 'lhpit2',
#  'LHpIT3': 'lhpit3',
#  'LHpIT4': 'lhpit4',
#  'LHpIT5': 'lhpit5',
#  'LHpIT6': 'lhpit6',
#  'LHpIT7': 'lhpit7',
#  'LHpIT8': 'lhpit8',
#  'LHpIT9': 'lhpit9',
#  'LHpIT10': 'lhpit10',
#  'LILS21': 'lils2_1',
#  'LILS22': 'lils2_2',
#  'LILS23': 'lils2_3',
#  'LILS24': 'lils2_4',
#  'LILS25': 'lils2_5',
#  'LILS26': 'lils2_6',
#  'LmLS31': 'lmls3_1',
#  'LmLS32': 'lmls3_2',
#  'LmLS33': 'lmls3_3',
#  'LmLS34': 'lmls3_4',
#  'LmLS35': 'lmls3_5',
#  'LmLS36': 'lmls3_6',
#  'LmLS37': 'lmls3_7',
#  'LmLS38': 'lmls3_8',
#  'C58': 'c58',
#  'C59': 'c59',
#  'C60': 'c60',
#  'C61': 'c61',
#  'C62': 'c62',
#  'C63': 'c63',
#  'C64': 'c64',
#  'LILS11': 'lils1_1',
#  'LILS12': 'lils1_2',
#  'LILS13': 'lils1_3',
#  'LILS14': 'lils1_4',
#  'LILS15': 'lils1_5',
#  'LILS16': 'lils1_6',
#  'LILS17': 'lils1_7',
#  'LILS18': 'lils1_8',
#  'RAgIT1': 'ragit1',
#  'RAgIT2': 'ragit2',
#  'RAgIT3': 'ragit3',
#  'RAgIT4': 'ragit4',
#  'RAgIT5': 'ragit5',
#  'RAgIT6': 'ragit6',
#  'RAgIT7': 'ragit7',
#  'RAgIT8': 'ragit8',
#  'RAgIT9': 'ragit9',
#  'RHpIT1': 'rhpit1',
#  'RHpIT2': 'rhpit2',
#  'RHpIT3': 'rhpit3',
#  'RHpIT4': 'rhpit4',
#  'RHpIT5': 'rhpit5',
#  'RHpIT6': 'rhpit6',
#  'RHpIT7': 'rhpit7',
#  'RHpIT8': 'rhpit8',
#  'RHpIT9': 'rhpit9',
#  'RHpIT10': 'rhpit10',
#  'RaCaS1': 'racas1',
#  'RaCaS2': 'racas2',
#  'RaCaS3': 'racas3',
#  'RaCaS4': 'racas4',
#  'RaCaS5': 'racas5',
#  'RaCaS6': 'racas6',
#  'RaCaS7': 'racas7',
#  'RaCaS8': 'racas8',
#  'RaCaS9': 'racas9',
#  'RaCaS10': 'racas10',
#  'RaCaS11': 'racas11',
#  'RaCaS12': 'racas12',
#  'LaImS1': 'laimm1',
#  'LaImS2': 'laimm2',
#  'LaImS3': 'laimm3',
#  'LaImS4': 'laimm4',
#  'LaImS5': 'laimm5',
#  'LaImS6': 'laimm6',
#  'LaImS7': 'laimm7',
#  'LaImS8': 'laimm8',
#  'LaImS9': 'laimm9',
#  'LaImS10': 'laimm10',
#  'LaImS11': 'laimm11',
#  'LaImS12': 'laimm12',
#  'LaImS13': 'laimm13',
#  'LaImS14': 'laimm14',
#  'LaImS15': 'laimm15',
#  'LaImS16': 'laimm16',
#  'C120': 'c120',
#  'C121': 'c121',
#  'C122': 'c122',
#  'C123': 'c123',
#  'C124': 'c124',
#  'C125': 'c125',
#  'C126': 'c126',
#  'C127': 'c127',
#  'C128': 'c128',
#  'LmCmS1': 'lmcms1',
#  'LmCmS2': 'lmcms2',
#  'LmCmS3': 'lmcms3',
#  'LmCmS4': 'lmcms4',
#  'LmCmS5': 'lmcms5',
#  'LmCmS6': 'lmcms6',
#  'LmCmS7': 'lmcms7',
#  'LmCmS8': 'lmcms8',
#  'LmCmS9': 'lmcms9',
#  'LmCmS10': 'lmcms10',
#  'Fp1': 'fp1',
#  'F7': 'f7',
#  'T3': 't3',
#  'T5': 't5',
#  'O1': 'o1',
#  'F3': 'f3',
#  'C3': 'c3',
#  'P3': 'p3',
#  'Fp2': 'fp2',
#  'F8': 'f8',
#  'T4': 't4',
#  'T6': 't6',
#  'O2': 'o2',
#  'F4': 'f4',
#  'C4': 'c4',
#  'P4': 'p4',
#  'Fz': 'fz',
#  'Cz': 'cz',
#  'Pz': 'pz',
#  'EKG1': 'ekg1',
#  'EKG2': 'ekg2',
#  'C160': 'c160',
#  'Abs1': 'abs1',
#  'Abs2': 'abs2',
#  'Chest1': 'chest1',
#  'Chest2': 'chest2',
#  'C165': 'c165',
#  'C166': 'c166',
#  'C167': 'c167',
#  'C168': 'c168',
#  'C169': 'c169',
#  'C170': 'c170',
#  'C171': 'c171',
#  'C172': 'c172',
#  'C173': 'c173',
#  'C174': 'c174',
#  'C175': 'c175',
#  'C176': 'c176',
#  'C177': 'c177',
#  'C178': 'c178',
#  'C179': 'c179',
#  'C180': 'c180',
#  'C181': 'c181',
#  'C182': 'c182',
#  'C183': 'c183',
#  'C184': 'c184',
#  'C185': 'c185',
#  'C186': 'c186',
#  'C187': 'c187',
#  'C188': 'c188',
#  'C189': 'c189',
#  'C190': 'c190',
#  'C191': 'c191',
#  'C192': 'c192',
#  'C193': 'c193',
#  'C194': 'c194',
#  'C195': 'c195',
#  'C196': 'c196',
#  'C197': 'c197',
#  'C198': 'c198',
#  'C199': 'c199',
#  'C200': 'c200',
#  'C201': 'c201',
#  'C202': 'c202',
#  'C203': 'c203',
#  'C204': 'c204',
#  'C205': 'c205',
#  'C206': 'c206',
#  'C207': 'c207',
#  'C208': 'c208',
#  'C209': 'c209',
#  'C210': 'c210',
#  'C211': 'c211',
#  'C212': 'c212',
#  'C213': 'c213',
#  'C214': 'c214',
#  'C215': 'c215',
#  'C216': 'c216',
#  'C217': 'c217',
#  'C218': 'c218',
#  'C219': 'c219',
#  'C220': 'c220',
#  'C221': 'c221',
#  'C222': 'c222',
#  'C223': 'c223',
#  'C224': 'c224',
#  'C225': 'c225',
#  'C226': 'c226',
#  'C227': 'c227',
#  'C228': 'c228',
#  'C229': 'c229',
#  'C230': 'c230',
#  'C231': 'c231',
#  'C232': 'c232',
#  'C233': 'c233',
#  'C234': 'c234',
#  'C235': 'c235',
#  'C236': 'c236',
#  'C237': 'c237',
#  'C238': 'c238',
#  'C239': 'c239',
#  'C240': 'c240',
#  'C241': 'c241',
#  'C242': 'c242',
#  'C243': 'c243',
#  'C244': 'c244',
#  'C245': 'c245',
#  'C246': 'c246',
#  'C247': 'c247',
#  'C248': 'c248',
#  'C249': 'c249',
#  'C250': 'c250',
#  'C251': 'c251',
#  'C252': 'c252',
#  'C253': 'c253',
#  'C254': 'c254',
#  'C255': 'c255',
#  'C256': 'c256',
#  'DC1': 'dc1',
#  'DC2': 'dc2',
#  'DC3': 'dc3',
#  'DC4': 'dc4',
#  'DC5': 'dc5',
#  'DC6': 'dc6',
#  'DC7': 'dc7',
#  'DC8': 'dc8',
#  'DC9': 'dc9',
#  'DC10': 'dc10',
#  'DC11': 'dc11',
#  'DC12': 'dc12',
#  'DC13': 'dc13',
#  'DC14': 'dc14',
#  'DC15': 'dc15',
#  'DC16': 'dc16',
#  'TRIG': 'trig',
#  'OSAT': 'osat',
#  'PR': 'pr',
#  'Pleth': 'pleth'}

# %%
# Rename the mne data according to the localization data
mne_data.rename_channels(new_name_dict)
# Out:
# <RawEDF | MS016_Resting_iEEG.edf, 276 x 692032 (675.8 s), ~1.42 GB, data loaded>

# %%
unmatched_seeg #make sure there are no unmatched names
# Out:
# []

# %%
anat_names = list(elec_locs.label.str.lower())
sum([ch not in mne_data.ch_names for ch in anat_names]) #if there are no missing channels, sum = 0. if sum >0, find the missing elecs
print([ch for ch in mne_data.ch_names if ch not in anat_names ]) 
#print extra channels in mne_data.ch_names and make sure none of them are neural channels
# Out:
# ['c58', 'c59', 'c60', 'c61', 'c62', 'c63', 'c64', 'c120', 'c121', 'c122', 'c123', 'c124', 'c125', 'c126', 'c127', 'c128', 'fp1', 'f7', 't3', 't5', 'o1', 'f3', 'c3', 'p3', 'fp2', 'f8', 't4', 't6', 'o2', 'f4', 'c4', 'p4', 'fz', 'cz', 'pz', 'ekg1', 'ekg2', 'c160', 'abs1', 'abs2', 'chest1', 'chest2', 'c165', 'c166', 'c167', 'c168', 'c169', 'c170', 'c171', 'c172', 'c173', 'c174', 'c175', 'c176', 'c177', 'c178', 'c179', 'c180', 'c181', 'c182', 'c183', 'c184', 'c185', 'c186', 'c187', 'c188', 'c189', 'c190', 'c191', 'c192', 'c193', 'c194', 'c195', 'c196', 'c197', 'c198', 'c199', 'c200', 'c201', 'c202', 'c203', 'c204', 'c205', 'c206', 'c207', 'c208', 'c209', 'c210', 'c211', 'c212', 'c213', 'c214', 'c215', 'c216', 'c217', 'c218', 'c219', 'c220', 'c221', 'c222', 'c223', 'c224', 'c225', 'c226', 'c227', 'c228', 'c229', 'c230', 'c231', 'c232', 'c233', 'c234', 'c235', 'c236', 'c237', 'c238', 'c239', 'c240', 'c241', 'c242', 'c243', 'c244', 'c245', 'c246', 'c247', 'c248', 'c249', 'c250', 'c251', 'c252', 'c253', 'c254', 'c255', 'c256', 'dc1', 'dc2', 'dc3', 'dc4', 'dc5', 'dc6', 'dc7', 'dc8', 'dc9', 'dc10', 'dc11', 'dc12', 'dc13', 'dc14', 'dc15', 'dc16', 'trig', 'osat', 'pr', 'pleth']

# %%
# Note, there is surface EEG data that we should separately indicate from the sEEG:
right_seeg_names = [i for i in mne_data.ch_names if i.startswith('r')]
left_seeg_names = [i for i in mne_data.ch_names if i.startswith('l')]
print(f'We have a total of', len(left_seeg_names), 'left &', len(right_seeg_names), 'right sEEG electrodes')
print(f'We have a total of {len(left_seeg_names) + len(right_seeg_names)} sEEG electrodes')
# Out:
# We have a total of 91 left & 31 right sEEG electrodes
# We have a total of 122 sEEG electrodes

# %%
drop_chans = list(set(mne_data.ch_names)^set(left_seeg_names+right_seeg_names)) # it is either called DC1 or research
mne_data.drop_channels(drop_chans) #number of chans should = number of seegs
# Out:
# <RawEDF | MS016_Resting_iEEG.edf, 122 x 692032 (675.8 s), ~644.2 MB, data loaded>

# %%
# Set channel types:
sEEG_mapping_dict = {f'{x}':'seeg' for x in left_seeg_names+right_seeg_names}
mne_data.set_channel_types(sEEG_mapping_dict)
# Out:
# <RawEDF | MS016_Resting_iEEG.edf, 122 x 692032 (675.8 s), ~644.2 MB, data loaded>

# %%
# make montage (convert mm to m)

montage = mne.channels.make_dig_montage(ch_pos=dict(zip(elec_locs.label, 
                                                        elec_locs[['mni_x', 'mni_y', 'mni_z']].to_numpy(dtype=float)/1000)),
                                        coord_frame='mni_tal')

mne_data.set_montage(montage, match_case=False, on_missing='warn')
# Out:
# <RawEDF | MS016_Resting_iEEG.edf, 122 x 692032 (675.8 s), ~644.3 MB, data loaded>

# %% [markdown]
# ### Notch filter line noise

# %%
# Identify line noise
mne_data.info['line_freq'] = 60

# Notch out 60 Hz noise and harmonics 
mne_data.notch_filter(freqs=(60, 120, 180, 240))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 122 out of 122 | elapsed:    2.0s finished
# <RawEDF | MS016_Resting_iEEG.edf, 122 x 692032 (675.8 s), ~644.3 MB, data loaded>

# %% [markdown]
# ### Resampling data

# %%
resample_sr = 500
mne_data.resample(sfreq=resample_sr, npad='auto', n_jobs=-1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 122 out of 122 | elapsed:    3.1s finished
# <RawEDF | MS016_Resting_iEEG.edf, 122 x 337906 (675.8 s), ~314.7 MB, data loaded>

# %% [markdown]
# ### Bad Channel Removal (manual)

# %% [markdown]
# Let's pick out any bad channels missed by automatic screening (visual inspection as a reference), or restore channels that were erroneously deemed bad. You have to press the "power" button twice (once for the plot and once for the panel beneath it) when you're done so that you're manual changes are saved.

# %%
mne_data = mne.io.read_raw_fif(f'{save_dir}/{subj_id}_raw_ieeg.fif', preload=True)

# %%
# %matplotlib notebook


fig = mne_data.plot(start=0, duration=120, n_channels=50, scalings=mne_data._data.max()/5)
fig.fake_keypress('a') #lots of bad times
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
mne_data.info['bads'] #sanity check that bads info saved
# Out:
# ['lmcms10']

# %% [markdown]
# ## Save raw LFP data
# Notch filtered and resampled with bad elecs indicated

# %%
mne_data.save(f'{save_dir}/{subj_id}_raw_ieeg.fif',overwrite=True)

# %% [markdown]
# # Rereference data

# %% [markdown]
# To start annotating, press 'Add new label' in the bottom panel. Then left click and drag around window of interest.

# %%
# Re-reference neural data
anat_file = glob(f'{anat_dir}/{subj_id}_labels.csv')[0]

mne_data_bp_reref = lfp_preprocess_utils.ref_mne(mne_data=mne_data, 
                                              elec_path=anat_file, 
                                              method='bipolar', 
                                              site='MSSM')
# Out:
# Number of electrodes in the mne file is less than the number of electrodes in the localization file

# %%
# %matplotlib notebook


fig = mne_data_bp_reref.plot(start=2, duration=100, n_channels=50,scalings=mne_data._data.max()/5 ) # plot all channels at once
fig.fake_keypress("a")
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %% [markdown]
# ### Save reref data

# %%
mne_data_bp_reref.save(f'{save_dir}/{subj_id}_bp_ref_ieeg.fif',overwrite=True)
